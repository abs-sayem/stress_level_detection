# %% [markdown]
# # **Stress Level Detection (using Feature Data)**
# **What we have tried here -**
# - **Make a csv dataset extracting all the features from the Audio data**
# - **Train and validate three differnt models for comparison study:**
#     - **Statistical ML Model (SVM and Random Forest)**
#     - **CNN Model (StressCNN)**
#     - **Proposed Model (LSTM + CNN)**

# %% [markdown]
# **Import Library**

# %%
# Importing all necessary libraries
import pandas as pd
import numpy as np
import os
import librosa
import librosa.display
from IPython.display import Audio
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import warnings
warnings.filterwarnings('ignore')
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import seaborn as sns

# %% [markdown]
# **Load Dataset**

# %%
df= pd.read_excel("features_2.xlsx");
df.head()
# Out:
#          Pitch  Intensity    Frequency  Amplitude  \
# 0  1410.588989   0.041406  1410.588989   0.337341
# 1  1168.005859   0.022364  1168.005859   0.176117
# 2  1863.138916   0.029732  1863.138916   0.265015
# 3  1489.154175   0.043054  1489.154175   0.343719
# 4  1090.847290   0.030544  1090.847290   0.282318
#
#                                                MFCCs  Spectral Centroid  \
# 0  [-390.0313415527344, 55.235965728759766, -15.0...        2244.518922
# 1  [-451.01947021484375, 67.048828125, -0.4482572...        2182.569100
# 2  [-406.5633239746094, 28.609004974365234, -5.31...        2964.378675
# 3  [-386.34002685546875, 53.43965530395508, -8.66...        2636.422929
# 4  [-404.7848815917969, 54.46256637573242, 3.3552...        2330.168832
#
#    Spectral Bandwidth  Spectral Rolloff  \
# 0         2417.499675       4023.786502
# 1         2405.502339       3817.591309
# 2         2675.259261       5331.541280
# 3         2515.913088       4431.942332
# 4         2432.395141       4295.259839
#
#                                       Spectral Flux    Energy       ZCR  \
# 0    (7.856366210035048e-06-8.686884029884823e-07j)  0.041406  0.081048
# 1    (7.408749752357835e-06-2.919421149272239e-07j)  0.022364  0.085180
# 2  (-3.4756992590700975e-06-8.736076779314317e-06j)  0.029732  0.127679
# 3  (-1.4807430943619693e-06-3.374229663677397e-06j)  0.043054  0.105919
# 4    (5.316106125974329e-06+1.038062237057602e-05j)  0.030544  0.076019
#
#         Tempo  Stress
# 0  143.050781       9
# 1  130.046165       9
# 2  143.050781       9
# 3   95.367188       9
# 4  110.039062       9

# %% [markdown]
# #### **Preprocess Data**

# %%
# Check if any column contains NaN or null values
df.isnull().any()
# Out:
# Pitch                 False
# Intensity             False
# Frequency             False
# Amplitude             False
# MFCCs                 False
# Spectral Centroid     False
# Spectral Bandwidth    False
# Spectral Rolloff      False
# Spectral Flux         False
# Energy                False
# ZCR                   False
# Tempo                 False
# Stress                False
# dtype: bool

# %%
import ast
def average_mfcc(mfcc_str):
    # Convert the string representation of list to actual list
    mfcc_list = ast.literal_eval(mfcc_str)
    # Calculate the average of the list
    return np.mean(mfcc_list)

df['MFCCs'] = df['MFCCs'].apply(average_mfcc)

# %%
# Convert the 'Spectral Flux' column to complex numbers if they are in string format
df['Spectral Flux'] = df['Spectral Flux'].apply(lambda x: complex(x) if isinstance(x, str) else x)

# Now calculate the magnitude (absolute value) of the complex numbers
df['Spectral Flux Magnitude'] = df['Spectral Flux'].apply(lambda x: abs(x))

# %%
# Drop the 'Spectral Flux' column from the DataFrame
df = df.drop(columns=['Spectral Flux'])

# %%
#data split
X = df.drop(columns=['Stress'])
y = df['Stress']

# %% [markdown]
# #### **Feature Selection**

# %%
from sklearn.feature_selection import SelectKBest, f_classif
# Step 2: Perform Feature Selection (Select top 8 features using ANOVA F-statistic)
selector = SelectKBest(score_func=f_classif, k='all')  # 'k=all' to keep all features
X_selected = selector.fit_transform(X, y)

# Step 3: Get the feature scores and normalize them to get percentages
feature_scores = selector.scores_
max_score = max(feature_scores)
feature_scores_percentage = [score / max_score * 100 for score in feature_scores]

# Step 4: Create a DataFrame to show feature scores and percentages
selected_features_df = pd.DataFrame({
    'Feature': X.columns,
    'Score': feature_scores,
    'Score Percentage': feature_scores_percentage
})

# Display the selected features and their importance
print("Feature Importance (Percentage):\n", selected_features_df)

# Step 5: Visualization (Bar plot of feature importance)
plt.figure(figsize=(10, 6))
plt.barh(selected_features_df['Feature'], selected_features_df['Score Percentage'], color='skyblue')
plt.xlabel('Importance (%)')
plt.title('Feature Importance Based on ANOVA F-Statistic')
plt.show()
# Out:
# Feature Importance (Percentage):
#                      Feature       Score  Score Percentage
# 0                     Pitch  109.533977         46.558552
# 1                 Intensity  201.722409         85.744200
# 2                 Frequency  109.533977         46.558552
# 3                 Amplitude  235.260704        100.000000
# 4                     MFCCs   24.063334         10.228369
# 5         Spectral Centroid   91.840289         39.037666
# 6        Spectral Bandwidth   94.941430         40.355839
# 7          Spectral Rolloff  114.462450         48.653450
# 8                    Energy  201.722409         85.744200
# 9                       ZCR   64.025727         27.214799
# 10                    Tempo   70.346124         29.901349
# 11  Spectral Flux Magnitude   14.524479          6.173780

# %%
#finalize column
# List of selected columns
selected_columns = [
    'Intensity',
    'Amplitude',
    'Spectral Centroid',
    'Spectral Bandwidth',
    'Spectral Rolloff',
    'Energy',
    'Pitch',
    'Frequency'
]

# Filter the DataFrame to keep only the selected columns
X_selected = X[selected_columns]

# Display the resulting DataFrame
print(X_selected.head())
# Out:
#    Intensity  Amplitude  Spectral Centroid  Spectral Bandwidth  \
# 0   0.041406   0.337341        2244.518922         2417.499675
# 1   0.022364   0.176117        2182.569100         2405.502339
# 2   0.029732   0.265015        2964.378675         2675.259261
# 3   0.043054   0.343719        2636.422929         2515.913088
# 4   0.030544   0.282318        2330.168832         2432.395141
#
#    Spectral Rolloff    Energy        Pitch    Frequency
# 0       4023.786502  0.041406  1410.588989  1410.588989
# 1       3817.591309  0.022364  1168.005859  1168.005859
# 2       5331.541280  0.029732  1863.138916  1863.138916
# 3       4431.942332  0.043054  1489.154175  1489.154175
# 4       4295.259839  0.030544  1090.847290  1090.847290

# %% [markdown]
# #### **Check SVM and Random Forest Model**

# %% [markdown]
# **Train-Test Split**

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
# Further split X_train into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# **Normilazition:** `[converting data values in a certain range]`

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ****Initialize Models and Train****

# %%
# Initialize models
svc_model = SVC(kernel='rbf', probability=True, random_state=42)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Train and evaluate models
history = {"svc": {"train_acc": [], "val_acc": []}, "rf": {"train_acc": [], "val_acc": []}}

# SVC Model
svc_model.fit(X_train, y_train)
svc_train_acc = svc_model.score(X_train, y_train)
svc_val_acc = svc_model.score(X_val, y_val)
history["svc"]["train_acc"].append(svc_train_acc)
history["svc"]["val_acc"].append(svc_val_acc)
svc_predictions = svc_model.predict(X_test)
svc_probs = svc_model.predict_proba(X_test)[:, 1]

# Random Forest Model
rf_model.fit(X_train, y_train)
rf_train_acc = rf_model.score(X_train, y_train)
rf_val_acc = rf_model.score(X_val, y_val)
history["rf"]["train_acc"].append(rf_train_acc)
history["rf"]["val_acc"].append(rf_val_acc)
rf_predictions = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# `Classification Reports`

# %%
# Classification Reports
print("SVC Classification Report:\n", classification_report(y_test, svc_predictions))
print("Random Forest Classification Report:\n", classification_report(y_test, rf_predictions))
# Out:
# SVC Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.59      0.75      0.66        73
#            2       0.58      0.73      0.65        77
#            4       0.68      0.56      0.61        82
#            5       0.61      0.62      0.61        87
#            6       0.74      0.67      0.70        78
#            8       0.70      0.61      0.65        89
#            9       0.66      0.59      0.62        74
#
#     accuracy                           0.64       560
#    macro avg       0.65      0.65      0.64       560
# weighted avg       0.65      0.64      0.64       560
#
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.73      0.76        73
#            2       0.60      0.77      0.67        77
#            4       0.75      0.80      0.78        82
#            5       0.62      0.62      0.62        87
#            6       0.79      0.76      0.77        78
#            8       0.77      0.61      0.68        89
#            9       0.71      0.73      0.72        74
#
#     accuracy                           0.71       560
#    macro avg       0.72      0.72      0.71       560
# weighted avg       0.72      0.71      0.71       560

# %% [markdown]
# `Confusion Matrixs`

# %%
# Confusion Matrices
svc_cm = confusion_matrix(y_test, svc_predictions)
rf_cm = confusion_matrix(y_test, rf_predictions)

# %%
# Plot Confusion Matrices
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.heatmap(svc_cm, annot=True, fmt='d', cmap="Blues")
plt.title("SVC Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")

plt.subplot(1, 2, 2)
sns.heatmap(rf_cm, annot=True, fmt='d', cmap="Blues")
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %% [markdown]
# #### **CNN Model**

# %% [markdown]
# **Transform Data** `[Getting ready data for cnn model]`

# %%
X_scaled = scaler.fit_transform(X)

print(X_scaled)
# Out:
# [[-0.47551382  0.58762502 -0.47551382 ... -1.11005622  0.76803954
#    0.37982777]
#  [-1.15943724 -0.44187184 -1.15943724 ... -1.03141218  0.2154015
#    0.31091928]
#  [ 0.80037662 -0.043507    0.80037662 ... -0.22252363  0.76803954
#    0.59057947]
#  ...
#  [-2.70469165  0.662916   -2.70469165 ...  0.41999564 -1.25829996
#   -0.41738433]
#  [-1.53234058 -0.10110286 -1.53234058 ... -0.52452091 -1.38903154
#   -0.58921565]
#  [-0.85374127 -0.05422649 -0.85374127 ...  0.25295812  1.84080751
#   -0.11823656]]

# %% [markdown]
# **Reshape Data** `[convery 2d data into 1d to make it suitable for out model]`

# %%
# Reshape the data for the CNN input (e.g., [batch_size, channels, height, width])
# Here, we assume 1 channel, and the features can be treated as a 2D input (for example, each row is a feature vector).

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1], 1)  # [samples, channels, feature_size, 1]
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1], 1)  # [samples, channels, feature_size, 1]

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# **Convert Numpy Data to Tenson**

# %%
# Convert NumPy arrays and pandas Series to PyTorch tensors
X_train_tensor = torch.tensor(X_train_final, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

y_train_tensor = torch.tensor(y_train_final.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array
y_val_tensor = torch.tensor(y_val.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array
y_test_tensor = torch.tensor(y_test.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array

# %%
print(f'x_train_tensor={X_train_tensor.shape}, X_val_tensor={X_val_tensor.shape}, X_test_tensor={X_test_tensor.shape}, y_train_tensor={y_train_tensor.shape}, y_val_tensor={y_val_tensor.shape},y_test_tensor={y_test_tensor.shape} ')
# Out:
# x_train_tensor=torch.Size([1433, 1, 8, 1]), X_val_tensor=torch.Size([359, 1, 8, 1]), X_test_tensor=torch.Size([560, 1, 8, 1]), y_train_tensor=torch.Size([1433]), y_val_tensor=torch.Size([359]),y_test_tensor=torch.Size([560])

# %% [markdown]
# **Further reshape to 1D**

# %%
# Reshaping input tensor to match Conv1d's expected input shape [batch_size, channels, sequence_length]
X_train_tensor = X_train_tensor.view(X_train_tensor.size(0), 1, -1)  # [1792, 1, 8]
X_val_tensor = X_val_tensor.view(X_val_tensor.size(0), 1, -1)        # [448, 1, 8]
X_test_tensor = X_test_tensor.view(X_test_tensor.size(0), 1, -1)      # [560, 1, 8]

y_train_tensor = y_train_tensor - 1
y_val_tensor = y_val_tensor - 1
y_test_tensor = y_test_tensor - 1

print(f'x_train_tensor={X_train_tensor.shape}, X_val_tensor={X_val_tensor.shape}, X_test_tensor={X_test_tensor.shape}, y_train_tensor={y_train_tensor.shape}, y_val_tensor={y_val_tensor.shape}, y_test_tensor={y_test_tensor.shape}')
# Out:
# x_train_tensor=torch.Size([1433, 1, 8]), X_val_tensor=torch.Size([359, 1, 8]), X_test_tensor=torch.Size([560, 1, 8]), y_train_tensor=torch.Size([1433]), y_val_tensor=torch.Size([359]), y_test_tensor=torch.Size([560])

# %%
print(f"Max label in y_train_tensor: {y_train_tensor.max()}")
print(f"Min label in y_train_tensor: {y_train_tensor.min()}")
# Out:
# Max label in y_train_tensor: 8
# Min label in y_train_tensor: 0

# %% [markdown]
# **CNN Model Difinition**

# %%
# Define the model
class StressCNN(nn.Module):
    def __init__(self, num_classes=9):  # Changed from 7 to 9
        super(StressCNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(64 * 2, 128)  # Adjusted size after calculating conv output
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, num_classes)  # This should match the number of classes

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(x)
        x = self.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# **Training ...**

# %%
# Define model, loss, and optimizer
model = StressCNN(num_classes=9)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Track history
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

# Early stopping parameters
early_stop_patience = 20  # Number of epochs to wait for improvement in validation loss
best_val_loss = float('inf')
patience_counter = 0

# Training loop with validation and early stopping
for epoch in range(500):  # Train for up to 200 epochs or until early stopping
    model.train()  # Set the model to training mode
    optimizer.zero_grad()
    
    # Forward pass on training data
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    
    # Calculate training accuracy
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == y_train_tensor).sum().item()
    train_accuracy = correct / y_train_tensor.size(0) * 100

    # Validation step
    model.eval()  # Set the model to evaluation mode for validation
    with torch.no_grad():
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)
        _, val_predicted = torch.max(val_outputs, 1)
        val_correct = (val_predicted == y_val_tensor).sum().item()
        val_accuracy = val_correct / y_val_tensor.size(0) * 100

    # Store history
    history["train_loss"].append(loss.item())
    history["val_loss"].append(val_loss.item())
    history["train_acc"].append(train_accuracy)
    history["val_acc"].append(val_accuracy)

    # Print progress
    print(f"Epoch [{epoch+1}/200], Train Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss.item():.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    # Early stopping check based on validation loss
    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        patience_counter = 0  # Reset counter if improvement
    else:
        patience_counter += 1

    # Trigger early stopping if validation loss doesn't improve
    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss:.4f}")
        break
# Out:
# Epoch [1/200], Train Loss: 2.2034, Train Accuracy: 14.38%
# Validation Loss: 2.1758, Validation Accuracy: 15.32%
# Epoch [2/200], Train Loss: 2.1797, Train Accuracy: 15.14%
# Validation Loss: 2.1521, Validation Accuracy: 15.88%
# Epoch [3/200], Train Loss: 2.1573, Train Accuracy: 16.89%
# Validation Loss: 2.1303, Validation Accuracy: 17.55%
# Epoch [4/200], Train Loss: 2.1352, Train Accuracy: 18.77%
# Validation Loss: 2.1088, Validation Accuracy: 18.11%
# Epoch [5/200], Train Loss: 2.1141, Train Accuracy: 19.12%
# Validation Loss: 2.0871, Validation Accuracy: 20.61%
# Epoch [6/200], Train Loss: 2.0879, Train Accuracy: 19.96%
# Validation Loss: 2.0646, Validation Accuracy: 21.17%
# Epoch [7/200], Train Loss: 2.0638, Train Accuracy: 21.00%
# Validation Loss: 2.0411, Validation Accuracy: 21.45%
# Epoch [8/200], Train Loss: 2.0404, Train Accuracy: 23.10%
# Validation Loss: 2.0166, Validation Accuracy: 21.73%
# Epoch [9/200], Train Loss: 2.0201, Train Accuracy: 22.12%
# Validation Loss: 1.9909, Validation Accuracy: 21.73%
# Epoch [10/200], Train Loss: 1.9931, Train Accuracy: 23.45%
# Validation Loss: 1.9645, Validation Accuracy: 21.73%
# Epoch [11/200], Train Loss: 1.9677, Train Accuracy: 25.54%
# Validation Loss: 1.9377, Validation Accuracy: 21.73%
# Epoch [12/200], Train Loss: 1.9482, Train Accuracy: 23.87%
# Validation Loss: 1.9109, Validation Accuracy: 21.17%
# Epoch [13/200], Train Loss: 1.9165, Train Accuracy: 23.87%
# Validation Loss: 1.8843, Validation Accuracy: 23.68%
# Epoch [14/200], Train Loss: 1.8915, Train Accuracy: 25.61%
# Validation Loss: 1.8584, Validation Accuracy: 24.23%
# Epoch [15/200], Train Loss: 1.8656, Train Accuracy: 24.63%
# Validation Loss: 1.8338, Validation Accuracy: 26.46%
# Epoch [16/200], Train Loss: 1.8374, Train Accuracy: 25.05%
# Validation Loss: 1.8112, Validation Accuracy: 27.58%
# Epoch [17/200], Train Loss: 1.8132, Train Accuracy: 27.08%
# Validation Loss: 1.7909, Validation Accuracy: 28.41%
# Epoch [18/200], Train Loss: 1.7930, Train Accuracy: 26.87%
# Validation Loss: 1.7729, Validation Accuracy: 29.25%
# Epoch [19/200], Train Loss: 1.7805, Train Accuracy: 24.98%
# Validation Loss: 1.7572, Validation Accuracy: 28.97%
# Epoch [20/200], Train Loss: 1.7604, Train Accuracy: 26.73%
# Validation Loss: 1.7439, Validation Accuracy: 28.97%
# Epoch [21/200], Train Loss: 1.7310, Train Accuracy: 29.10%
# Validation Loss: 1.7326, Validation Accuracy: 28.69%
# Epoch [22/200], Train Loss: 1.7364, Train Accuracy: 27.70%
# Validation Loss: 1.7226, Validation Accuracy: 28.13%
# Epoch [23/200], Train Loss: 1.7405, Train Accuracy: 26.73%
# Validation Loss: 1.7131, Validation Accuracy: 29.25%
# Epoch [24/200], Train Loss: 1.7217, Train Accuracy: 27.63%
# Validation Loss: 1.7044, Validation Accuracy: 31.48%
# Epoch [25/200], Train Loss: 1.7077, Train Accuracy: 28.54%
# Validation Loss: 1.6959, Validation Accuracy: 33.15%
# Epoch [26/200], Train Loss: 1.6875, Train Accuracy: 28.47%
# Validation Loss: 1.6876, Validation Accuracy: 33.98%
# Epoch [27/200], Train Loss: 1.6969, Train Accuracy: 30.36%
# Validation Loss: 1.6794, Validation Accuracy: 33.43%
# Epoch [28/200], Train Loss: 1.6848, Train Accuracy: 30.15%
# Validation Loss: 1.6708, Validation Accuracy: 33.98%
# Epoch [29/200], Train Loss: 1.6659, Train Accuracy: 29.87%
# Validation Loss: 1.6618, Validation Accuracy: 34.82%
# Epoch [30/200], Train Loss: 1.6592, Train Accuracy: 32.59%
# Validation Loss: 1.6524, Validation Accuracy: 33.98%
# Epoch [31/200], Train Loss: 1.6552, Train Accuracy: 32.38%
# Validation Loss: 1.6432, Validation Accuracy: 35.38%
# Epoch [32/200], Train Loss: 1.6350, Train Accuracy: 32.59%
# Validation Loss: 1.6342, Validation Accuracy: 36.21%
# Epoch [33/200], Train Loss: 1.6170, Train Accuracy: 33.78%
# Validation Loss: 1.6251, Validation Accuracy: 37.60%
# Epoch [34/200], Train Loss: 1.6197, Train Accuracy: 33.64%
# Validation Loss: 1.6161, Validation Accuracy: 38.44%
# Epoch [35/200], Train Loss: 1.6140, Train Accuracy: 35.31%
# Validation Loss: 1.6070, Validation Accuracy: 39.28%
# Epoch [36/200], Train Loss: 1.6019, Train Accuracy: 34.96%
# Validation Loss: 1.5978, Validation Accuracy: 39.55%
# Epoch [37/200], Train Loss: 1.5795, Train Accuracy: 36.64%
# Validation Loss: 1.5884, Validation Accuracy: 39.83%
# Epoch [38/200], Train Loss: 1.5836, Train Accuracy: 36.64%
# Validation Loss: 1.5791, Validation Accuracy: 40.39%
# Epoch [39/200], Train Loss: 1.5634, Train Accuracy: 38.31%
# Validation Loss: 1.5700, Validation Accuracy: 40.39%
# Epoch [40/200], Train Loss: 1.5553, Train Accuracy: 37.82%
# Validation Loss: 1.5613, Validation Accuracy: 40.11%
# Epoch [41/200], Train Loss: 1.5395, Train Accuracy: 39.64%
# Validation Loss: 1.5529, Validation Accuracy: 40.39%
# Epoch [42/200], Train Loss: 1.5217, Train Accuracy: 39.43%
# Validation Loss: 1.5445, Validation Accuracy: 40.95%
# Epoch [43/200], Train Loss: 1.5213, Train Accuracy: 40.47%
# Validation Loss: 1.5361, Validation Accuracy: 41.23%
# Epoch [44/200], Train Loss: 1.4944, Train Accuracy: 42.92%
# Validation Loss: 1.5274, Validation Accuracy: 41.50%
# Epoch [45/200], Train Loss: 1.5125, Train Accuracy: 41.94%
# Validation Loss: 1.5189, Validation Accuracy: 42.06%
# Epoch [46/200], Train Loss: 1.5063, Train Accuracy: 41.24%
# Validation Loss: 1.5101, Validation Accuracy: 42.34%
# Epoch [47/200], Train Loss: 1.4743, Train Accuracy: 42.08%
# Validation Loss: 1.5009, Validation Accuracy: 43.73%
# Epoch [48/200], Train Loss: 1.4586, Train Accuracy: 45.50%
# Validation Loss: 1.4907, Validation Accuracy: 44.01%
# Epoch [49/200], Train Loss: 1.4534, Train Accuracy: 43.82%
# Validation Loss: 1.4802, Validation Accuracy: 43.73%
# Epoch [50/200], Train Loss: 1.4344, Train Accuracy: 45.57%
# Validation Loss: 1.4694, Validation Accuracy: 44.29%
# Epoch [51/200], Train Loss: 1.4224, Train Accuracy: 45.22%
# Validation Loss: 1.4589, Validation Accuracy: 44.85%
# Epoch [52/200], Train Loss: 1.4229, Train Accuracy: 45.50%
# Validation Loss: 1.4487, Validation Accuracy: 45.40%
# Epoch [53/200], Train Loss: 1.4169, Train Accuracy: 47.38%
# Validation Loss: 1.4380, Validation Accuracy: 45.13%
# Epoch [54/200], Train Loss: 1.4044, Train Accuracy: 46.41%
# Validation Loss: 1.4274, Validation Accuracy: 45.68%
# Epoch [55/200], Train Loss: 1.3906, Train Accuracy: 47.03%
# Validation Loss: 1.4170, Validation Accuracy: 46.24%
# Epoch [56/200], Train Loss: 1.3754, Train Accuracy: 48.71%
# Validation Loss: 1.4065, Validation Accuracy: 47.08%
# Epoch [57/200], Train Loss: 1.3741, Train Accuracy: 46.89%
# Validation Loss: 1.3966, Validation Accuracy: 47.35%
# Epoch [58/200], Train Loss: 1.3741, Train Accuracy: 48.15%
# Validation Loss: 1.3866, Validation Accuracy: 47.63%
# Epoch [59/200], Train Loss: 1.3512, Train Accuracy: 48.85%
# Validation Loss: 1.3769, Validation Accuracy: 47.63%
# Epoch [60/200], Train Loss: 1.3449, Train Accuracy: 49.48%
# Validation Loss: 1.3672, Validation Accuracy: 47.35%
# Epoch [61/200], Train Loss: 1.3191, Train Accuracy: 49.62%
# Validation Loss: 1.3571, Validation Accuracy: 47.63%
# Epoch [62/200], Train Loss: 1.3423, Train Accuracy: 48.85%
# Validation Loss: 1.3475, Validation Accuracy: 47.63%
# Epoch [63/200], Train Loss: 1.3046, Train Accuracy: 52.41%
# Validation Loss: 1.3386, Validation Accuracy: 47.91%
# Epoch [64/200], Train Loss: 1.2964, Train Accuracy: 51.08%
# Validation Loss: 1.3288, Validation Accuracy: 47.63%
# Epoch [65/200], Train Loss: 1.2906, Train Accuracy: 51.71%
# Validation Loss: 1.3190, Validation Accuracy: 48.19%
# Epoch [66/200], Train Loss: 1.2725, Train Accuracy: 54.29%
# Validation Loss: 1.3097, Validation Accuracy: 48.47%
# Epoch [67/200], Train Loss: 1.2833, Train Accuracy: 51.43%
# Validation Loss: 1.3012, Validation Accuracy: 49.30%
# Epoch [68/200], Train Loss: 1.2740, Train Accuracy: 51.78%
# Validation Loss: 1.2931, Validation Accuracy: 50.70%
# Epoch [69/200], Train Loss: 1.2389, Train Accuracy: 53.73%
# Validation Loss: 1.2851, Validation Accuracy: 50.97%
# Epoch [70/200], Train Loss: 1.2527, Train Accuracy: 54.22%
# Validation Loss: 1.2760, Validation Accuracy: 51.25%
# Epoch [71/200], Train Loss: 1.2404, Train Accuracy: 52.83%
# Validation Loss: 1.2673, Validation Accuracy: 52.09%
# Epoch [72/200], Train Loss: 1.2329, Train Accuracy: 52.76%
# Validation Loss: 1.2588, Validation Accuracy: 52.37%
# Epoch [73/200], Train Loss: 1.2302, Train Accuracy: 54.92%
# Validation Loss: 1.2508, Validation Accuracy: 52.65%
# Epoch [74/200], Train Loss: 1.2093, Train Accuracy: 55.48%
# Validation Loss: 1.2428, Validation Accuracy: 53.20%
# Epoch [75/200], Train Loss: 1.2042, Train Accuracy: 55.76%
# Validation Loss: 1.2358, Validation Accuracy: 53.20%
# Epoch [76/200], Train Loss: 1.1931, Train Accuracy: 55.62%
# Validation Loss: 1.2297, Validation Accuracy: 53.48%
# Epoch [77/200], Train Loss: 1.2017, Train Accuracy: 55.34%
# Validation Loss: 1.2229, Validation Accuracy: 53.20%
# Epoch [78/200], Train Loss: 1.1816, Train Accuracy: 56.04%
# Validation Loss: 1.2151, Validation Accuracy: 54.32%
# Epoch [79/200], Train Loss: 1.1722, Train Accuracy: 56.66%
# Validation Loss: 1.2068, Validation Accuracy: 54.87%
# Epoch [80/200], Train Loss: 1.1504, Train Accuracy: 58.34%
# Validation Loss: 1.1992, Validation Accuracy: 54.87%
# Epoch [81/200], Train Loss: 1.1428, Train Accuracy: 57.08%
# Validation Loss: 1.1911, Validation Accuracy: 55.15%
# Epoch [82/200], Train Loss: 1.1515, Train Accuracy: 56.73%
# Validation Loss: 1.1848, Validation Accuracy: 55.43%
# Epoch [83/200], Train Loss: 1.1455, Train Accuracy: 56.94%
# Validation Loss: 1.1799, Validation Accuracy: 55.71%
# Epoch [84/200], Train Loss: 1.1387, Train Accuracy: 57.22%
# Validation Loss: 1.1755, Validation Accuracy: 56.27%
# Epoch [85/200], Train Loss: 1.1504, Train Accuracy: 57.01%
# Validation Loss: 1.1681, Validation Accuracy: 56.55%
# Epoch [86/200], Train Loss: 1.1300, Train Accuracy: 57.08%
# Validation Loss: 1.1584, Validation Accuracy: 56.55%
# Epoch [87/200], Train Loss: 1.1223, Train Accuracy: 57.92%
# Validation Loss: 1.1499, Validation Accuracy: 56.82%
# Epoch [88/200], Train Loss: 1.1214, Train Accuracy: 56.87%
# Validation Loss: 1.1429, Validation Accuracy: 55.99%
# Epoch [89/200], Train Loss: 1.0990, Train Accuracy: 60.29%
# Validation Loss: 1.1375, Validation Accuracy: 56.55%
# Epoch [90/200], Train Loss: 1.1099, Train Accuracy: 59.25%
# Validation Loss: 1.1323, Validation Accuracy: 56.27%
# Epoch [91/200], Train Loss: 1.0987, Train Accuracy: 58.97%
# Validation Loss: 1.1275, Validation Accuracy: 56.27%
# Epoch [92/200], Train Loss: 1.0916, Train Accuracy: 60.29%
# Validation Loss: 1.1234, Validation Accuracy: 56.82%
# Epoch [93/200], Train Loss: 1.1004, Train Accuracy: 59.94%
# Validation Loss: 1.1179, Validation Accuracy: 56.82%
# Epoch [94/200], Train Loss: 1.0855, Train Accuracy: 60.01%
# Validation Loss: 1.1114, Validation Accuracy: 56.82%
# Epoch [95/200], Train Loss: 1.0730, Train Accuracy: 59.53%
# Validation Loss: 1.1063, Validation Accuracy: 56.27%
# Epoch [96/200], Train Loss: 1.0738, Train Accuracy: 60.78%
# Validation Loss: 1.1012, Validation Accuracy: 56.55%
# Epoch [97/200], Train Loss: 1.0559, Train Accuracy: 60.78%
# Validation Loss: 1.0945, Validation Accuracy: 56.55%
# Epoch [98/200], Train Loss: 1.0548, Train Accuracy: 60.29%
# Validation Loss: 1.0878, Validation Accuracy: 58.22%
# Epoch [99/200], Train Loss: 1.0535, Train Accuracy: 59.60%
# Validation Loss: 1.0829, Validation Accuracy: 58.22%
# Epoch [100/200], Train Loss: 1.0468, Train Accuracy: 61.06%
# Validation Loss: 1.0780, Validation Accuracy: 58.50%
# Epoch [101/200], Train Loss: 1.0346, Train Accuracy: 60.71%
# Validation Loss: 1.0741, Validation Accuracy: 57.38%
# Epoch [102/200], Train Loss: 1.0276, Train Accuracy: 61.55%
# Validation Loss: 1.0688, Validation Accuracy: 57.38%
# Epoch [103/200], Train Loss: 1.0361, Train Accuracy: 61.83%
# Validation Loss: 1.0630, Validation Accuracy: 57.38%
# Epoch [104/200], Train Loss: 1.0259, Train Accuracy: 61.55%
# Validation Loss: 1.0563, Validation Accuracy: 58.22%
# Epoch [105/200], Train Loss: 1.0066, Train Accuracy: 62.88%
# Validation Loss: 1.0525, Validation Accuracy: 59.05%
# Epoch [106/200], Train Loss: 1.0319, Train Accuracy: 61.06%
# Validation Loss: 1.0475, Validation Accuracy: 59.61%
# Epoch [107/200], Train Loss: 1.0036, Train Accuracy: 62.60%
# Validation Loss: 1.0395, Validation Accuracy: 59.05%
# Epoch [108/200], Train Loss: 1.0143, Train Accuracy: 61.41%
# Validation Loss: 1.0335, Validation Accuracy: 59.33%
# Epoch [109/200], Train Loss: 1.0011, Train Accuracy: 63.08%
# Validation Loss: 1.0292, Validation Accuracy: 59.33%
# Epoch [110/200], Train Loss: 0.9902, Train Accuracy: 64.20%
# Validation Loss: 1.0248, Validation Accuracy: 59.61%
# Epoch [111/200], Train Loss: 0.9874, Train Accuracy: 63.15%
# Validation Loss: 1.0200, Validation Accuracy: 59.89%
# Epoch [112/200], Train Loss: 0.9992, Train Accuracy: 62.46%
# Validation Loss: 1.0147, Validation Accuracy: 60.17%
# Epoch [113/200], Train Loss: 0.9716, Train Accuracy: 63.78%
# Validation Loss: 1.0096, Validation Accuracy: 59.61%
# Epoch [114/200], Train Loss: 0.9807, Train Accuracy: 63.15%
# Validation Loss: 1.0042, Validation Accuracy: 59.61%
# Epoch [115/200], Train Loss: 0.9575, Train Accuracy: 64.06%
# Validation Loss: 1.0024, Validation Accuracy: 60.17%
# Epoch [116/200], Train Loss: 0.9519, Train Accuracy: 64.83%
# Validation Loss: 1.0018, Validation Accuracy: 59.61%
# Epoch [117/200], Train Loss: 0.9505, Train Accuracy: 63.64%
# Validation Loss: 0.9975, Validation Accuracy: 59.05%
# Epoch [118/200], Train Loss: 0.9721, Train Accuracy: 63.99%
# Validation Loss: 0.9887, Validation Accuracy: 59.89%
# Epoch [119/200], Train Loss: 0.9590, Train Accuracy: 64.13%
# Validation Loss: 0.9789, Validation Accuracy: 60.45%
# Epoch [120/200], Train Loss: 0.9421, Train Accuracy: 64.55%
# Validation Loss: 0.9731, Validation Accuracy: 61.28%
# Epoch [121/200], Train Loss: 0.9386, Train Accuracy: 63.50%
# Validation Loss: 0.9717, Validation Accuracy: 60.72%
# Epoch [122/200], Train Loss: 0.9372, Train Accuracy: 65.46%
# Validation Loss: 0.9757, Validation Accuracy: 61.28%
# Epoch [123/200], Train Loss: 0.9359, Train Accuracy: 65.18%
# Validation Loss: 0.9754, Validation Accuracy: 61.00%
# Epoch [124/200], Train Loss: 0.9337, Train Accuracy: 63.64%
# Validation Loss: 0.9655, Validation Accuracy: 61.00%
# Epoch [125/200], Train Loss: 0.9216, Train Accuracy: 65.67%
# Validation Loss: 0.9584, Validation Accuracy: 61.00%
# Epoch [126/200], Train Loss: 0.8967, Train Accuracy: 65.88%
# Validation Loss: 0.9521, Validation Accuracy: 61.00%
# Epoch [127/200], Train Loss: 0.9244, Train Accuracy: 64.55%
# Validation Loss: 0.9473, Validation Accuracy: 62.67%
# Epoch [128/200], Train Loss: 0.9014, Train Accuracy: 66.99%
# Validation Loss: 0.9429, Validation Accuracy: 62.95%
# Epoch [129/200], Train Loss: 0.8870, Train Accuracy: 66.43%
# Validation Loss: 0.9382, Validation Accuracy: 63.23%
# Epoch [130/200], Train Loss: 0.9042, Train Accuracy: 66.50%
# Validation Loss: 0.9339, Validation Accuracy: 63.23%
# Epoch [131/200], Train Loss: 0.8863, Train Accuracy: 66.43%
# Validation Loss: 0.9307, Validation Accuracy: 62.95%
# Epoch [132/200], Train Loss: 0.8721, Train Accuracy: 67.55%
# Validation Loss: 0.9280, Validation Accuracy: 63.23%
# Epoch [133/200], Train Loss: 0.8779, Train Accuracy: 65.53%
# Validation Loss: 0.9225, Validation Accuracy: 64.35%
# Epoch [134/200], Train Loss: 0.8944, Train Accuracy: 66.64%
# Validation Loss: 0.9163, Validation Accuracy: 64.90%
# Epoch [135/200], Train Loss: 0.8899, Train Accuracy: 65.74%
# Validation Loss: 0.9108, Validation Accuracy: 64.90%
# Epoch [136/200], Train Loss: 0.8730, Train Accuracy: 67.13%
# Validation Loss: 0.9076, Validation Accuracy: 64.62%
# Epoch [137/200], Train Loss: 0.8694, Train Accuracy: 67.76%
# Validation Loss: 0.9044, Validation Accuracy: 65.74%
# Epoch [138/200], Train Loss: 0.8651, Train Accuracy: 67.06%
# Validation Loss: 0.9024, Validation Accuracy: 66.02%
# Epoch [139/200], Train Loss: 0.8382, Train Accuracy: 69.50%
# Validation Loss: 0.9025, Validation Accuracy: 65.46%
# Epoch [140/200], Train Loss: 0.8507, Train Accuracy: 67.41%
# Validation Loss: 0.9002, Validation Accuracy: 66.02%
# Epoch [141/200], Train Loss: 0.8512, Train Accuracy: 67.97%
# Validation Loss: 0.8918, Validation Accuracy: 66.57%
# Epoch [142/200], Train Loss: 0.8524, Train Accuracy: 67.55%
# Validation Loss: 0.8863, Validation Accuracy: 67.13%
# Epoch [143/200], Train Loss: 0.8551, Train Accuracy: 67.55%
# Validation Loss: 0.8839, Validation Accuracy: 67.13%
# Epoch [144/200], Train Loss: 0.8588, Train Accuracy: 66.92%
# Validation Loss: 0.8828, Validation Accuracy: 67.13%
# Epoch [145/200], Train Loss: 0.8366, Train Accuracy: 67.97%
# Validation Loss: 0.8834, Validation Accuracy: 67.69%
# Epoch [146/200], Train Loss: 0.8351, Train Accuracy: 68.39%
# Validation Loss: 0.8827, Validation Accuracy: 67.69%
# Epoch [147/200], Train Loss: 0.8241, Train Accuracy: 68.60%
# Validation Loss: 0.8784, Validation Accuracy: 68.25%
# Epoch [148/200], Train Loss: 0.8139, Train Accuracy: 71.60%
# Validation Loss: 0.8734, Validation Accuracy: 67.97%
# Epoch [149/200], Train Loss: 0.8095, Train Accuracy: 69.43%
# Validation Loss: 0.8685, Validation Accuracy: 67.69%
# Epoch [150/200], Train Loss: 0.8153, Train Accuracy: 69.78%
# Validation Loss: 0.8634, Validation Accuracy: 67.69%
# Epoch [151/200], Train Loss: 0.8065, Train Accuracy: 70.97%
# Validation Loss: 0.8585, Validation Accuracy: 68.25%
# Epoch [152/200], Train Loss: 0.8233, Train Accuracy: 68.25%
# Validation Loss: 0.8543, Validation Accuracy: 67.97%
# Epoch [153/200], Train Loss: 0.8053, Train Accuracy: 69.85%
# Validation Loss: 0.8520, Validation Accuracy: 67.97%
# Epoch [154/200], Train Loss: 0.8096, Train Accuracy: 69.78%
# Validation Loss: 0.8504, Validation Accuracy: 68.25%
# Epoch [155/200], Train Loss: 0.8026, Train Accuracy: 70.06%
# Validation Loss: 0.8492, Validation Accuracy: 67.69%
# Epoch [156/200], Train Loss: 0.8084, Train Accuracy: 70.76%
# Validation Loss: 0.8445, Validation Accuracy: 68.80%
# Epoch [157/200], Train Loss: 0.7805, Train Accuracy: 70.48%
# Validation Loss: 0.8409, Validation Accuracy: 69.08%
# Epoch [158/200], Train Loss: 0.7891, Train Accuracy: 69.71%
# Validation Loss: 0.8387, Validation Accuracy: 68.52%
# Epoch [159/200], Train Loss: 0.7810, Train Accuracy: 71.53%
# Validation Loss: 0.8372, Validation Accuracy: 68.80%
# Epoch [160/200], Train Loss: 0.7880, Train Accuracy: 70.41%
# Validation Loss: 0.8356, Validation Accuracy: 68.52%
# Epoch [161/200], Train Loss: 0.7920, Train Accuracy: 70.90%
# Validation Loss: 0.8321, Validation Accuracy: 69.08%
# Epoch [162/200], Train Loss: 0.7724, Train Accuracy: 71.04%
# Validation Loss: 0.8267, Validation Accuracy: 69.92%
# Epoch [163/200], Train Loss: 0.7768, Train Accuracy: 71.25%
# Validation Loss: 0.8218, Validation Accuracy: 70.75%
# Epoch [164/200], Train Loss: 0.7733, Train Accuracy: 71.04%
# Validation Loss: 0.8195, Validation Accuracy: 69.92%
# Epoch [165/200], Train Loss: 0.7640, Train Accuracy: 71.67%
# Validation Loss: 0.8211, Validation Accuracy: 69.64%
# Epoch [166/200], Train Loss: 0.7721, Train Accuracy: 70.20%
# Validation Loss: 0.8205, Validation Accuracy: 69.64%
# Epoch [167/200], Train Loss: 0.7652, Train Accuracy: 71.25%
# Validation Loss: 0.8171, Validation Accuracy: 69.36%
# Epoch [168/200], Train Loss: 0.7604, Train Accuracy: 72.02%
# Validation Loss: 0.8150, Validation Accuracy: 68.52%
# Epoch [169/200], Train Loss: 0.7693, Train Accuracy: 70.76%
# Validation Loss: 0.8113, Validation Accuracy: 68.52%
# Epoch [170/200], Train Loss: 0.7474, Train Accuracy: 71.60%
# Validation Loss: 0.8095, Validation Accuracy: 70.19%
# Epoch [171/200], Train Loss: 0.7430, Train Accuracy: 71.11%
# Validation Loss: 0.8060, Validation Accuracy: 69.92%
# Epoch [172/200], Train Loss: 0.7470, Train Accuracy: 72.30%
# Validation Loss: 0.8025, Validation Accuracy: 70.75%
# Epoch [173/200], Train Loss: 0.7403, Train Accuracy: 71.88%
# Validation Loss: 0.8017, Validation Accuracy: 69.92%
# Epoch [174/200], Train Loss: 0.7469, Train Accuracy: 71.39%
# Validation Loss: 0.8023, Validation Accuracy: 69.64%
# Epoch [175/200], Train Loss: 0.7440, Train Accuracy: 73.34%
# Validation Loss: 0.8034, Validation Accuracy: 69.64%
# Epoch [176/200], Train Loss: 0.7413, Train Accuracy: 71.46%
# Validation Loss: 0.7993, Validation Accuracy: 69.64%
# Epoch [177/200], Train Loss: 0.7390, Train Accuracy: 72.02%
# Validation Loss: 0.7929, Validation Accuracy: 70.19%
# Epoch [178/200], Train Loss: 0.7301, Train Accuracy: 72.37%
# Validation Loss: 0.7892, Validation Accuracy: 71.31%
# Epoch [179/200], Train Loss: 0.7206, Train Accuracy: 72.09%
# Validation Loss: 0.7894, Validation Accuracy: 70.47%
# Epoch [180/200], Train Loss: 0.7299, Train Accuracy: 72.37%
# Validation Loss: 0.7885, Validation Accuracy: 71.03%
# Epoch [181/200], Train Loss: 0.7064, Train Accuracy: 73.48%
# Validation Loss: 0.7878, Validation Accuracy: 71.03%
# Epoch [182/200], Train Loss: 0.7357, Train Accuracy: 72.44%
# Validation Loss: 0.7855, Validation Accuracy: 71.31%
# Epoch [183/200], Train Loss: 0.7155, Train Accuracy: 72.16%
# Validation Loss: 0.7825, Validation Accuracy: 72.42%
# Epoch [184/200], Train Loss: 0.7262, Train Accuracy: 73.06%
# Validation Loss: 0.7799, Validation Accuracy: 71.87%
# Epoch [185/200], Train Loss: 0.7106, Train Accuracy: 73.48%
# Validation Loss: 0.7786, Validation Accuracy: 71.87%
# Epoch [186/200], Train Loss: 0.6995, Train Accuracy: 74.18%
# Validation Loss: 0.7765, Validation Accuracy: 72.14%
# Epoch [187/200], Train Loss: 0.7086, Train Accuracy: 72.71%
# Validation Loss: 0.7731, Validation Accuracy: 72.14%
# Epoch [188/200], Train Loss: 0.7178, Train Accuracy: 73.83%
# Validation Loss: 0.7707, Validation Accuracy: 72.70%
# Epoch [189/200], Train Loss: 0.7064, Train Accuracy: 73.41%
# Validation Loss: 0.7690, Validation Accuracy: 72.70%
# Epoch [190/200], Train Loss: 0.6902, Train Accuracy: 74.39%
# Validation Loss: 0.7697, Validation Accuracy: 72.42%
# Epoch [191/200], Train Loss: 0.7068, Train Accuracy: 73.83%
# Validation Loss: 0.7690, Validation Accuracy: 73.26%
# Epoch [192/200], Train Loss: 0.7032, Train Accuracy: 73.13%
# Validation Loss: 0.7678, Validation Accuracy: 72.14%
# Epoch [193/200], Train Loss: 0.6990, Train Accuracy: 74.46%
# Validation Loss: 0.7664, Validation Accuracy: 72.98%
# Epoch [194/200], Train Loss: 0.6951, Train Accuracy: 73.48%
# Validation Loss: 0.7639, Validation Accuracy: 72.42%
# Epoch [195/200], Train Loss: 0.6936, Train Accuracy: 74.88%
# Validation Loss: 0.7629, Validation Accuracy: 72.70%
# Epoch [196/200], Train Loss: 0.6923, Train Accuracy: 73.97%
# Validation Loss: 0.7647, Validation Accuracy: 72.70%
# Epoch [197/200], Train Loss: 0.6769, Train Accuracy: 74.74%
# Validation Loss: 0.7645, Validation Accuracy: 72.42%
# Epoch [198/200], Train Loss: 0.6825, Train Accuracy: 75.02%
# Validation Loss: 0.7578, Validation Accuracy: 72.42%
# Epoch [199/200], Train Loss: 0.6783, Train Accuracy: 74.25%
# Validation Loss: 0.7560, Validation Accuracy: 71.59%
# Epoch [200/200], Train Loss: 0.6841, Train Accuracy: 75.02%
# Validation Loss: 0.7553, Validation Accuracy: 72.70%
# Epoch [201/200], Train Loss: 0.6803, Train Accuracy: 74.39%
# Validation Loss: 0.7589, Validation Accuracy: 71.87%
# Epoch [202/200], Train Loss: 0.6847, Train Accuracy: 73.34%
# Validation Loss: 0.7622, Validation Accuracy: 71.87%
# Epoch [203/200], Train Loss: 0.6558, Train Accuracy: 74.88%
# Validation Loss: 0.7554, Validation Accuracy: 72.14%
# Epoch [204/200], Train Loss: 0.6594, Train Accuracy: 74.81%
# Validation Loss: 0.7485, Validation Accuracy: 73.54%
# Epoch [205/200], Train Loss: 0.6798, Train Accuracy: 74.88%
# Validation Loss: 0.7452, Validation Accuracy: 73.26%
# Epoch [206/200], Train Loss: 0.6780, Train Accuracy: 74.46%
# Validation Loss: 0.7420, Validation Accuracy: 73.26%
# Epoch [207/200], Train Loss: 0.6841, Train Accuracy: 74.04%
# Validation Loss: 0.7431, Validation Accuracy: 74.65%
# Epoch [208/200], Train Loss: 0.6572, Train Accuracy: 76.20%
# Validation Loss: 0.7471, Validation Accuracy: 73.26%
# Epoch [209/200], Train Loss: 0.6678, Train Accuracy: 74.53%
# Validation Loss: 0.7475, Validation Accuracy: 73.26%
# Epoch [210/200], Train Loss: 0.6556, Train Accuracy: 75.58%
# Validation Loss: 0.7442, Validation Accuracy: 73.54%
# Epoch [211/200], Train Loss: 0.6599, Train Accuracy: 75.58%
# Validation Loss: 0.7423, Validation Accuracy: 72.98%
# Epoch [212/200], Train Loss: 0.6700, Train Accuracy: 74.53%
# Validation Loss: 0.7392, Validation Accuracy: 73.82%
# Epoch [213/200], Train Loss: 0.6436, Train Accuracy: 75.79%
# Validation Loss: 0.7392, Validation Accuracy: 73.26%
# Epoch [214/200], Train Loss: 0.6545, Train Accuracy: 75.16%
# Validation Loss: 0.7407, Validation Accuracy: 73.82%
# Epoch [215/200], Train Loss: 0.6468, Train Accuracy: 75.99%
# Validation Loss: 0.7398, Validation Accuracy: 73.82%
# Epoch [216/200], Train Loss: 0.6558, Train Accuracy: 75.92%
# Validation Loss: 0.7411, Validation Accuracy: 72.98%
# Epoch [217/200], Train Loss: 0.6418, Train Accuracy: 76.27%
# Validation Loss: 0.7422, Validation Accuracy: 72.42%
# Epoch [218/200], Train Loss: 0.6349, Train Accuracy: 76.13%
# Validation Loss: 0.7406, Validation Accuracy: 72.98%
# Epoch [219/200], Train Loss: 0.6571, Train Accuracy: 74.74%
# Validation Loss: 0.7374, Validation Accuracy: 73.54%
# Epoch [220/200], Train Loss: 0.6418, Train Accuracy: 76.48%
# Validation Loss: 0.7345, Validation Accuracy: 73.26%
# Epoch [221/200], Train Loss: 0.6283, Train Accuracy: 75.99%
# Validation Loss: 0.7337, Validation Accuracy: 73.54%
# Epoch [222/200], Train Loss: 0.6354, Train Accuracy: 76.90%
# Validation Loss: 0.7354, Validation Accuracy: 72.70%
# Epoch [223/200], Train Loss: 0.6481, Train Accuracy: 76.06%
# Validation Loss: 0.7358, Validation Accuracy: 73.26%
# Epoch [224/200], Train Loss: 0.6449, Train Accuracy: 76.06%
# Validation Loss: 0.7329, Validation Accuracy: 72.98%
# Epoch [225/200], Train Loss: 0.6361, Train Accuracy: 75.99%
# Validation Loss: 0.7316, Validation Accuracy: 72.98%
# Epoch [226/200], Train Loss: 0.6267, Train Accuracy: 76.34%
# Validation Loss: 0.7309, Validation Accuracy: 72.14%
# Epoch [227/200], Train Loss: 0.6297, Train Accuracy: 76.69%
# Validation Loss: 0.7301, Validation Accuracy: 73.82%
# Epoch [228/200], Train Loss: 0.6105, Train Accuracy: 77.74%
# Validation Loss: 0.7285, Validation Accuracy: 73.82%
# Epoch [229/200], Train Loss: 0.6195, Train Accuracy: 75.92%
# Validation Loss: 0.7267, Validation Accuracy: 74.09%
# Epoch [230/200], Train Loss: 0.6293, Train Accuracy: 75.99%
# Validation Loss: 0.7248, Validation Accuracy: 75.21%
# Epoch [231/200], Train Loss: 0.6139, Train Accuracy: 76.48%
# Validation Loss: 0.7220, Validation Accuracy: 75.21%
# Epoch [232/200], Train Loss: 0.6266, Train Accuracy: 76.48%
# Validation Loss: 0.7195, Validation Accuracy: 74.93%
# Epoch [233/200], Train Loss: 0.6201, Train Accuracy: 77.32%
# Validation Loss: 0.7219, Validation Accuracy: 74.09%
# Epoch [234/200], Train Loss: 0.6255, Train Accuracy: 77.25%
# Validation Loss: 0.7280, Validation Accuracy: 73.26%
# Epoch [235/200], Train Loss: 0.6223, Train Accuracy: 76.34%
# Validation Loss: 0.7308, Validation Accuracy: 72.98%
# Epoch [236/200], Train Loss: 0.6256, Train Accuracy: 76.83%
# Validation Loss: 0.7276, Validation Accuracy: 72.70%
# Epoch [237/200], Train Loss: 0.6069, Train Accuracy: 77.25%
# Validation Loss: 0.7209, Validation Accuracy: 74.37%
# Epoch [238/200], Train Loss: 0.6158, Train Accuracy: 77.39%
# Validation Loss: 0.7182, Validation Accuracy: 74.09%
# Epoch [239/200], Train Loss: 0.6164, Train Accuracy: 76.55%
# Validation Loss: 0.7187, Validation Accuracy: 74.37%
# Epoch [240/200], Train Loss: 0.6044, Train Accuracy: 77.67%
# Validation Loss: 0.7231, Validation Accuracy: 73.82%
# Epoch [241/200], Train Loss: 0.6082, Train Accuracy: 78.44%
# Validation Loss: 0.7268, Validation Accuracy: 73.26%
# Epoch [242/200], Train Loss: 0.5899, Train Accuracy: 78.30%
# Validation Loss: 0.7241, Validation Accuracy: 73.26%
# Epoch [243/200], Train Loss: 0.5977, Train Accuracy: 78.37%
# Validation Loss: 0.7201, Validation Accuracy: 74.09%
# Epoch [244/200], Train Loss: 0.6185, Train Accuracy: 76.41%
# Validation Loss: 0.7169, Validation Accuracy: 74.93%
# Epoch [245/200], Train Loss: 0.6197, Train Accuracy: 76.27%
# Validation Loss: 0.7171, Validation Accuracy: 74.37%
# Epoch [246/200], Train Loss: 0.5940, Train Accuracy: 76.90%
# Validation Loss: 0.7200, Validation Accuracy: 73.82%
# Epoch [247/200], Train Loss: 0.6023, Train Accuracy: 77.32%
# Validation Loss: 0.7214, Validation Accuracy: 72.70%
# Epoch [248/200], Train Loss: 0.6003, Train Accuracy: 76.97%
# Validation Loss: 0.7198, Validation Accuracy: 72.70%
# Epoch [249/200], Train Loss: 0.5815, Train Accuracy: 77.81%
# Validation Loss: 0.7168, Validation Accuracy: 73.54%
# Epoch [250/200], Train Loss: 0.6111, Train Accuracy: 76.27%
# Validation Loss: 0.7147, Validation Accuracy: 74.65%
# Epoch [251/200], Train Loss: 0.5960, Train Accuracy: 77.39%
# Validation Loss: 0.7115, Validation Accuracy: 75.21%
# Epoch [252/200], Train Loss: 0.5883, Train Accuracy: 78.79%
# Validation Loss: 0.7106, Validation Accuracy: 74.37%
# Epoch [253/200], Train Loss: 0.5955, Train Accuracy: 77.53%
# Validation Loss: 0.7099, Validation Accuracy: 74.65%
# Epoch [254/200], Train Loss: 0.5867, Train Accuracy: 77.67%
# Validation Loss: 0.7118, Validation Accuracy: 74.37%
# Epoch [255/200], Train Loss: 0.5893, Train Accuracy: 78.09%
# Validation Loss: 0.7143, Validation Accuracy: 72.98%
# Epoch [256/200], Train Loss: 0.6057, Train Accuracy: 77.60%
# Validation Loss: 0.7148, Validation Accuracy: 72.98%
# Epoch [257/200], Train Loss: 0.6089, Train Accuracy: 76.76%
# Validation Loss: 0.7113, Validation Accuracy: 74.09%
# Epoch [258/200], Train Loss: 0.5785, Train Accuracy: 78.02%
# Validation Loss: 0.7079, Validation Accuracy: 74.37%
# Epoch [259/200], Train Loss: 0.5829, Train Accuracy: 79.20%
# Validation Loss: 0.7086, Validation Accuracy: 74.09%
# Epoch [260/200], Train Loss: 0.5812, Train Accuracy: 79.06%
# Validation Loss: 0.7117, Validation Accuracy: 72.70%
# Epoch [261/200], Train Loss: 0.5750, Train Accuracy: 78.23%
# Validation Loss: 0.7146, Validation Accuracy: 72.70%
# Epoch [262/200], Train Loss: 0.5935, Train Accuracy: 78.02%
# Validation Loss: 0.7142, Validation Accuracy: 73.26%
# Epoch [263/200], Train Loss: 0.5725, Train Accuracy: 78.65%
# Validation Loss: 0.7100, Validation Accuracy: 74.65%
# Epoch [264/200], Train Loss: 0.5857, Train Accuracy: 77.60%
# Validation Loss: 0.7092, Validation Accuracy: 75.21%
# Epoch [265/200], Train Loss: 0.5767, Train Accuracy: 77.60%
# Validation Loss: 0.7103, Validation Accuracy: 74.65%
# Epoch [266/200], Train Loss: 0.5924, Train Accuracy: 77.60%
# Validation Loss: 0.7174, Validation Accuracy: 73.54%
# Epoch [267/200], Train Loss: 0.5743, Train Accuracy: 78.44%
# Validation Loss: 0.7225, Validation Accuracy: 72.70%
# Epoch [268/200], Train Loss: 0.5730, Train Accuracy: 78.79%
# Validation Loss: 0.7194, Validation Accuracy: 72.70%
# Epoch [269/200], Train Loss: 0.5821, Train Accuracy: 77.88%
# Validation Loss: 0.7118, Validation Accuracy: 74.09%
# Epoch [270/200], Train Loss: 0.5429, Train Accuracy: 78.44%
# Validation Loss: 0.7086, Validation Accuracy: 75.49%
# Epoch [271/200], Train Loss: 0.5758, Train Accuracy: 79.48%
# Validation Loss: 0.7076, Validation Accuracy: 74.93%
# Epoch [272/200], Train Loss: 0.5761, Train Accuracy: 78.72%
# Validation Loss: 0.7096, Validation Accuracy: 73.82%
# Epoch [273/200], Train Loss: 0.5677, Train Accuracy: 79.27%
# Validation Loss: 0.7116, Validation Accuracy: 73.82%
# Epoch [274/200], Train Loss: 0.5732, Train Accuracy: 78.65%
# Validation Loss: 0.7088, Validation Accuracy: 73.82%
# Epoch [275/200], Train Loss: 0.5476, Train Accuracy: 78.72%
# Validation Loss: 0.7074, Validation Accuracy: 73.82%
# Epoch [276/200], Train Loss: 0.5549, Train Accuracy: 80.11%
# Validation Loss: 0.7080, Validation Accuracy: 74.37%
# Epoch [277/200], Train Loss: 0.5688, Train Accuracy: 77.74%
# Validation Loss: 0.7082, Validation Accuracy: 74.65%
# Epoch [278/200], Train Loss: 0.5630, Train Accuracy: 78.58%
# Validation Loss: 0.7080, Validation Accuracy: 74.65%
# Epoch [279/200], Train Loss: 0.5547, Train Accuracy: 78.86%
# Validation Loss: 0.7102, Validation Accuracy: 74.37%
# Epoch [280/200], Train Loss: 0.5656, Train Accuracy: 79.13%
# Validation Loss: 0.7080, Validation Accuracy: 73.82%
# Epoch [281/200], Train Loss: 0.5387, Train Accuracy: 79.48%
# Validation Loss: 0.7059, Validation Accuracy: 73.54%
# Epoch [282/200], Train Loss: 0.5575, Train Accuracy: 79.48%
# Validation Loss: 0.7029, Validation Accuracy: 73.82%
# Epoch [283/200], Train Loss: 0.5614, Train Accuracy: 79.27%
# Validation Loss: 0.6994, Validation Accuracy: 73.54%
# Epoch [284/200], Train Loss: 0.5532, Train Accuracy: 79.27%
# Validation Loss: 0.6969, Validation Accuracy: 74.65%
# Epoch [285/200], Train Loss: 0.5523, Train Accuracy: 79.34%
# Validation Loss: 0.6974, Validation Accuracy: 74.37%
# Epoch [286/200], Train Loss: 0.5611, Train Accuracy: 78.58%
# Validation Loss: 0.6989, Validation Accuracy: 74.09%
# Epoch [287/200], Train Loss: 0.5557, Train Accuracy: 79.48%
# Validation Loss: 0.7040, Validation Accuracy: 73.26%
# Epoch [288/200], Train Loss: 0.5557, Train Accuracy: 79.06%
# Validation Loss: 0.7048, Validation Accuracy: 73.26%
# Epoch [289/200], Train Loss: 0.5554, Train Accuracy: 79.69%
# Validation Loss: 0.7034, Validation Accuracy: 73.26%
# Epoch [290/200], Train Loss: 0.5586, Train Accuracy: 79.27%
# Validation Loss: 0.7011, Validation Accuracy: 74.37%
# Epoch [291/200], Train Loss: 0.5373, Train Accuracy: 80.11%
# Validation Loss: 0.6983, Validation Accuracy: 74.65%
# Epoch [292/200], Train Loss: 0.5433, Train Accuracy: 80.11%
# Validation Loss: 0.6978, Validation Accuracy: 74.65%
# Epoch [293/200], Train Loss: 0.5415, Train Accuracy: 80.11%
# Validation Loss: 0.7039, Validation Accuracy: 73.54%
# Epoch [294/200], Train Loss: 0.5496, Train Accuracy: 80.04%
# Validation Loss: 0.7084, Validation Accuracy: 72.98%
# Epoch [295/200], Train Loss: 0.5333, Train Accuracy: 79.76%
# Validation Loss: 0.7079, Validation Accuracy: 72.42%
# Epoch [296/200], Train Loss: 0.5389, Train Accuracy: 79.55%
# Validation Loss: 0.7058, Validation Accuracy: 72.98%
# Epoch [297/200], Train Loss: 0.5424, Train Accuracy: 79.20%
# Validation Loss: 0.7047, Validation Accuracy: 73.82%
# Epoch [298/200], Train Loss: 0.5297, Train Accuracy: 80.67%
# Validation Loss: 0.7034, Validation Accuracy: 74.09%
# Epoch [299/200], Train Loss: 0.5214, Train Accuracy: 80.53%
# Validation Loss: 0.7018, Validation Accuracy: 74.65%
# Epoch [300/200], Train Loss: 0.5462, Train Accuracy: 79.41%
# Validation Loss: 0.7030, Validation Accuracy: 73.54%
# Epoch [301/200], Train Loss: 0.5442, Train Accuracy: 80.39%
# Validation Loss: 0.7045, Validation Accuracy: 73.54%
# Epoch [302/200], Train Loss: 0.5373, Train Accuracy: 79.90%
# Validation Loss: 0.7015, Validation Accuracy: 73.82%
# Epoch [303/200], Train Loss: 0.5486, Train Accuracy: 79.62%
# Validation Loss: 0.6969, Validation Accuracy: 74.37%
# Epoch [304/200], Train Loss: 0.5326, Train Accuracy: 79.55%
# Validation Loss: 0.6956, Validation Accuracy: 73.82%
# Epoch [305/200], Train Loss: 0.5417, Train Accuracy: 80.39%
# Validation Loss: 0.6975, Validation Accuracy: 72.98%
# Epoch [306/200], Train Loss: 0.5287, Train Accuracy: 81.02%
# Validation Loss: 0.6977, Validation Accuracy: 73.54%
# Epoch [307/200], Train Loss: 0.5380, Train Accuracy: 80.04%
# Validation Loss: 0.6951, Validation Accuracy: 74.93%
# Epoch [308/200], Train Loss: 0.5319, Train Accuracy: 80.60%
# Validation Loss: 0.6954, Validation Accuracy: 75.21%
# Epoch [309/200], Train Loss: 0.5162, Train Accuracy: 81.30%
# Validation Loss: 0.6960, Validation Accuracy: 74.65%
# Epoch [310/200], Train Loss: 0.5239, Train Accuracy: 80.32%
# Validation Loss: 0.6957, Validation Accuracy: 74.65%
# Epoch [311/200], Train Loss: 0.5203, Train Accuracy: 80.60%
# Validation Loss: 0.6946, Validation Accuracy: 74.37%
# Epoch [312/200], Train Loss: 0.5173, Train Accuracy: 80.67%
# Validation Loss: 0.6965, Validation Accuracy: 74.65%
# Epoch [313/200], Train Loss: 0.5323, Train Accuracy: 80.32%
# Validation Loss: 0.6962, Validation Accuracy: 73.54%
# Epoch [314/200], Train Loss: 0.5232, Train Accuracy: 81.02%
# Validation Loss: 0.6944, Validation Accuracy: 72.70%
# Epoch [315/200], Train Loss: 0.5324, Train Accuracy: 79.83%
# Validation Loss: 0.6948, Validation Accuracy: 74.09%
# Epoch [316/200], Train Loss: 0.5186, Train Accuracy: 81.23%
# Validation Loss: 0.6956, Validation Accuracy: 73.82%
# Epoch [317/200], Train Loss: 0.5228, Train Accuracy: 80.11%
# Validation Loss: 0.6963, Validation Accuracy: 74.09%
# Epoch [318/200], Train Loss: 0.5095, Train Accuracy: 80.88%
# Validation Loss: 0.6974, Validation Accuracy: 73.82%
# Epoch [319/200], Train Loss: 0.5304, Train Accuracy: 80.60%
# Validation Loss: 0.6972, Validation Accuracy: 73.26%
# Epoch [320/200], Train Loss: 0.5274, Train Accuracy: 80.67%
# Validation Loss: 0.6973, Validation Accuracy: 72.98%
# Epoch [321/200], Train Loss: 0.5011, Train Accuracy: 82.21%
# Validation Loss: 0.6985, Validation Accuracy: 73.26%
# Epoch [322/200], Train Loss: 0.5123, Train Accuracy: 81.93%
# Validation Loss: 0.6964, Validation Accuracy: 73.82%
# Epoch [323/200], Train Loss: 0.5090, Train Accuracy: 80.95%
# Validation Loss: 0.6932, Validation Accuracy: 74.65%
# Epoch [324/200], Train Loss: 0.5151, Train Accuracy: 81.02%
# Validation Loss: 0.6912, Validation Accuracy: 75.21%
# Epoch [325/200], Train Loss: 0.5103, Train Accuracy: 81.16%
# Validation Loss: 0.6911, Validation Accuracy: 75.77%
# Epoch [326/200], Train Loss: 0.4993, Train Accuracy: 81.30%
# Validation Loss: 0.6913, Validation Accuracy: 75.21%
# Epoch [327/200], Train Loss: 0.5182, Train Accuracy: 79.83%
# Validation Loss: 0.6941, Validation Accuracy: 74.09%
# Epoch [328/200], Train Loss: 0.5042, Train Accuracy: 81.23%
# Validation Loss: 0.6949, Validation Accuracy: 74.09%
# Epoch [329/200], Train Loss: 0.5325, Train Accuracy: 81.30%
# Validation Loss: 0.6922, Validation Accuracy: 74.37%
# Epoch [330/200], Train Loss: 0.5068, Train Accuracy: 82.14%
# Validation Loss: 0.6926, Validation Accuracy: 74.37%
# Epoch [331/200], Train Loss: 0.5135, Train Accuracy: 81.44%
# Validation Loss: 0.6931, Validation Accuracy: 74.37%
# Epoch [332/200], Train Loss: 0.5135, Train Accuracy: 80.95%
# Validation Loss: 0.6971, Validation Accuracy: 73.82%
# Epoch [333/200], Train Loss: 0.5083, Train Accuracy: 81.58%
# Validation Loss: 0.7025, Validation Accuracy: 73.26%
# Epoch [334/200], Train Loss: 0.5061, Train Accuracy: 82.41%
# Validation Loss: 0.6995, Validation Accuracy: 73.54%
# Epoch [335/200], Train Loss: 0.5051, Train Accuracy: 80.74%
# Validation Loss: 0.6936, Validation Accuracy: 75.21%
# Epoch [336/200], Train Loss: 0.4981, Train Accuracy: 83.46%
# Validation Loss: 0.6922, Validation Accuracy: 74.65%
# Epoch [337/200], Train Loss: 0.4881, Train Accuracy: 81.02%
# Validation Loss: 0.6953, Validation Accuracy: 73.26%
# Epoch [338/200], Train Loss: 0.5035, Train Accuracy: 81.79%
# Validation Loss: 0.7001, Validation Accuracy: 72.70%
# Epoch [339/200], Train Loss: 0.4856, Train Accuracy: 81.16%
# Validation Loss: 0.7035, Validation Accuracy: 73.26%
# Epoch [340/200], Train Loss: 0.4889, Train Accuracy: 81.44%
# Validation Loss: 0.7001, Validation Accuracy: 75.21%
# Epoch [341/200], Train Loss: 0.5062, Train Accuracy: 81.72%
# Validation Loss: 0.6962, Validation Accuracy: 74.65%
# Epoch [342/200], Train Loss: 0.4983, Train Accuracy: 81.02%
# Validation Loss: 0.6983, Validation Accuracy: 74.09%
# Epoch [343/200], Train Loss: 0.5001, Train Accuracy: 81.65%
# Validation Loss: 0.7027, Validation Accuracy: 73.54%
# Epoch [344/200], Train Loss: 0.4783, Train Accuracy: 83.04%
# Validation Loss: 0.7000, Validation Accuracy: 74.93%
# Epoch [345/200], Train Loss: 0.4900, Train Accuracy: 81.93%
# Validation Loss: 0.6947, Validation Accuracy: 75.49%
# Early stopping at epoch 345. Best Validation Loss: 0.6911

# %% [markdown]
# **Visualize the Training Results**

# %%
# Plot loss and accuracy curves
def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)
    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Accuracy")
    plt.plot(epochs, history["val_acc"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    plt.show()

plot_history(history)

# Classification report
val_pred = val_predicted.cpu().numpy()
val_true = y_val_tensor.cpu().numpy()
print("\nClassification Report:\n", classification_report(val_true, val_pred))

# Confusion matrix
cm = confusion_matrix(val_true, val_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=range(9), yticklabels=range(9))
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# # ROC and AUC
# if len(set(val_true)) == 2:  # Binary classification
#     val_probs = torch.softmax(val_outputs, dim=1)[:, 1].cpu().numpy()
#     auc = roc_auc_score(val_true, val_probs)
#     fpr, tpr, _ = roc_curve(val_true, val_probs)

#     plt.figure(figsize=(8, 6))
#     plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
#     plt.plot([0, 1], [0, 1], "--", color="gray")
#     plt.title("ROC Curve")
#     plt.xlabel("False Positive Rate")
#     plt.ylabel("True Positive Rate")
#     plt.legend()
#     plt.show()
# else:
#     print("ROC curve and AUC are only applicable for binary classification.")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        57
#            1       0.67      0.69      0.68        52
#            3       0.80      0.73      0.76        55
#            4       0.72      0.66      0.69        50
#            5       0.78      0.81      0.80        43
#            7       0.72      0.84      0.78        50
#            8       0.80      0.69      0.74        52
#
#     accuracy                           0.75       359
#    macro avg       0.76      0.76      0.75       359
# weighted avg       0.76      0.75      0.75       359
# ROC curve and AUC are only applicable for binary classification.

# %% [markdown]
# #### **Proposed (LSTM + CNN) Model**

# %% [markdown]
# **Model Definition**

# %%
# Define the model
class LSTM_CNN_Model(nn.Module):
    def __init__(self, input_dim, hidden_dim, lstm_layers, cnn_channels, num_classes):
        super(LSTM_CNN_Model, self).__init__()

        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.conv1 = nn.Conv1d(in_channels=hidden_dim * 2, out_channels=cnn_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(cnn_channels, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x, (hn, cn) = self.lstm(x)
        x = x.permute(0, 2, 1)
        x = self.relu(self.conv1(x))
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# **Training ...**

# %%
# Initialize model, criterion, and optimizer
model = LSTM_CNN_Model(input_dim=8, hidden_dim=64, lstm_layers=2, cnn_channels=32, num_classes=9)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Track history
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

# Early stopping parameters
early_stop_patience = 20
best_val_loss = float('inf')
patience_counter = 0

# Training loop
for epoch in range(500):
    model.train()
    optimizer.zero_grad()

    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()

    _, predicted = torch.max(outputs, 1)
    correct = (predicted == y_train_tensor).sum().item()
    train_accuracy = correct / y_train_tensor.size(0) * 100

    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)
        _, val_predicted = torch.max(val_outputs, 1)
        val_correct = (val_predicted == y_val_tensor).sum().item()
        val_accuracy = val_correct / y_val_tensor.size(0) * 100

    # Store history
    history["train_loss"].append(loss.item())
    history["val_loss"].append(val_loss.item())
    history["train_acc"].append(train_accuracy)
    history["val_acc"].append(val_accuracy)

    # Verbose output
    print(f"Epoch [{epoch+1}/200], Train Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss.item():.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss:.4f}")
        break
# Out:
# Epoch [1/200], Train Loss: 2.2203, Train Accuracy: 1.67%
# Validation Loss: 2.2114, Validation Accuracy: 0.00%
# Epoch [2/200], Train Loss: 2.2152, Train Accuracy: 3.42%
# Validation Loss: 2.2071, Validation Accuracy: 0.00%
# Epoch [3/200], Train Loss: 2.2097, Train Accuracy: 4.95%
# Validation Loss: 2.2029, Validation Accuracy: 0.00%
# Epoch [4/200], Train Loss: 2.2054, Train Accuracy: 6.35%
# Validation Loss: 2.1987, Validation Accuracy: 11.98%
# Epoch [5/200], Train Loss: 2.2018, Train Accuracy: 9.00%
# Validation Loss: 2.1945, Validation Accuracy: 15.88%
# Epoch [6/200], Train Loss: 2.1984, Train Accuracy: 9.77%
# Validation Loss: 2.1903, Validation Accuracy: 15.88%
# Epoch [7/200], Train Loss: 2.1943, Train Accuracy: 12.21%
# Validation Loss: 2.1860, Validation Accuracy: 15.88%
# Epoch [8/200], Train Loss: 2.1904, Train Accuracy: 12.07%
# Validation Loss: 2.1816, Validation Accuracy: 15.88%
# Epoch [9/200], Train Loss: 2.1859, Train Accuracy: 13.40%
# Validation Loss: 2.1772, Validation Accuracy: 15.88%
# Epoch [10/200], Train Loss: 2.1813, Train Accuracy: 13.19%
# Validation Loss: 2.1726, Validation Accuracy: 15.88%
# Epoch [11/200], Train Loss: 2.1767, Train Accuracy: 14.79%
# Validation Loss: 2.1679, Validation Accuracy: 15.88%
# Epoch [12/200], Train Loss: 2.1723, Train Accuracy: 14.03%
# Validation Loss: 2.1631, Validation Accuracy: 15.88%
# Epoch [13/200], Train Loss: 2.1653, Train Accuracy: 14.17%
# Validation Loss: 2.1582, Validation Accuracy: 15.88%
# Epoch [14/200], Train Loss: 2.1617, Train Accuracy: 14.03%
# Validation Loss: 2.1530, Validation Accuracy: 15.88%
# Epoch [15/200], Train Loss: 2.1563, Train Accuracy: 14.58%
# Validation Loss: 2.1477, Validation Accuracy: 15.88%
# Epoch [16/200], Train Loss: 2.1504, Train Accuracy: 13.75%
# Validation Loss: 2.1421, Validation Accuracy: 15.88%
# Epoch [17/200], Train Loss: 2.1431, Train Accuracy: 17.38%
# Validation Loss: 2.1362, Validation Accuracy: 15.88%
# Epoch [18/200], Train Loss: 2.1401, Train Accuracy: 15.21%
# Validation Loss: 2.1301, Validation Accuracy: 15.88%
# Epoch [19/200], Train Loss: 2.1319, Train Accuracy: 17.73%
# Validation Loss: 2.1236, Validation Accuracy: 16.16%
# Epoch [20/200], Train Loss: 2.1259, Train Accuracy: 15.84%
# Validation Loss: 2.1167, Validation Accuracy: 16.99%
# Epoch [21/200], Train Loss: 2.1189, Train Accuracy: 16.26%
# Validation Loss: 2.1093, Validation Accuracy: 19.22%
# Epoch [22/200], Train Loss: 2.1121, Train Accuracy: 17.45%
# Validation Loss: 2.1014, Validation Accuracy: 20.33%
# Epoch [23/200], Train Loss: 2.1027, Train Accuracy: 18.35%
# Validation Loss: 2.0929, Validation Accuracy: 22.28%
# Epoch [24/200], Train Loss: 2.0939, Train Accuracy: 18.91%
# Validation Loss: 2.0839, Validation Accuracy: 24.23%
# Epoch [25/200], Train Loss: 2.0866, Train Accuracy: 17.93%
# Validation Loss: 2.0741, Validation Accuracy: 24.51%
# Epoch [26/200], Train Loss: 2.0735, Train Accuracy: 21.70%
# Validation Loss: 2.0636, Validation Accuracy: 26.46%
# Epoch [27/200], Train Loss: 2.0673, Train Accuracy: 19.33%
# Validation Loss: 2.0523, Validation Accuracy: 25.35%
# Epoch [28/200], Train Loss: 2.0565, Train Accuracy: 18.98%
# Validation Loss: 2.0402, Validation Accuracy: 24.79%
# Epoch [29/200], Train Loss: 2.0424, Train Accuracy: 19.75%
# Validation Loss: 2.0272, Validation Accuracy: 24.23%
# Epoch [30/200], Train Loss: 2.0319, Train Accuracy: 19.40%
# Validation Loss: 2.0133, Validation Accuracy: 24.51%
# Epoch [31/200], Train Loss: 2.0124, Train Accuracy: 22.61%
# Validation Loss: 1.9985, Validation Accuracy: 23.68%
# Epoch [32/200], Train Loss: 1.9970, Train Accuracy: 22.33%
# Validation Loss: 1.9828, Validation Accuracy: 20.89%
# Epoch [33/200], Train Loss: 1.9834, Train Accuracy: 22.05%
# Validation Loss: 1.9662, Validation Accuracy: 21.73%
# Epoch [34/200], Train Loss: 1.9630, Train Accuracy: 24.98%
# Validation Loss: 1.9489, Validation Accuracy: 21.45%
# Epoch [35/200], Train Loss: 1.9465, Train Accuracy: 24.49%
# Validation Loss: 1.9310, Validation Accuracy: 21.45%
# Epoch [36/200], Train Loss: 1.9303, Train Accuracy: 24.21%
# Validation Loss: 1.9126, Validation Accuracy: 21.73%
# Epoch [37/200], Train Loss: 1.9135, Train Accuracy: 22.68%
# Validation Loss: 1.8941, Validation Accuracy: 21.17%
# Epoch [38/200], Train Loss: 1.9019, Train Accuracy: 23.17%
# Validation Loss: 1.8757, Validation Accuracy: 21.17%
# Epoch [39/200], Train Loss: 1.8807, Train Accuracy: 22.33%
# Validation Loss: 1.8574, Validation Accuracy: 21.17%
# Epoch [40/200], Train Loss: 1.8617, Train Accuracy: 22.54%
# Validation Loss: 1.8395, Validation Accuracy: 21.45%
# Epoch [41/200], Train Loss: 1.8434, Train Accuracy: 24.28%
# Validation Loss: 1.8220, Validation Accuracy: 21.45%
# Epoch [42/200], Train Loss: 1.8308, Train Accuracy: 23.03%
# Validation Loss: 1.8053, Validation Accuracy: 21.17%
# Epoch [43/200], Train Loss: 1.8135, Train Accuracy: 23.80%
# Validation Loss: 1.7893, Validation Accuracy: 21.17%
# Epoch [44/200], Train Loss: 1.7957, Train Accuracy: 23.52%
# Validation Loss: 1.7742, Validation Accuracy: 23.96%
# Epoch [45/200], Train Loss: 1.7868, Train Accuracy: 24.21%
# Validation Loss: 1.7603, Validation Accuracy: 24.51%
# Epoch [46/200], Train Loss: 1.7662, Train Accuracy: 24.35%
# Validation Loss: 1.7476, Validation Accuracy: 24.51%
# Epoch [47/200], Train Loss: 1.7648, Train Accuracy: 22.54%
# Validation Loss: 1.7361, Validation Accuracy: 24.51%
# Epoch [48/200], Train Loss: 1.7388, Train Accuracy: 25.33%
# Validation Loss: 1.7260, Validation Accuracy: 24.79%
# Epoch [49/200], Train Loss: 1.7410, Train Accuracy: 22.26%
# Validation Loss: 1.7171, Validation Accuracy: 24.51%
# Epoch [50/200], Train Loss: 1.7191, Train Accuracy: 26.66%
# Validation Loss: 1.7091, Validation Accuracy: 24.23%
# Epoch [51/200], Train Loss: 1.7162, Train Accuracy: 23.94%
# Validation Loss: 1.7020, Validation Accuracy: 24.23%
# Epoch [52/200], Train Loss: 1.7265, Train Accuracy: 24.77%
# Validation Loss: 1.6954, Validation Accuracy: 23.40%
# Epoch [53/200], Train Loss: 1.7168, Train Accuracy: 22.47%
# Validation Loss: 1.6891, Validation Accuracy: 23.40%
# Epoch [54/200], Train Loss: 1.6965, Train Accuracy: 23.73%
# Validation Loss: 1.6832, Validation Accuracy: 22.56%
# Epoch [55/200], Train Loss: 1.6903, Train Accuracy: 23.24%
# Validation Loss: 1.6774, Validation Accuracy: 23.40%
# Epoch [56/200], Train Loss: 1.6646, Train Accuracy: 25.47%
# Validation Loss: 1.6717, Validation Accuracy: 21.73%
# Epoch [57/200], Train Loss: 1.6857, Train Accuracy: 24.49%
# Validation Loss: 1.6659, Validation Accuracy: 22.28%
# Epoch [58/200], Train Loss: 1.6690, Train Accuracy: 24.91%
# Validation Loss: 1.6601, Validation Accuracy: 22.84%
# Epoch [59/200], Train Loss: 1.6662, Train Accuracy: 25.82%
# Validation Loss: 1.6544, Validation Accuracy: 23.68%
# Epoch [60/200], Train Loss: 1.6449, Train Accuracy: 26.45%
# Validation Loss: 1.6484, Validation Accuracy: 24.23%
# Epoch [61/200], Train Loss: 1.6241, Train Accuracy: 26.66%
# Validation Loss: 1.6424, Validation Accuracy: 25.35%
# Epoch [62/200], Train Loss: 1.6203, Train Accuracy: 29.17%
# Validation Loss: 1.6363, Validation Accuracy: 25.91%
# Epoch [63/200], Train Loss: 1.6296, Train Accuracy: 27.15%
# Validation Loss: 1.6302, Validation Accuracy: 25.63%
# Epoch [64/200], Train Loss: 1.6088, Train Accuracy: 27.70%
# Validation Loss: 1.6238, Validation Accuracy: 25.35%
# Epoch [65/200], Train Loss: 1.5884, Train Accuracy: 28.96%
# Validation Loss: 1.6174, Validation Accuracy: 25.91%
# Epoch [66/200], Train Loss: 1.5848, Train Accuracy: 29.38%
# Validation Loss: 1.6113, Validation Accuracy: 25.91%
# Epoch [67/200], Train Loss: 1.5814, Train Accuracy: 30.64%
# Validation Loss: 1.6053, Validation Accuracy: 26.18%
# Epoch [68/200], Train Loss: 1.5720, Train Accuracy: 31.47%
# Validation Loss: 1.5996, Validation Accuracy: 26.18%
# Epoch [69/200], Train Loss: 1.5761, Train Accuracy: 28.89%
# Validation Loss: 1.5941, Validation Accuracy: 27.02%
# Epoch [70/200], Train Loss: 1.5528, Train Accuracy: 31.33%
# Validation Loss: 1.5889, Validation Accuracy: 28.69%
# Epoch [71/200], Train Loss: 1.5393, Train Accuracy: 30.77%
# Validation Loss: 1.5841, Validation Accuracy: 29.81%
# Epoch [72/200], Train Loss: 1.5448, Train Accuracy: 31.40%
# Validation Loss: 1.5796, Validation Accuracy: 30.92%
# Epoch [73/200], Train Loss: 1.5354, Train Accuracy: 31.75%
# Validation Loss: 1.5756, Validation Accuracy: 30.64%
# Epoch [74/200], Train Loss: 1.5333, Train Accuracy: 31.89%
# Validation Loss: 1.5718, Validation Accuracy: 31.20%
# Epoch [75/200], Train Loss: 1.5099, Train Accuracy: 34.47%
# Validation Loss: 1.5680, Validation Accuracy: 30.36%
# Epoch [76/200], Train Loss: 1.5207, Train Accuracy: 31.82%
# Validation Loss: 1.5643, Validation Accuracy: 30.36%
# Epoch [77/200], Train Loss: 1.5105, Train Accuracy: 33.91%
# Validation Loss: 1.5605, Validation Accuracy: 30.36%
# Epoch [78/200], Train Loss: 1.5052, Train Accuracy: 32.52%
# Validation Loss: 1.5570, Validation Accuracy: 29.81%
# Epoch [79/200], Train Loss: 1.5044, Train Accuracy: 35.80%
# Validation Loss: 1.5533, Validation Accuracy: 30.08%
# Epoch [80/200], Train Loss: 1.4896, Train Accuracy: 34.61%
# Validation Loss: 1.5497, Validation Accuracy: 30.08%
# Epoch [81/200], Train Loss: 1.4863, Train Accuracy: 34.75%
# Validation Loss: 1.5460, Validation Accuracy: 30.36%
# Epoch [82/200], Train Loss: 1.5018, Train Accuracy: 33.15%
# Validation Loss: 1.5421, Validation Accuracy: 30.36%
# Epoch [83/200], Train Loss: 1.4867, Train Accuracy: 33.15%
# Validation Loss: 1.5379, Validation Accuracy: 30.92%
# Epoch [84/200], Train Loss: 1.4838, Train Accuracy: 35.31%
# Validation Loss: 1.5335, Validation Accuracy: 31.20%
# Epoch [85/200], Train Loss: 1.4683, Train Accuracy: 36.01%
# Validation Loss: 1.5293, Validation Accuracy: 30.64%
# Epoch [86/200], Train Loss: 1.4627, Train Accuracy: 36.71%
# Validation Loss: 1.5249, Validation Accuracy: 31.20%
# Epoch [87/200], Train Loss: 1.4636, Train Accuracy: 36.57%
# Validation Loss: 1.5207, Validation Accuracy: 31.48%
# Epoch [88/200], Train Loss: 1.4600, Train Accuracy: 35.52%
# Validation Loss: 1.5164, Validation Accuracy: 31.48%
# Epoch [89/200], Train Loss: 1.4685, Train Accuracy: 35.10%
# Validation Loss: 1.5121, Validation Accuracy: 31.75%
# Epoch [90/200], Train Loss: 1.4624, Train Accuracy: 34.75%
# Validation Loss: 1.5079, Validation Accuracy: 31.75%
# Epoch [91/200], Train Loss: 1.4550, Train Accuracy: 35.59%
# Validation Loss: 1.5035, Validation Accuracy: 32.03%
# Epoch [92/200], Train Loss: 1.4506, Train Accuracy: 36.78%
# Validation Loss: 1.4995, Validation Accuracy: 32.87%
# Epoch [93/200], Train Loss: 1.4452, Train Accuracy: 36.78%
# Validation Loss: 1.4956, Validation Accuracy: 33.43%
# Epoch [94/200], Train Loss: 1.4465, Train Accuracy: 36.57%
# Validation Loss: 1.4920, Validation Accuracy: 33.70%
# Epoch [95/200], Train Loss: 1.4283, Train Accuracy: 37.68%
# Validation Loss: 1.4886, Validation Accuracy: 33.43%
# Epoch [96/200], Train Loss: 1.4458, Train Accuracy: 37.54%
# Validation Loss: 1.4859, Validation Accuracy: 34.26%
# Epoch [97/200], Train Loss: 1.4326, Train Accuracy: 37.33%
# Validation Loss: 1.4829, Validation Accuracy: 33.98%
# Epoch [98/200], Train Loss: 1.4364, Train Accuracy: 37.26%
# Validation Loss: 1.4798, Validation Accuracy: 34.82%
# Epoch [99/200], Train Loss: 1.4323, Train Accuracy: 37.82%
# Validation Loss: 1.4768, Validation Accuracy: 34.54%
# Epoch [100/200], Train Loss: 1.4166, Train Accuracy: 39.01%
# Validation Loss: 1.4740, Validation Accuracy: 34.54%
# Epoch [101/200], Train Loss: 1.4305, Train Accuracy: 37.96%
# Validation Loss: 1.4717, Validation Accuracy: 34.82%
# Epoch [102/200], Train Loss: 1.4174, Train Accuracy: 38.73%
# Validation Loss: 1.4693, Validation Accuracy: 35.38%
# Epoch [103/200], Train Loss: 1.4191, Train Accuracy: 39.71%
# Validation Loss: 1.4669, Validation Accuracy: 35.38%
# Epoch [104/200], Train Loss: 1.4082, Train Accuracy: 40.40%
# Validation Loss: 1.4641, Validation Accuracy: 36.21%
# Epoch [105/200], Train Loss: 1.4129, Train Accuracy: 39.15%
# Validation Loss: 1.4612, Validation Accuracy: 36.21%
# Epoch [106/200], Train Loss: 1.4044, Train Accuracy: 41.03%
# Validation Loss: 1.4582, Validation Accuracy: 35.93%
# Epoch [107/200], Train Loss: 1.3962, Train Accuracy: 41.52%
# Validation Loss: 1.4553, Validation Accuracy: 36.49%
# Epoch [108/200], Train Loss: 1.3895, Train Accuracy: 40.68%
# Validation Loss: 1.4529, Validation Accuracy: 36.49%
# Epoch [109/200], Train Loss: 1.3923, Train Accuracy: 41.59%
# Validation Loss: 1.4507, Validation Accuracy: 36.49%
# Epoch [110/200], Train Loss: 1.4061, Train Accuracy: 41.73%
# Validation Loss: 1.4483, Validation Accuracy: 37.05%
# Epoch [111/200], Train Loss: 1.3847, Train Accuracy: 42.64%
# Validation Loss: 1.4459, Validation Accuracy: 37.88%
# Epoch [112/200], Train Loss: 1.3944, Train Accuracy: 41.59%
# Validation Loss: 1.4434, Validation Accuracy: 37.88%
# Epoch [113/200], Train Loss: 1.3874, Train Accuracy: 41.66%
# Validation Loss: 1.4410, Validation Accuracy: 38.16%
# Epoch [114/200], Train Loss: 1.3809, Train Accuracy: 42.99%
# Validation Loss: 1.4387, Validation Accuracy: 38.44%
# Epoch [115/200], Train Loss: 1.3865, Train Accuracy: 42.50%
# Validation Loss: 1.4364, Validation Accuracy: 37.88%
# Epoch [116/200], Train Loss: 1.3843, Train Accuracy: 42.64%
# Validation Loss: 1.4343, Validation Accuracy: 39.55%
# Epoch [117/200], Train Loss: 1.3847, Train Accuracy: 42.92%
# Validation Loss: 1.4318, Validation Accuracy: 40.11%
# Epoch [118/200], Train Loss: 1.3600, Train Accuracy: 43.82%
# Validation Loss: 1.4299, Validation Accuracy: 40.39%
# Epoch [119/200], Train Loss: 1.3707, Train Accuracy: 43.27%
# Validation Loss: 1.4278, Validation Accuracy: 40.95%
# Epoch [120/200], Train Loss: 1.3802, Train Accuracy: 41.94%
# Validation Loss: 1.4259, Validation Accuracy: 40.39%
# Epoch [121/200], Train Loss: 1.3676, Train Accuracy: 42.15%
# Validation Loss: 1.4237, Validation Accuracy: 39.00%
# Epoch [122/200], Train Loss: 1.3581, Train Accuracy: 44.66%
# Validation Loss: 1.4221, Validation Accuracy: 37.88%
# Epoch [123/200], Train Loss: 1.3572, Train Accuracy: 43.41%
# Validation Loss: 1.4214, Validation Accuracy: 37.88%
# Epoch [124/200], Train Loss: 1.3563, Train Accuracy: 43.61%
# Validation Loss: 1.4211, Validation Accuracy: 39.00%
# Epoch [125/200], Train Loss: 1.3574, Train Accuracy: 45.15%
# Validation Loss: 1.4201, Validation Accuracy: 39.83%
# Epoch [126/200], Train Loss: 1.3431, Train Accuracy: 44.87%
# Validation Loss: 1.4179, Validation Accuracy: 39.55%
# Epoch [127/200], Train Loss: 1.3397, Train Accuracy: 44.66%
# Validation Loss: 1.4151, Validation Accuracy: 38.44%
# Epoch [128/200], Train Loss: 1.3306, Train Accuracy: 44.45%
# Validation Loss: 1.4123, Validation Accuracy: 37.60%
# Epoch [129/200], Train Loss: 1.3341, Train Accuracy: 44.94%
# Validation Loss: 1.4091, Validation Accuracy: 38.16%
# Epoch [130/200], Train Loss: 1.3191, Train Accuracy: 45.71%
# Validation Loss: 1.4071, Validation Accuracy: 38.16%
# Epoch [131/200], Train Loss: 1.3360, Train Accuracy: 44.66%
# Validation Loss: 1.4055, Validation Accuracy: 38.16%
# Epoch [132/200], Train Loss: 1.3212, Train Accuracy: 45.85%
# Validation Loss: 1.4053, Validation Accuracy: 37.88%
# Epoch [133/200], Train Loss: 1.3241, Train Accuracy: 44.45%
# Validation Loss: 1.4046, Validation Accuracy: 38.16%
# Epoch [134/200], Train Loss: 1.3276, Train Accuracy: 45.85%
# Validation Loss: 1.4028, Validation Accuracy: 37.60%
# Epoch [135/200], Train Loss: 1.3243, Train Accuracy: 44.87%
# Validation Loss: 1.4005, Validation Accuracy: 37.33%
# Epoch [136/200], Train Loss: 1.3110, Train Accuracy: 45.36%
# Validation Loss: 1.3988, Validation Accuracy: 37.60%
# Epoch [137/200], Train Loss: 1.2986, Train Accuracy: 45.36%
# Validation Loss: 1.3972, Validation Accuracy: 37.88%
# Epoch [138/200], Train Loss: 1.3082, Train Accuracy: 45.92%
# Validation Loss: 1.3972, Validation Accuracy: 37.60%
# Epoch [139/200], Train Loss: 1.3035, Train Accuracy: 46.06%
# Validation Loss: 1.3983, Validation Accuracy: 37.33%
# Epoch [140/200], Train Loss: 1.3160, Train Accuracy: 45.85%
# Validation Loss: 1.3985, Validation Accuracy: 37.33%
# Epoch [141/200], Train Loss: 1.3044, Train Accuracy: 46.62%
# Validation Loss: 1.3966, Validation Accuracy: 37.88%
# Epoch [142/200], Train Loss: 1.2988, Train Accuracy: 47.66%
# Validation Loss: 1.3933, Validation Accuracy: 37.60%
# Epoch [143/200], Train Loss: 1.2924, Train Accuracy: 46.13%
# Validation Loss: 1.3893, Validation Accuracy: 37.60%
# Epoch [144/200], Train Loss: 1.2838, Train Accuracy: 46.89%
# Validation Loss: 1.3864, Validation Accuracy: 37.05%
# Epoch [145/200], Train Loss: 1.2845, Train Accuracy: 46.20%
# Validation Loss: 1.3844, Validation Accuracy: 37.88%
# Epoch [146/200], Train Loss: 1.2789, Train Accuracy: 46.62%
# Validation Loss: 1.3816, Validation Accuracy: 37.88%
# Epoch [147/200], Train Loss: 1.2755, Train Accuracy: 46.76%
# Validation Loss: 1.3789, Validation Accuracy: 38.16%
# Epoch [148/200], Train Loss: 1.2622, Train Accuracy: 48.78%
# Validation Loss: 1.3769, Validation Accuracy: 38.72%
# Epoch [149/200], Train Loss: 1.2775, Train Accuracy: 46.82%
# Validation Loss: 1.3749, Validation Accuracy: 39.28%
# Epoch [150/200], Train Loss: 1.2743, Train Accuracy: 46.96%
# Validation Loss: 1.3728, Validation Accuracy: 39.55%
# Epoch [151/200], Train Loss: 1.2515, Train Accuracy: 48.57%
# Validation Loss: 1.3707, Validation Accuracy: 40.11%
# Epoch [152/200], Train Loss: 1.2582, Train Accuracy: 48.08%
# Validation Loss: 1.3675, Validation Accuracy: 40.11%
# Epoch [153/200], Train Loss: 1.2490, Train Accuracy: 49.76%
# Validation Loss: 1.3633, Validation Accuracy: 40.67%
# Epoch [154/200], Train Loss: 1.2372, Train Accuracy: 48.36%
# Validation Loss: 1.3593, Validation Accuracy: 42.34%
# Epoch [155/200], Train Loss: 1.2466, Train Accuracy: 48.85%
# Validation Loss: 1.3553, Validation Accuracy: 43.18%
# Epoch [156/200], Train Loss: 1.2524, Train Accuracy: 49.06%
# Validation Loss: 1.3519, Validation Accuracy: 42.90%
# Epoch [157/200], Train Loss: 1.2389, Train Accuracy: 49.69%
# Validation Loss: 1.3485, Validation Accuracy: 43.18%
# Epoch [158/200], Train Loss: 1.2196, Train Accuracy: 51.71%
# Validation Loss: 1.3457, Validation Accuracy: 44.29%
# Epoch [159/200], Train Loss: 1.2135, Train Accuracy: 50.66%
# Validation Loss: 1.3433, Validation Accuracy: 44.29%
# Epoch [160/200], Train Loss: 1.2312, Train Accuracy: 50.52%
# Validation Loss: 1.3408, Validation Accuracy: 44.57%
# Epoch [161/200], Train Loss: 1.2160, Train Accuracy: 50.73%
# Validation Loss: 1.3376, Validation Accuracy: 45.13%
# Epoch [162/200], Train Loss: 1.2069, Train Accuracy: 52.20%
# Validation Loss: 1.3339, Validation Accuracy: 44.57%
# Epoch [163/200], Train Loss: 1.2048, Train Accuracy: 51.08%
# Validation Loss: 1.3290, Validation Accuracy: 45.40%
# Epoch [164/200], Train Loss: 1.1983, Train Accuracy: 52.55%
# Validation Loss: 1.3233, Validation Accuracy: 46.24%
# Epoch [165/200], Train Loss: 1.1988, Train Accuracy: 50.66%
# Validation Loss: 1.3175, Validation Accuracy: 46.24%
# Epoch [166/200], Train Loss: 1.1849, Train Accuracy: 53.31%
# Validation Loss: 1.3119, Validation Accuracy: 46.24%
# Epoch [167/200], Train Loss: 1.1795, Train Accuracy: 52.48%
# Validation Loss: 1.3072, Validation Accuracy: 45.40%
# Epoch [168/200], Train Loss: 1.1864, Train Accuracy: 54.36%
# Validation Loss: 1.3034, Validation Accuracy: 45.68%
# Epoch [169/200], Train Loss: 1.1763, Train Accuracy: 53.80%
# Validation Loss: 1.2993, Validation Accuracy: 46.52%
# Epoch [170/200], Train Loss: 1.1816, Train Accuracy: 54.71%
# Validation Loss: 1.2947, Validation Accuracy: 47.63%
# Epoch [171/200], Train Loss: 1.1683, Train Accuracy: 53.04%
# Validation Loss: 1.2890, Validation Accuracy: 47.91%
# Epoch [172/200], Train Loss: 1.1745, Train Accuracy: 54.15%
# Validation Loss: 1.2811, Validation Accuracy: 47.91%
# Epoch [173/200], Train Loss: 1.1513, Train Accuracy: 54.22%
# Validation Loss: 1.2738, Validation Accuracy: 48.19%
# Epoch [174/200], Train Loss: 1.1614, Train Accuracy: 53.38%
# Validation Loss: 1.2676, Validation Accuracy: 48.47%
# Epoch [175/200], Train Loss: 1.1437, Train Accuracy: 53.94%
# Validation Loss: 1.2615, Validation Accuracy: 47.35%
# Epoch [176/200], Train Loss: 1.1532, Train Accuracy: 52.90%
# Validation Loss: 1.2565, Validation Accuracy: 47.63%
# Epoch [177/200], Train Loss: 1.1471, Train Accuracy: 53.94%
# Validation Loss: 1.2511, Validation Accuracy: 47.91%
# Epoch [178/200], Train Loss: 1.1341, Train Accuracy: 53.80%
# Validation Loss: 1.2460, Validation Accuracy: 47.91%
# Epoch [179/200], Train Loss: 1.1202, Train Accuracy: 55.48%
# Validation Loss: 1.2409, Validation Accuracy: 47.63%
# Epoch [180/200], Train Loss: 1.1343, Train Accuracy: 55.27%
# Validation Loss: 1.2373, Validation Accuracy: 48.19%
# Epoch [181/200], Train Loss: 1.1259, Train Accuracy: 54.92%
# Validation Loss: 1.2333, Validation Accuracy: 48.19%
# Epoch [182/200], Train Loss: 1.1227, Train Accuracy: 54.92%
# Validation Loss: 1.2279, Validation Accuracy: 47.63%
# Epoch [183/200], Train Loss: 1.1084, Train Accuracy: 55.76%
# Validation Loss: 1.2222, Validation Accuracy: 47.91%
# Epoch [184/200], Train Loss: 1.1150, Train Accuracy: 57.36%
# Validation Loss: 1.2161, Validation Accuracy: 47.91%
# Epoch [185/200], Train Loss: 1.1043, Train Accuracy: 56.52%
# Validation Loss: 1.2097, Validation Accuracy: 48.75%
# Epoch [186/200], Train Loss: 1.0909, Train Accuracy: 57.43%
# Validation Loss: 1.2043, Validation Accuracy: 48.47%
# Epoch [187/200], Train Loss: 1.0906, Train Accuracy: 57.08%
# Validation Loss: 1.1994, Validation Accuracy: 48.75%
# Epoch [188/200], Train Loss: 1.0958, Train Accuracy: 55.90%
# Validation Loss: 1.1932, Validation Accuracy: 50.14%
# Epoch [189/200], Train Loss: 1.0883, Train Accuracy: 56.39%
# Validation Loss: 1.1870, Validation Accuracy: 49.30%
# Epoch [190/200], Train Loss: 1.0831, Train Accuracy: 56.94%
# Validation Loss: 1.1808, Validation Accuracy: 49.03%
# Epoch [191/200], Train Loss: 1.0718, Train Accuracy: 58.20%
# Validation Loss: 1.1745, Validation Accuracy: 49.03%
# Epoch [192/200], Train Loss: 1.0755, Train Accuracy: 57.22%
# Validation Loss: 1.1671, Validation Accuracy: 50.14%
# Epoch [193/200], Train Loss: 1.0572, Train Accuracy: 57.15%
# Validation Loss: 1.1617, Validation Accuracy: 51.81%
# Epoch [194/200], Train Loss: 1.0654, Train Accuracy: 56.94%
# Validation Loss: 1.1552, Validation Accuracy: 52.65%
# Epoch [195/200], Train Loss: 1.0505, Train Accuracy: 58.97%
# Validation Loss: 1.1473, Validation Accuracy: 53.48%
# Epoch [196/200], Train Loss: 1.0448, Train Accuracy: 58.13%
# Validation Loss: 1.1412, Validation Accuracy: 51.53%
# Epoch [197/200], Train Loss: 1.0440, Train Accuracy: 58.41%
# Validation Loss: 1.1347, Validation Accuracy: 52.09%
# Epoch [198/200], Train Loss: 1.0303, Train Accuracy: 58.90%
# Validation Loss: 1.1268, Validation Accuracy: 52.09%
# Epoch [199/200], Train Loss: 1.0159, Train Accuracy: 59.80%
# Validation Loss: 1.1197, Validation Accuracy: 54.04%
# Epoch [200/200], Train Loss: 1.0136, Train Accuracy: 60.78%
# Validation Loss: 1.1146, Validation Accuracy: 53.48%
# Epoch [201/200], Train Loss: 1.0172, Train Accuracy: 60.01%
# Validation Loss: 1.1098, Validation Accuracy: 53.76%
# Epoch [202/200], Train Loss: 1.0072, Train Accuracy: 59.94%
# Validation Loss: 1.1051, Validation Accuracy: 52.92%
# Epoch [203/200], Train Loss: 1.0107, Train Accuracy: 60.64%
# Validation Loss: 1.0987, Validation Accuracy: 54.60%
# Epoch [204/200], Train Loss: 0.9836, Train Accuracy: 62.25%
# Validation Loss: 1.0892, Validation Accuracy: 55.99%
# Epoch [205/200], Train Loss: 0.9992, Train Accuracy: 60.64%
# Validation Loss: 1.0791, Validation Accuracy: 56.82%
# Epoch [206/200], Train Loss: 0.9796, Train Accuracy: 62.25%
# Validation Loss: 1.0708, Validation Accuracy: 56.82%
# Epoch [207/200], Train Loss: 0.9675, Train Accuracy: 61.76%
# Validation Loss: 1.0625, Validation Accuracy: 56.27%
# Epoch [208/200], Train Loss: 0.9854, Train Accuracy: 62.53%
# Validation Loss: 1.0566, Validation Accuracy: 55.99%
# Epoch [209/200], Train Loss: 0.9603, Train Accuracy: 63.36%
# Validation Loss: 1.0540, Validation Accuracy: 55.99%
# Epoch [210/200], Train Loss: 0.9651, Train Accuracy: 62.94%
# Validation Loss: 1.0494, Validation Accuracy: 55.99%
# Epoch [211/200], Train Loss: 0.9586, Train Accuracy: 62.67%
# Validation Loss: 1.0429, Validation Accuracy: 57.38%
# Epoch [212/200], Train Loss: 0.9428, Train Accuracy: 62.88%
# Validation Loss: 1.0362, Validation Accuracy: 57.94%
# Epoch [213/200], Train Loss: 0.9400, Train Accuracy: 63.92%
# Validation Loss: 1.0292, Validation Accuracy: 58.22%
# Epoch [214/200], Train Loss: 0.9296, Train Accuracy: 63.92%
# Validation Loss: 1.0213, Validation Accuracy: 57.38%
# Epoch [215/200], Train Loss: 0.9271, Train Accuracy: 64.13%
# Validation Loss: 1.0154, Validation Accuracy: 58.77%
# Epoch [216/200], Train Loss: 0.9353, Train Accuracy: 62.94%
# Validation Loss: 1.0104, Validation Accuracy: 59.05%
# Epoch [217/200], Train Loss: 0.9318, Train Accuracy: 63.29%
# Validation Loss: 1.0024, Validation Accuracy: 59.89%
# Epoch [218/200], Train Loss: 0.9193, Train Accuracy: 64.83%
# Validation Loss: 0.9965, Validation Accuracy: 59.33%
# Epoch [219/200], Train Loss: 0.9144, Train Accuracy: 64.06%
# Validation Loss: 0.9915, Validation Accuracy: 58.22%
# Epoch [220/200], Train Loss: 0.9156, Train Accuracy: 63.57%
# Validation Loss: 0.9833, Validation Accuracy: 60.17%
# Epoch [221/200], Train Loss: 0.8896, Train Accuracy: 65.81%
# Validation Loss: 0.9766, Validation Accuracy: 59.89%
# Epoch [222/200], Train Loss: 0.9090, Train Accuracy: 64.83%
# Validation Loss: 0.9705, Validation Accuracy: 60.72%
# Epoch [223/200], Train Loss: 0.8964, Train Accuracy: 65.39%
# Validation Loss: 0.9667, Validation Accuracy: 61.28%
# Epoch [224/200], Train Loss: 0.9086, Train Accuracy: 64.27%
# Validation Loss: 0.9639, Validation Accuracy: 61.00%
# Epoch [225/200], Train Loss: 0.8862, Train Accuracy: 65.95%
# Validation Loss: 0.9601, Validation Accuracy: 61.28%
# Epoch [226/200], Train Loss: 0.8854, Train Accuracy: 64.83%
# Validation Loss: 0.9579, Validation Accuracy: 62.12%
# Epoch [227/200], Train Loss: 0.8879, Train Accuracy: 64.48%
# Validation Loss: 0.9517, Validation Accuracy: 62.40%
# Epoch [228/200], Train Loss: 0.8719, Train Accuracy: 66.99%
# Validation Loss: 0.9415, Validation Accuracy: 62.67%
# Epoch [229/200], Train Loss: 0.8624, Train Accuracy: 66.92%
# Validation Loss: 0.9339, Validation Accuracy: 62.40%
# Epoch [230/200], Train Loss: 0.8634, Train Accuracy: 66.78%
# Validation Loss: 0.9300, Validation Accuracy: 61.56%
# Epoch [231/200], Train Loss: 0.8800, Train Accuracy: 66.71%
# Validation Loss: 0.9277, Validation Accuracy: 61.84%
# Epoch [232/200], Train Loss: 0.8413, Train Accuracy: 67.48%
# Validation Loss: 0.9247, Validation Accuracy: 63.51%
# Epoch [233/200], Train Loss: 0.8431, Train Accuracy: 68.04%
# Validation Loss: 0.9186, Validation Accuracy: 63.79%
# Epoch [234/200], Train Loss: 0.8447, Train Accuracy: 66.92%
# Validation Loss: 0.9141, Validation Accuracy: 63.23%
# Epoch [235/200], Train Loss: 0.8514, Train Accuracy: 68.04%
# Validation Loss: 0.9108, Validation Accuracy: 63.51%
# Epoch [236/200], Train Loss: 0.8325, Train Accuracy: 67.90%
# Validation Loss: 0.9082, Validation Accuracy: 64.07%
# Epoch [237/200], Train Loss: 0.8492, Train Accuracy: 67.34%
# Validation Loss: 0.9016, Validation Accuracy: 63.79%
# Epoch [238/200], Train Loss: 0.8463, Train Accuracy: 68.18%
# Validation Loss: 0.8934, Validation Accuracy: 64.07%
# Epoch [239/200], Train Loss: 0.8347, Train Accuracy: 68.18%
# Validation Loss: 0.8886, Validation Accuracy: 64.62%
# Epoch [240/200], Train Loss: 0.8307, Train Accuracy: 68.60%
# Validation Loss: 0.8865, Validation Accuracy: 65.18%
# Epoch [241/200], Train Loss: 0.8296, Train Accuracy: 69.50%
# Validation Loss: 0.8839, Validation Accuracy: 65.18%
# Epoch [242/200], Train Loss: 0.8236, Train Accuracy: 68.46%
# Validation Loss: 0.8782, Validation Accuracy: 65.18%
# Epoch [243/200], Train Loss: 0.8128, Train Accuracy: 70.06%
# Validation Loss: 0.8713, Validation Accuracy: 66.30%
# Epoch [244/200], Train Loss: 0.8097, Train Accuracy: 69.36%
# Validation Loss: 0.8654, Validation Accuracy: 67.41%
# Epoch [245/200], Train Loss: 0.8169, Train Accuracy: 70.06%
# Validation Loss: 0.8623, Validation Accuracy: 68.25%
# Epoch [246/200], Train Loss: 0.8180, Train Accuracy: 69.85%
# Validation Loss: 0.8601, Validation Accuracy: 67.41%
# Epoch [247/200], Train Loss: 0.8110, Train Accuracy: 70.55%
# Validation Loss: 0.8577, Validation Accuracy: 66.85%
# Epoch [248/200], Train Loss: 0.8103, Train Accuracy: 69.09%
# Validation Loss: 0.8559, Validation Accuracy: 66.30%
# Epoch [249/200], Train Loss: 0.7995, Train Accuracy: 70.06%
# Validation Loss: 0.8510, Validation Accuracy: 66.85%
# Epoch [250/200], Train Loss: 0.7976, Train Accuracy: 69.43%
# Validation Loss: 0.8459, Validation Accuracy: 69.36%
# Epoch [251/200], Train Loss: 0.7907, Train Accuracy: 69.92%
# Validation Loss: 0.8408, Validation Accuracy: 69.08%
# Epoch [252/200], Train Loss: 0.7927, Train Accuracy: 70.34%
# Validation Loss: 0.8363, Validation Accuracy: 69.64%
# Epoch [253/200], Train Loss: 0.7868, Train Accuracy: 71.18%
# Validation Loss: 0.8344, Validation Accuracy: 69.92%
# Epoch [254/200], Train Loss: 0.7843, Train Accuracy: 69.64%
# Validation Loss: 0.8322, Validation Accuracy: 69.92%
# Epoch [255/200], Train Loss: 0.7750, Train Accuracy: 70.48%
# Validation Loss: 0.8257, Validation Accuracy: 70.19%
# Epoch [256/200], Train Loss: 0.7602, Train Accuracy: 72.44%
# Validation Loss: 0.8205, Validation Accuracy: 70.47%
# Epoch [257/200], Train Loss: 0.7501, Train Accuracy: 71.95%
# Validation Loss: 0.8173, Validation Accuracy: 70.75%
# Epoch [258/200], Train Loss: 0.7697, Train Accuracy: 71.32%
# Validation Loss: 0.8142, Validation Accuracy: 70.47%
# Epoch [259/200], Train Loss: 0.7929, Train Accuracy: 70.41%
# Validation Loss: 0.8123, Validation Accuracy: 71.03%
# Epoch [260/200], Train Loss: 0.7773, Train Accuracy: 71.46%
# Validation Loss: 0.8090, Validation Accuracy: 70.19%
# Epoch [261/200], Train Loss: 0.7688, Train Accuracy: 71.67%
# Validation Loss: 0.8063, Validation Accuracy: 71.03%
# Epoch [262/200], Train Loss: 0.7435, Train Accuracy: 72.30%
# Validation Loss: 0.8045, Validation Accuracy: 71.31%
# Epoch [263/200], Train Loss: 0.7528, Train Accuracy: 71.88%
# Validation Loss: 0.8015, Validation Accuracy: 71.31%
# Epoch [264/200], Train Loss: 0.7603, Train Accuracy: 72.30%
# Validation Loss: 0.7978, Validation Accuracy: 70.75%
# Epoch [265/200], Train Loss: 0.7376, Train Accuracy: 72.51%
# Validation Loss: 0.7943, Validation Accuracy: 71.87%
# Epoch [266/200], Train Loss: 0.7377, Train Accuracy: 72.23%
# Validation Loss: 0.7919, Validation Accuracy: 70.75%
# Epoch [267/200], Train Loss: 0.7579, Train Accuracy: 72.64%
# Validation Loss: 0.7919, Validation Accuracy: 70.75%
# Epoch [268/200], Train Loss: 0.7557, Train Accuracy: 72.16%
# Validation Loss: 0.7891, Validation Accuracy: 71.03%
# Epoch [269/200], Train Loss: 0.7389, Train Accuracy: 71.88%
# Validation Loss: 0.7956, Validation Accuracy: 72.70%
# Epoch [270/200], Train Loss: 0.7348, Train Accuracy: 73.48%
# Validation Loss: 0.7900, Validation Accuracy: 73.82%
# Epoch [271/200], Train Loss: 0.7557, Train Accuracy: 72.30%
# Validation Loss: 0.7882, Validation Accuracy: 71.87%
# Epoch [272/200], Train Loss: 0.7262, Train Accuracy: 73.41%
# Validation Loss: 0.7818, Validation Accuracy: 71.87%
# Epoch [273/200], Train Loss: 0.7284, Train Accuracy: 72.85%
# Validation Loss: 0.7784, Validation Accuracy: 73.26%
# Epoch [274/200], Train Loss: 0.7139, Train Accuracy: 73.55%
# Validation Loss: 0.7755, Validation Accuracy: 72.42%
# Epoch [275/200], Train Loss: 0.7319, Train Accuracy: 72.85%
# Validation Loss: 0.7742, Validation Accuracy: 71.87%
# Epoch [276/200], Train Loss: 0.7266, Train Accuracy: 73.90%
# Validation Loss: 0.7733, Validation Accuracy: 72.14%
# Epoch [277/200], Train Loss: 0.7185, Train Accuracy: 72.92%
# Validation Loss: 0.7713, Validation Accuracy: 74.65%
# Epoch [278/200], Train Loss: 0.7268, Train Accuracy: 72.71%
# Validation Loss: 0.7710, Validation Accuracy: 74.09%
# Epoch [279/200], Train Loss: 0.7318, Train Accuracy: 73.48%
# Validation Loss: 0.7701, Validation Accuracy: 72.42%
# Epoch [280/200], Train Loss: 0.7106, Train Accuracy: 74.53%
# Validation Loss: 0.7698, Validation Accuracy: 72.14%
# Epoch [281/200], Train Loss: 0.7128, Train Accuracy: 73.06%
# Validation Loss: 0.7651, Validation Accuracy: 73.82%
# Epoch [282/200], Train Loss: 0.7061, Train Accuracy: 72.99%
# Validation Loss: 0.7648, Validation Accuracy: 73.54%
# Epoch [283/200], Train Loss: 0.7147, Train Accuracy: 72.02%
# Validation Loss: 0.7630, Validation Accuracy: 72.70%
# Epoch [284/200], Train Loss: 0.7120, Train Accuracy: 73.06%
# Validation Loss: 0.7621, Validation Accuracy: 72.42%
# Epoch [285/200], Train Loss: 0.7075, Train Accuracy: 74.25%
# Validation Loss: 0.7593, Validation Accuracy: 72.70%
# Epoch [286/200], Train Loss: 0.7069, Train Accuracy: 74.53%
# Validation Loss: 0.7554, Validation Accuracy: 73.82%
# Epoch [287/200], Train Loss: 0.7073, Train Accuracy: 73.76%
# Validation Loss: 0.7521, Validation Accuracy: 73.54%
# Epoch [288/200], Train Loss: 0.7046, Train Accuracy: 74.46%
# Validation Loss: 0.7528, Validation Accuracy: 74.09%
# Epoch [289/200], Train Loss: 0.7147, Train Accuracy: 73.76%
# Validation Loss: 0.7540, Validation Accuracy: 73.54%
# Epoch [290/200], Train Loss: 0.6996, Train Accuracy: 75.16%
# Validation Loss: 0.7538, Validation Accuracy: 74.09%
# Epoch [291/200], Train Loss: 0.6965, Train Accuracy: 74.25%
# Validation Loss: 0.7486, Validation Accuracy: 74.09%
# Epoch [292/200], Train Loss: 0.6858, Train Accuracy: 73.90%
# Validation Loss: 0.7451, Validation Accuracy: 74.37%
# Epoch [293/200], Train Loss: 0.6833, Train Accuracy: 74.60%
# Validation Loss: 0.7455, Validation Accuracy: 73.54%
# Epoch [294/200], Train Loss: 0.7016, Train Accuracy: 74.53%
# Validation Loss: 0.7440, Validation Accuracy: 74.65%
# Epoch [295/200], Train Loss: 0.6986, Train Accuracy: 73.48%
# Validation Loss: 0.7470, Validation Accuracy: 74.09%
# Epoch [296/200], Train Loss: 0.6889, Train Accuracy: 74.18%
# Validation Loss: 0.7494, Validation Accuracy: 74.09%
# Epoch [297/200], Train Loss: 0.6701, Train Accuracy: 74.39%
# Validation Loss: 0.7519, Validation Accuracy: 73.54%
# Epoch [298/200], Train Loss: 0.6731, Train Accuracy: 75.16%
# Validation Loss: 0.7428, Validation Accuracy: 74.37%
# Epoch [299/200], Train Loss: 0.6837, Train Accuracy: 73.97%
# Validation Loss: 0.7389, Validation Accuracy: 74.09%
# Epoch [300/200], Train Loss: 0.6827, Train Accuracy: 75.02%
# Validation Loss: 0.7379, Validation Accuracy: 74.37%
# Epoch [301/200], Train Loss: 0.6729, Train Accuracy: 75.09%
# Validation Loss: 0.7407, Validation Accuracy: 73.26%
# Epoch [302/200], Train Loss: 0.6757, Train Accuracy: 75.72%
# Validation Loss: 0.7370, Validation Accuracy: 73.82%
# Epoch [303/200], Train Loss: 0.6843, Train Accuracy: 75.72%
# Validation Loss: 0.7383, Validation Accuracy: 74.09%
# Epoch [304/200], Train Loss: 0.6845, Train Accuracy: 74.95%
# Validation Loss: 0.7383, Validation Accuracy: 74.37%
# Epoch [305/200], Train Loss: 0.6618, Train Accuracy: 77.11%
# Validation Loss: 0.7416, Validation Accuracy: 72.98%
# Epoch [306/200], Train Loss: 0.6717, Train Accuracy: 76.20%
# Validation Loss: 0.7343, Validation Accuracy: 74.37%
# Epoch [307/200], Train Loss: 0.6736, Train Accuracy: 74.25%
# Validation Loss: 0.7295, Validation Accuracy: 74.09%
# Epoch [308/200], Train Loss: 0.6773, Train Accuracy: 74.81%
# Validation Loss: 0.7257, Validation Accuracy: 74.65%
# Epoch [309/200], Train Loss: 0.6606, Train Accuracy: 75.79%
# Validation Loss: 0.7349, Validation Accuracy: 73.26%
# Epoch [310/200], Train Loss: 0.6795, Train Accuracy: 74.46%
# Validation Loss: 0.7269, Validation Accuracy: 73.82%
# Epoch [311/200], Train Loss: 0.6650, Train Accuracy: 75.72%
# Validation Loss: 0.7272, Validation Accuracy: 74.09%
# Epoch [312/200], Train Loss: 0.6693, Train Accuracy: 76.20%
# Validation Loss: 0.7256, Validation Accuracy: 74.09%
# Epoch [313/200], Train Loss: 0.6542, Train Accuracy: 76.27%
# Validation Loss: 0.7365, Validation Accuracy: 72.70%
# Epoch [314/200], Train Loss: 0.6666, Train Accuracy: 75.79%
# Validation Loss: 0.7327, Validation Accuracy: 72.98%
# Epoch [315/200], Train Loss: 0.6509, Train Accuracy: 75.85%
# Validation Loss: 0.7224, Validation Accuracy: 74.37%
# Epoch [316/200], Train Loss: 0.6504, Train Accuracy: 76.76%
# Validation Loss: 0.7230, Validation Accuracy: 75.21%
# Epoch [317/200], Train Loss: 0.6692, Train Accuracy: 75.02%
# Validation Loss: 0.7183, Validation Accuracy: 75.49%
# Epoch [318/200], Train Loss: 0.6473, Train Accuracy: 76.76%
# Validation Loss: 0.7293, Validation Accuracy: 73.54%
# Epoch [319/200], Train Loss: 0.6522, Train Accuracy: 76.69%
# Validation Loss: 0.7199, Validation Accuracy: 74.93%
# Epoch [320/200], Train Loss: 0.6380, Train Accuracy: 76.20%
# Validation Loss: 0.7191, Validation Accuracy: 74.93%
# Epoch [321/200], Train Loss: 0.6604, Train Accuracy: 76.34%
# Validation Loss: 0.7163, Validation Accuracy: 74.65%
# Epoch [322/200], Train Loss: 0.6563, Train Accuracy: 76.34%
# Validation Loss: 0.7182, Validation Accuracy: 73.54%
# Epoch [323/200], Train Loss: 0.6390, Train Accuracy: 76.62%
# Validation Loss: 0.7169, Validation Accuracy: 74.65%
# Epoch [324/200], Train Loss: 0.6414, Train Accuracy: 75.58%
# Validation Loss: 0.7158, Validation Accuracy: 74.65%
# Epoch [325/200], Train Loss: 0.6401, Train Accuracy: 77.25%
# Validation Loss: 0.7159, Validation Accuracy: 74.93%
# Epoch [326/200], Train Loss: 0.6374, Train Accuracy: 77.88%
# Validation Loss: 0.7150, Validation Accuracy: 74.93%
# Epoch [327/200], Train Loss: 0.6389, Train Accuracy: 76.34%
# Validation Loss: 0.7138, Validation Accuracy: 74.93%
# Epoch [328/200], Train Loss: 0.6360, Train Accuracy: 76.06%
# Validation Loss: 0.7125, Validation Accuracy: 74.93%
# Epoch [329/200], Train Loss: 0.6361, Train Accuracy: 75.99%
# Validation Loss: 0.7093, Validation Accuracy: 74.93%
# Epoch [330/200], Train Loss: 0.6474, Train Accuracy: 76.48%
# Validation Loss: 0.7110, Validation Accuracy: 75.21%
# Epoch [331/200], Train Loss: 0.6281, Train Accuracy: 77.39%
# Validation Loss: 0.7113, Validation Accuracy: 74.93%
# Epoch [332/200], Train Loss: 0.6442, Train Accuracy: 76.97%
# Validation Loss: 0.7123, Validation Accuracy: 74.09%
# Epoch [333/200], Train Loss: 0.6256, Train Accuracy: 76.41%
# Validation Loss: 0.7084, Validation Accuracy: 74.09%
# Epoch [334/200], Train Loss: 0.6343, Train Accuracy: 77.04%
# Validation Loss: 0.7044, Validation Accuracy: 74.09%
# Epoch [335/200], Train Loss: 0.6213, Train Accuracy: 78.30%
# Validation Loss: 0.7034, Validation Accuracy: 75.21%
# Epoch [336/200], Train Loss: 0.6199, Train Accuracy: 77.53%
# Validation Loss: 0.7043, Validation Accuracy: 74.09%
# Epoch [337/200], Train Loss: 0.6151, Train Accuracy: 77.53%
# Validation Loss: 0.7101, Validation Accuracy: 74.37%
# Epoch [338/200], Train Loss: 0.6365, Train Accuracy: 77.11%
# Validation Loss: 0.7089, Validation Accuracy: 75.21%
# Epoch [339/200], Train Loss: 0.6314, Train Accuracy: 78.16%
# Validation Loss: 0.7093, Validation Accuracy: 75.21%
# Epoch [340/200], Train Loss: 0.6256, Train Accuracy: 78.16%
# Validation Loss: 0.7065, Validation Accuracy: 75.77%
# Epoch [341/200], Train Loss: 0.6236, Train Accuracy: 77.39%
# Validation Loss: 0.7055, Validation Accuracy: 74.09%
# Epoch [342/200], Train Loss: 0.6282, Train Accuracy: 77.39%
# Validation Loss: 0.7026, Validation Accuracy: 73.82%
# Epoch [343/200], Train Loss: 0.6115, Train Accuracy: 77.53%
# Validation Loss: 0.6997, Validation Accuracy: 74.65%
# Epoch [344/200], Train Loss: 0.6038, Train Accuracy: 78.16%
# Validation Loss: 0.7010, Validation Accuracy: 74.65%
# Epoch [345/200], Train Loss: 0.6097, Train Accuracy: 78.37%
# Validation Loss: 0.7051, Validation Accuracy: 74.37%
# Epoch [346/200], Train Loss: 0.6171, Train Accuracy: 77.88%
# Validation Loss: 0.7077, Validation Accuracy: 74.65%
# Epoch [347/200], Train Loss: 0.6234, Train Accuracy: 76.83%
# Validation Loss: 0.7055, Validation Accuracy: 74.09%
# Epoch [348/200], Train Loss: 0.6179, Train Accuracy: 76.97%
# Validation Loss: 0.7015, Validation Accuracy: 74.37%
# Epoch [349/200], Train Loss: 0.6199, Train Accuracy: 77.46%
# Validation Loss: 0.6986, Validation Accuracy: 74.93%
# Epoch [350/200], Train Loss: 0.6136, Train Accuracy: 78.23%
# Validation Loss: 0.6979, Validation Accuracy: 74.93%
# Epoch [351/200], Train Loss: 0.6297, Train Accuracy: 76.76%
# Validation Loss: 0.7003, Validation Accuracy: 74.37%
# Epoch [352/200], Train Loss: 0.6054, Train Accuracy: 78.09%
# Validation Loss: 0.7012, Validation Accuracy: 74.65%
# Epoch [353/200], Train Loss: 0.6091, Train Accuracy: 78.65%
# Validation Loss: 0.7010, Validation Accuracy: 75.21%
# Epoch [354/200], Train Loss: 0.6113, Train Accuracy: 78.72%
# Validation Loss: 0.7038, Validation Accuracy: 75.77%
# Epoch [355/200], Train Loss: 0.6131, Train Accuracy: 77.74%
# Validation Loss: 0.7054, Validation Accuracy: 75.49%
# Epoch [356/200], Train Loss: 0.6094, Train Accuracy: 77.67%
# Validation Loss: 0.7099, Validation Accuracy: 74.37%
# Epoch [357/200], Train Loss: 0.6025, Train Accuracy: 77.39%
# Validation Loss: 0.7010, Validation Accuracy: 74.93%
# Epoch [358/200], Train Loss: 0.5994, Train Accuracy: 77.81%
# Validation Loss: 0.6984, Validation Accuracy: 76.04%
# Epoch [359/200], Train Loss: 0.5955, Train Accuracy: 78.30%
# Validation Loss: 0.6935, Validation Accuracy: 76.04%
# Epoch [360/200], Train Loss: 0.6024, Train Accuracy: 77.46%
# Validation Loss: 0.6964, Validation Accuracy: 74.37%
# Epoch [361/200], Train Loss: 0.5911, Train Accuracy: 77.81%
# Validation Loss: 0.6944, Validation Accuracy: 74.65%
# Epoch [362/200], Train Loss: 0.6025, Train Accuracy: 77.74%
# Validation Loss: 0.6928, Validation Accuracy: 76.32%
# Epoch [363/200], Train Loss: 0.5975, Train Accuracy: 78.72%
# Validation Loss: 0.6955, Validation Accuracy: 75.77%
# Epoch [364/200], Train Loss: 0.5898, Train Accuracy: 78.30%
# Validation Loss: 0.6983, Validation Accuracy: 75.77%
# Epoch [365/200], Train Loss: 0.6038, Train Accuracy: 77.88%
# Validation Loss: 0.7009, Validation Accuracy: 74.37%
# Epoch [366/200], Train Loss: 0.6062, Train Accuracy: 78.30%
# Validation Loss: 0.6952, Validation Accuracy: 76.04%
# Epoch [367/200], Train Loss: 0.5909, Train Accuracy: 78.51%
# Validation Loss: 0.6976, Validation Accuracy: 75.77%
# Epoch [368/200], Train Loss: 0.5853, Train Accuracy: 78.44%
# Validation Loss: 0.6948, Validation Accuracy: 75.49%
# Epoch [369/200], Train Loss: 0.5852, Train Accuracy: 78.79%
# Validation Loss: 0.6989, Validation Accuracy: 74.09%
# Epoch [370/200], Train Loss: 0.5973, Train Accuracy: 78.93%
# Validation Loss: 0.6934, Validation Accuracy: 75.21%
# Epoch [371/200], Train Loss: 0.5805, Train Accuracy: 77.88%
# Validation Loss: 0.6915, Validation Accuracy: 75.49%
# Epoch [372/200], Train Loss: 0.5892, Train Accuracy: 78.44%
# Validation Loss: 0.6897, Validation Accuracy: 75.21%
# Epoch [373/200], Train Loss: 0.5881, Train Accuracy: 78.65%
# Validation Loss: 0.6945, Validation Accuracy: 74.93%
# Epoch [374/200], Train Loss: 0.5787, Train Accuracy: 77.81%
# Validation Loss: 0.6958, Validation Accuracy: 74.65%
# Epoch [375/200], Train Loss: 0.5754, Train Accuracy: 79.00%
# Validation Loss: 0.6892, Validation Accuracy: 75.77%
# Epoch [376/200], Train Loss: 0.5771, Train Accuracy: 78.37%
# Validation Loss: 0.6936, Validation Accuracy: 75.49%
# Epoch [377/200], Train Loss: 0.5888, Train Accuracy: 78.09%
# Validation Loss: 0.6918, Validation Accuracy: 76.04%
# Epoch [378/200], Train Loss: 0.5797, Train Accuracy: 78.93%
# Validation Loss: 0.7022, Validation Accuracy: 74.93%
# Epoch [379/200], Train Loss: 0.6043, Train Accuracy: 78.09%
# Validation Loss: 0.6960, Validation Accuracy: 75.21%
# Epoch [380/200], Train Loss: 0.5671, Train Accuracy: 78.58%
# Validation Loss: 0.6934, Validation Accuracy: 76.04%
# Epoch [381/200], Train Loss: 0.5842, Train Accuracy: 78.23%
# Validation Loss: 0.6918, Validation Accuracy: 76.04%
# Epoch [382/200], Train Loss: 0.5803, Train Accuracy: 79.41%
# Validation Loss: 0.6913, Validation Accuracy: 75.49%
# Epoch [383/200], Train Loss: 0.5804, Train Accuracy: 78.58%
# Validation Loss: 0.6965, Validation Accuracy: 74.65%
# Epoch [384/200], Train Loss: 0.5791, Train Accuracy: 79.00%
# Validation Loss: 0.6905, Validation Accuracy: 75.77%
# Epoch [385/200], Train Loss: 0.5877, Train Accuracy: 78.37%
# Validation Loss: 0.6934, Validation Accuracy: 76.32%
# Epoch [386/200], Train Loss: 0.5659, Train Accuracy: 80.39%
# Validation Loss: 0.6912, Validation Accuracy: 76.32%
# Epoch [387/200], Train Loss: 0.5732, Train Accuracy: 79.34%
# Validation Loss: 0.6889, Validation Accuracy: 75.49%
# Epoch [388/200], Train Loss: 0.5792, Train Accuracy: 78.65%
# Validation Loss: 0.6895, Validation Accuracy: 75.21%
# Epoch [389/200], Train Loss: 0.5678, Train Accuracy: 79.48%
# Validation Loss: 0.6847, Validation Accuracy: 75.77%
# Epoch [390/200], Train Loss: 0.5623, Train Accuracy: 78.58%
# Validation Loss: 0.6857, Validation Accuracy: 75.49%
# Epoch [391/200], Train Loss: 0.5633, Train Accuracy: 79.62%
# Validation Loss: 0.6900, Validation Accuracy: 75.21%
# Epoch [392/200], Train Loss: 0.5661, Train Accuracy: 78.51%
# Validation Loss: 0.6922, Validation Accuracy: 75.21%
# Epoch [393/200], Train Loss: 0.5662, Train Accuracy: 79.41%
# Validation Loss: 0.6940, Validation Accuracy: 74.93%
# Epoch [394/200], Train Loss: 0.5726, Train Accuracy: 79.13%
# Validation Loss: 0.6873, Validation Accuracy: 75.77%
# Epoch [395/200], Train Loss: 0.5570, Train Accuracy: 79.55%
# Validation Loss: 0.6881, Validation Accuracy: 75.49%
# Epoch [396/200], Train Loss: 0.5675, Train Accuracy: 79.69%
# Validation Loss: 0.6854, Validation Accuracy: 75.49%
# Epoch [397/200], Train Loss: 0.5527, Train Accuracy: 79.62%
# Validation Loss: 0.6911, Validation Accuracy: 75.77%
# Epoch [398/200], Train Loss: 0.5542, Train Accuracy: 79.41%
# Validation Loss: 0.6905, Validation Accuracy: 75.49%
# Epoch [399/200], Train Loss: 0.5403, Train Accuracy: 80.39%
# Validation Loss: 0.6896, Validation Accuracy: 75.49%
# Epoch [400/200], Train Loss: 0.5523, Train Accuracy: 79.41%
# Validation Loss: 0.6890, Validation Accuracy: 75.49%
# Epoch [401/200], Train Loss: 0.5626, Train Accuracy: 78.51%
# Validation Loss: 0.6863, Validation Accuracy: 75.49%
# Epoch [402/200], Train Loss: 0.5483, Train Accuracy: 79.97%
# Validation Loss: 0.6960, Validation Accuracy: 75.77%
# Epoch [403/200], Train Loss: 0.5639, Train Accuracy: 79.00%
# Validation Loss: 0.6819, Validation Accuracy: 76.04%
# Epoch [404/200], Train Loss: 0.5580, Train Accuracy: 79.41%
# Validation Loss: 0.6875, Validation Accuracy: 75.49%
# Epoch [405/200], Train Loss: 0.5793, Train Accuracy: 77.18%
# Validation Loss: 0.6849, Validation Accuracy: 75.49%
# Epoch [406/200], Train Loss: 0.5682, Train Accuracy: 79.13%
# Validation Loss: 0.6910, Validation Accuracy: 74.93%
# Epoch [407/200], Train Loss: 0.5545, Train Accuracy: 79.83%
# Validation Loss: 0.6888, Validation Accuracy: 75.77%
# Epoch [408/200], Train Loss: 0.5623, Train Accuracy: 78.86%
# Validation Loss: 0.6818, Validation Accuracy: 76.32%
# Epoch [409/200], Train Loss: 0.5530, Train Accuracy: 79.27%
# Validation Loss: 0.6816, Validation Accuracy: 77.16%
# Epoch [410/200], Train Loss: 0.5673, Train Accuracy: 78.16%
# Validation Loss: 0.6769, Validation Accuracy: 76.88%
# Epoch [411/200], Train Loss: 0.5682, Train Accuracy: 78.79%
# Validation Loss: 0.6795, Validation Accuracy: 75.77%
# Epoch [412/200], Train Loss: 0.5510, Train Accuracy: 79.55%
# Validation Loss: 0.6758, Validation Accuracy: 77.16%
# Epoch [413/200], Train Loss: 0.5418, Train Accuracy: 81.09%
# Validation Loss: 0.6781, Validation Accuracy: 76.60%
# Epoch [414/200], Train Loss: 0.5474, Train Accuracy: 79.41%
# Validation Loss: 0.6806, Validation Accuracy: 76.04%
# Epoch [415/200], Train Loss: 0.5504, Train Accuracy: 79.55%
# Validation Loss: 0.6828, Validation Accuracy: 75.49%
# Epoch [416/200], Train Loss: 0.5504, Train Accuracy: 80.18%
# Validation Loss: 0.6876, Validation Accuracy: 75.49%
# Epoch [417/200], Train Loss: 0.5405, Train Accuracy: 79.41%
# Validation Loss: 0.6881, Validation Accuracy: 76.32%
# Epoch [418/200], Train Loss: 0.5567, Train Accuracy: 79.76%
# Validation Loss: 0.6907, Validation Accuracy: 76.04%
# Epoch [419/200], Train Loss: 0.5301, Train Accuracy: 80.95%
# Validation Loss: 0.6901, Validation Accuracy: 75.77%
# Epoch [420/200], Train Loss: 0.5444, Train Accuracy: 79.90%
# Validation Loss: 0.6888, Validation Accuracy: 75.21%
# Epoch [421/200], Train Loss: 0.5414, Train Accuracy: 80.04%
# Validation Loss: 0.6878, Validation Accuracy: 75.21%
# Epoch [422/200], Train Loss: 0.5514, Train Accuracy: 79.55%
# Validation Loss: 0.6851, Validation Accuracy: 76.60%
# Epoch [423/200], Train Loss: 0.5374, Train Accuracy: 81.51%
# Validation Loss: 0.6847, Validation Accuracy: 76.60%
# Epoch [424/200], Train Loss: 0.5476, Train Accuracy: 79.97%
# Validation Loss: 0.6839, Validation Accuracy: 77.16%
# Epoch [425/200], Train Loss: 0.5404, Train Accuracy: 79.83%
# Validation Loss: 0.6871, Validation Accuracy: 76.60%
# Epoch [426/200], Train Loss: 0.5448, Train Accuracy: 79.90%
# Validation Loss: 0.6886, Validation Accuracy: 76.60%
# Epoch [427/200], Train Loss: 0.5532, Train Accuracy: 80.25%
# Validation Loss: 0.6862, Validation Accuracy: 76.32%
# Epoch [428/200], Train Loss: 0.5328, Train Accuracy: 80.88%
# Validation Loss: 0.6847, Validation Accuracy: 76.88%
# Epoch [429/200], Train Loss: 0.5326, Train Accuracy: 79.90%
# Validation Loss: 0.6827, Validation Accuracy: 77.16%
# Epoch [430/200], Train Loss: 0.5434, Train Accuracy: 79.97%
# Validation Loss: 0.6829, Validation Accuracy: 76.60%
# Epoch [431/200], Train Loss: 0.5450, Train Accuracy: 80.67%
# Validation Loss: 0.6842, Validation Accuracy: 77.16%
# Epoch [432/200], Train Loss: 0.5405, Train Accuracy: 80.11%
# Validation Loss: 0.6861, Validation Accuracy: 77.16%
# Early stopping at epoch 432. Best Validation Loss: 0.6758

# %% [markdown]
# **Visualize the Training Results**

# %%
# Plot loss and accuracy curves
def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)
    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Accuracy")
    plt.plot(epochs, history["val_acc"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    plt.show()

plot_history(history)

# Classification report
val_pred = val_predicted.cpu().numpy()
val_true = y_val_tensor.cpu().numpy()
print("\nClassification Report:\n", classification_report(val_true, val_pred))

# Confusion matrix
cm = confusion_matrix(val_true, val_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=range(9), yticklabels=range(9))
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ROC and AUC
if len(set(val_true)) == 2:  # Binary classification
    val_probs = torch.softmax(val_outputs, dim=1)[:, 1].cpu().numpy()
    auc = roc_auc_score(val_true, val_probs)
    fpr, tpr, _ = roc_curve(val_true, val_probs)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
    plt.plot([0, 1], [0, 1], "--", color="gray")
    plt.title("ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()
else:
    print("ROC curve and AUC are only applicable for binary classification.")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        57
#            1       0.69      0.71      0.70        52
#            3       0.83      0.80      0.81        55
#            4       0.70      0.60      0.65        50
#            5       0.79      0.88      0.84        43
#            7       0.74      0.84      0.79        50
#            8       0.83      0.73      0.78        52
#
#     accuracy                           0.77       359
#    macro avg       0.77      0.77      0.77       359
# weighted avg       0.77      0.77      0.77       359
# ROC curve and AUC are only applicable for binary classification.
