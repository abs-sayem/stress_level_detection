# %%
# Importing all necessary libraries
import pandas as pd
import numpy as np
import os
import librosa
import librosa.display
from IPython.display import Audio
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import warnings
warnings.filterwarnings('ignore')
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
import seaborn as sns

# %%
df= pd.read_excel("features_2.xlsx");
df.head()
# Out:
#          Pitch  Intensity    Frequency  Amplitude  \
# 0  1410.588989   0.041406  1410.588989   0.337341
# 1  1168.005859   0.022364  1168.005859   0.176117
# 2  1863.138916   0.029732  1863.138916   0.265015
# 3  1489.154175   0.043054  1489.154175   0.343719
# 4  1090.847290   0.030544  1090.847290   0.282318
#
#                                                MFCCs  Spectral Centroid  \
# 0  [-390.0313415527344, 55.235965728759766, -15.0...        2244.518922
# 1  [-451.01947021484375, 67.048828125, -0.4482572...        2182.569100
# 2  [-406.5633239746094, 28.609004974365234, -5.31...        2964.378675
# 3  [-386.34002685546875, 53.43965530395508, -8.66...        2636.422929
# 4  [-404.7848815917969, 54.46256637573242, 3.3552...        2330.168832
#
#    Spectral Bandwidth  Spectral Rolloff  \
# 0         2417.499675       4023.786502
# 1         2405.502339       3817.591309
# 2         2675.259261       5331.541280
# 3         2515.913088       4431.942332
# 4         2432.395141       4295.259839
#
#                                       Spectral Flux    Energy       ZCR  \
# 0    (7.856366210035048e-06-8.686884029884823e-07j)  0.041406  0.081048
# 1    (7.408749752357835e-06-2.919421149272239e-07j)  0.022364  0.085180
# 2  (-3.4756992590700975e-06-8.736076779314317e-06j)  0.029732  0.127679
# 3  (-1.4807430943619693e-06-3.374229663677397e-06j)  0.043054  0.105919
# 4    (5.316106125974329e-06+1.038062237057602e-05j)  0.030544  0.076019
#
#         Tempo  Stress
# 0  143.050781       9
# 1  130.046165       9
# 2  143.050781       9
# 3   95.367188       9
# 4  110.039062       9

# %% [markdown]
# # preprocess

# %%
# Check if any column contains NaN or null values
df.isnull().any()
# Out:
# Pitch                 False
# Intensity             False
# Frequency             False
# Amplitude             False
# MFCCs                 False
# Spectral Centroid     False
# Spectral Bandwidth    False
# Spectral Rolloff      False
# Spectral Flux         False
# Energy                False
# ZCR                   False
# Tempo                 False
# Stress                False
# dtype: bool

# %%
import ast
def average_mfcc(mfcc_str):
    # Convert the string representation of list to actual list
    mfcc_list = ast.literal_eval(mfcc_str)
    # Calculate the average of the list
    return np.mean(mfcc_list)

df['MFCCs'] = df['MFCCs'].apply(average_mfcc)

# %%
# Convert the 'Spectral Flux' column to complex numbers if they are in string format
df['Spectral Flux'] = df['Spectral Flux'].apply(lambda x: complex(x) if isinstance(x, str) else x)

# Now calculate the magnitude (absolute value) of the complex numbers
df['Spectral Flux Magnitude'] = df['Spectral Flux'].apply(lambda x: abs(x))

# %%
# Drop the 'Spectral Flux' column from the DataFrame
df = df.drop(columns=['Spectral Flux'])

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize label encoder
label_encoder = LabelEncoder()

# Encode the 'Stress' column
df['Stress'] = label_encoder.fit_transform(df['Stress'])

# Check the encoding
print(df['Stress'])
print(df['Stress'].unique())
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 2795    2
# 2796    2
# 2797    2
# 2798    2
# 2799    2
# Name: Stress, Length: 2800, dtype: int64
# [6 4 5 1 0 3 2]

# %%
#data split
X = df.drop(columns=['Stress'])
y = df['Stress']

# %%
from sklearn.feature_selection import SelectKBest, f_classif
# Step 2: Perform Feature Selection (Select top 8 features using ANOVA F-statistic)
selector = SelectKBest(score_func=f_classif, k='all')  # 'k=all' to keep all features
X_selected = selector.fit_transform(X, y)

# Step 3: Get the feature scores and normalize them to get percentages
feature_scores = selector.scores_
max_score = max(feature_scores)
feature_scores_percentage = [score / max_score * 100 for score in feature_scores]

# Step 4: Create a DataFrame to show feature scores and percentages
selected_features_df = pd.DataFrame({
    'Feature': X.columns,
    'Score': feature_scores,
    'Score Percentage': feature_scores_percentage
})

# Display the selected features and their importance
print("Feature Importance (Percentage):\n", selected_features_df)

# Step 5: Visualization (Bar plot of feature importance)
plt.figure(figsize=(10, 6))
plt.barh(selected_features_df['Feature'], selected_features_df['Score Percentage'], color='skyblue')
plt.xlabel('Importance (%)')
plt.title('Feature Importance Based on ANOVA F-Statistic')
plt.show()
# Out:
# Feature Importance (Percentage):
#                      Feature       Score  Score Percentage
# 0                     Pitch  109.533977         46.558552
# 1                 Intensity  201.722409         85.744200
# 2                 Frequency  109.533977         46.558552
# 3                 Amplitude  235.260704        100.000000
# 4                     MFCCs   24.063334         10.228369
# 5         Spectral Centroid   91.840289         39.037666
# 6        Spectral Bandwidth   94.941430         40.355839
# 7          Spectral Rolloff  114.462450         48.653450
# 8                    Energy  201.722409         85.744200
# 9                       ZCR   64.025727         27.214799
# 10                    Tempo   70.346124         29.901349
# 11  Spectral Flux Magnitude   14.524479          6.173780

# %%
#finalize column
# List of selected columns
selected_columns = [
    'Intensity',
    'Amplitude',
    'Spectral Centroid',
    'Spectral Bandwidth',
    'Spectral Rolloff',
    'Energy',
    'Pitch',
    'Frequency'
]

# Filter the DataFrame to keep only the selected columns
X_selected = X[selected_columns]

# Display the resulting DataFrame
print(X_selected.head())
# Out:
#    Intensity  Amplitude  Spectral Centroid  Spectral Bandwidth  \
# 0   0.041406   0.337341        2244.518922         2417.499675
# 1   0.022364   0.176117        2182.569100         2405.502339
# 2   0.029732   0.265015        2964.378675         2675.259261
# 3   0.043054   0.343719        2636.422929         2515.913088
# 4   0.030544   0.282318        2330.168832         2432.395141
#
#    Spectral Rolloff    Energy        Pitch    Frequency
# 0       4023.786502  0.041406  1410.588989  1410.588989
# 1       3817.591309  0.022364  1168.005859  1168.005859
# 2       5331.541280  0.029732  1863.138916  1863.138916
# 3       4431.942332  0.043054  1489.154175  1489.154175
# 4       4295.259839  0.030544  1090.847290  1090.847290

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
# Further split X_train into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# # traditional machine learning model

# %%
# Initialize models
svc_model = SVC(kernel='rbf', probability=True, random_state=42)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Train and evaluate models
history = {"svc": {"train_acc": [], "val_acc": []}, "rf": {"train_acc": [], "val_acc": []}}

# SVC Model
svc_model.fit(X_train, y_train)
svc_train_acc = svc_model.score(X_train, y_train)
svc_val_acc = svc_model.score(X_val, y_val)
history["svc"]["train_acc"].append(svc_train_acc)
history["svc"]["val_acc"].append(svc_val_acc)
svc_predictions = svc_model.predict(X_test)
svc_probs = svc_model.predict_proba(X_test)[:, 1]

# Random Forest Model
rf_model.fit(X_train, y_train)
rf_train_acc = rf_model.score(X_train, y_train)
rf_val_acc = rf_model.score(X_val, y_val)
history["rf"]["train_acc"].append(rf_train_acc)
history["rf"]["val_acc"].append(rf_val_acc)
rf_predictions = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
label_mapping = {0: '1', 1: '2', 2: '4', 3: '5', 4: '6', 5: '8', 6: '9'}
decoded_label_mapping = {v: k for k, v in label_mapping.items()}  # Reverse mapping for display
y_test_decoded = [label_mapping[label] for label in y_test]
svc_predictions_decoded = [label_mapping[label] for label in svc_predictions]
rf_predictions_decoded = [label_mapping[label] for label in rf_predictions]

# %%
# Classification Reports for Decoded Labels
print("SVC Classification Report (Decoded Labels):\n", classification_report(y_test_decoded, svc_predictions_decoded))
print("Random Forest Classification Report (Decoded Labels):\n", classification_report(y_test_decoded, rf_predictions_decoded))
# Out:
# SVC Classification Report (Decoded Labels):
#                precision    recall  f1-score   support
#
#            1       0.59      0.75      0.66        73
#            2       0.58      0.73      0.65        77
#            4       0.68      0.56      0.61        82
#            5       0.61      0.62      0.61        87
#            6       0.74      0.67      0.70        78
#            8       0.70      0.61      0.65        89
#            9       0.66      0.59      0.62        74
#
#     accuracy                           0.64       560
#    macro avg       0.65      0.65      0.64       560
# weighted avg       0.65      0.64      0.64       560
#
# Random Forest Classification Report (Decoded Labels):
#                precision    recall  f1-score   support
#
#            1       0.80      0.73      0.76        73
#            2       0.60      0.77      0.67        77
#            4       0.75      0.80      0.78        82
#            5       0.62      0.62      0.62        87
#            6       0.79      0.76      0.77        78
#            8       0.77      0.61      0.68        89
#            9       0.71      0.73      0.72        74
#
#     accuracy                           0.71       560
#    macro avg       0.72      0.72      0.71       560
# weighted avg       0.72      0.71      0.71       560

# %%
# Confusion Matrices for Decoded Labels
svc_cm_decoded = confusion_matrix(y_test_decoded, svc_predictions_decoded, labels=list(label_mapping.values()))
rf_cm_decoded = confusion_matrix(y_test_decoded, rf_predictions_decoded, labels=list(label_mapping.values()))

# %%
# Plot Confusion Matrices for Decoded Labels
plt.figure(figsize=(12, 5))

# SVC Confusion Matrix
plt.subplot(1, 2, 1)
sns.heatmap(svc_cm_decoded, annot=True, fmt='d', cmap="Blues", 
            xticklabels=list(label_mapping.values()), yticklabels=list(label_mapping.values()))
plt.title("SVC Confusion Matrix (Decoded Labels)")
plt.xlabel("Predicted")
plt.ylabel("True")

# Random Forest Confusion Matrix
plt.subplot(1, 2, 2)
sns.heatmap(rf_cm_decoded, annot=True, fmt='d', cmap="Blues", 
            xticklabels=list(label_mapping.values()), yticklabels=list(label_mapping.values()))
plt.title("Random Forest Confusion Matrix (Decoded Labels)")
plt.xlabel("Predicted")
plt.ylabel("True")

plt.tight_layout()
plt.show()

# %%
# # Classification Reports
# print("SVC Classification Report:\n", classification_report(y_test, svc_predictions))
# print("Random Forest Classification Report:\n", classification_report(y_test, rf_predictions))

# %%
# # Confusion Matrices
# svc_cm = confusion_matrix(y_test, svc_predictions)
# rf_cm = confusion_matrix(y_test, rf_predictions)

# %%
# # Plot Confusion Matrices
# plt.figure(figsize=(12, 5))
# plt.subplot(1, 2, 1)
# sns.heatmap(svc_cm, annot=True, fmt='d', cmap="Blues")
# plt.title("SVC Confusion Matrix")
# plt.xlabel("Predicted")
# plt.ylabel("True")

# plt.subplot(1, 2, 2)
# sns.heatmap(rf_cm, annot=True, fmt='d', cmap="Blues")
# plt.title("Random Forest Confusion Matrix")
# plt.xlabel("Predicted")
# plt.ylabel("True")
# plt.show()

# %%
import joblib

# Save SVC Model
joblib.dump(svc_model, 'svc_numerical.pkl')

# Save Random Forest Model
joblib.dump(rf_model, 'rf_numerical.pkl')
# Out:
# ['rf_numerical.pkl']

# %% [markdown]
# # CNN model

# %%
X_scaled = scaler.fit_transform(X)

print(X_scaled)
# Out:
# [[-0.47551382  0.58762502 -0.47551382 ... -1.11005622  0.76803954
#    0.37982777]
#  [-1.15943724 -0.44187184 -1.15943724 ... -1.03141218  0.2154015
#    0.31091928]
#  [ 0.80037662 -0.043507    0.80037662 ... -0.22252363  0.76803954
#    0.59057947]
#  ...
#  [-2.70469165  0.662916   -2.70469165 ...  0.41999564 -1.25829996
#   -0.41738433]
#  [-1.53234058 -0.10110286 -1.53234058 ... -0.52452091 -1.38903154
#   -0.58921565]
#  [-0.85374127 -0.05422649 -0.85374127 ...  0.25295812  1.84080751
#   -0.11823656]]

# %%
# Reshape the data for the CNN input (e.g., [batch_size, channels, height, width])
# Here, we assume 1 channel, and the features can be treated as a 2D input (for example, each row is a feature vector).

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1], 1)  # [samples, channels, feature_size, 1]
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1], 1)  # [samples, channels, feature_size, 1]

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Convert NumPy arrays and pandas Series to PyTorch tensors
X_train_tensor = torch.tensor(X_train_final, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

y_train_tensor = torch.tensor(y_train_final.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array
y_val_tensor = torch.tensor(y_val.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array
y_test_tensor = torch.tensor(y_test.to_numpy(), dtype=torch.long)  # Convert Series to NumPy array

# %%
print(f'x_train_tensor={X_train_tensor.shape}, X_val_tensor={X_val_tensor.shape}, X_test_tensor={X_test_tensor.shape}, y_train_tensor={y_train_tensor.shape}, y_val_tensor={y_val_tensor.shape},y_test_tensor={y_test_tensor.shape} ')
# Out:
# x_train_tensor=torch.Size([1433, 1, 8, 1]), X_val_tensor=torch.Size([359, 1, 8, 1]), X_test_tensor=torch.Size([560, 1, 8, 1]), y_train_tensor=torch.Size([1433]), y_val_tensor=torch.Size([359]),y_test_tensor=torch.Size([560])

# %%
X_train_tensor = X_train_tensor.view(X_train_tensor.size(0), 1,-1)  # [1792, 1, 8]
X_val_tensor = X_val_tensor.view(X_val_tensor.size(0), 1, -1)        # [448, 1, 8]
X_test_tensor = X_test_tensor.view(X_test_tensor.size(0), 1,-1)      # [560, 1, 8]# here i modify

y_train_tensor = y_train_tensor #here change
y_val_tensor = y_val_tensor 
y_test_tensor = y_test_tensor 

print(f'x_train_tensor={X_train_tensor.shape}, X_val_tensor={X_val_tensor.shape}, X_test_tensor={X_test_tensor.shape}, y_train_tensor={y_train_tensor.shape}, y_val_tensor={y_val_tensor.shape}, y_test_tensor={y_test_tensor.shape}')
# Out:
# x_train_tensor=torch.Size([1433, 1, 8]), X_val_tensor=torch.Size([359, 1, 8]), X_test_tensor=torch.Size([560, 1, 8]), y_train_tensor=torch.Size([1433]), y_val_tensor=torch.Size([359]), y_test_tensor=torch.Size([560])

# %%
print(f"Max label in y_train_tensor: {y_train_tensor.max()}")
print(f"Min label in y_train_tensor: {y_train_tensor.min()}")
# Out:
# Max label in y_train_tensor: 6
# Min label in y_train_tensor: 0

# %%
# Define the model
class StressCNN(nn.Module):
    def __init__(self, num_classes=7):  # Changed from 7 to 9
        super(StressCNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(64 * 2, 128)  # Adjusted size after calculating conv output
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, num_classes)  # This should match the number of classes

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(x)
        x = self.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Define model, loss, and optimizer
model = StressCNN(num_classes=7)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Track history
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

# Early stopping parameters
early_stop_patience = 20  # Number of epochs to wait for improvement in validation loss
best_val_loss = float('inf')
patience_counter = 0

# Training loop with validation and early stopping
for epoch in range(500):  # Train for up to 200 epochs or until early stopping
    model.train()  # Set the model to training mode
    optimizer.zero_grad()
    
    # Forward pass on training data
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    
    # Calculate training accuracy
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == y_train_tensor).sum().item()
    train_accuracy = correct / y_train_tensor.size(0) * 100

    # Validation step
    model.eval()  # Set the model to evaluation mode for validation
    with torch.no_grad():
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)
        _, val_predicted = torch.max(val_outputs, 1)
        val_correct = (val_predicted == y_val_tensor).sum().item()
        val_accuracy = val_correct / y_val_tensor.size(0) * 100

    # Store history
    history["train_loss"].append(loss.item())
    history["val_loss"].append(val_loss.item())
    history["train_acc"].append(train_accuracy)
    history["val_acc"].append(val_accuracy)

    # Print progress
    print(f"Epoch [{epoch+1}/200], Train Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss.item():.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    # Early stopping check based on validation loss
    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        patience_counter = 0  # Reset counter if improvement
    else:
        patience_counter += 1

    # Trigger early stopping if validation loss doesn't improve
    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss:.4f}")
        break
# Out:
# Epoch [1/200], Train Loss: 1.9543, Train Accuracy: 14.31%
# Validation Loss: 1.9455, Validation Accuracy: 14.21%
# Epoch [2/200], Train Loss: 1.9441, Train Accuracy: 15.00%
# Validation Loss: 1.9356, Validation Accuracy: 14.76%
# Epoch [3/200], Train Loss: 1.9315, Train Accuracy: 18.77%
# Validation Loss: 1.9260, Validation Accuracy: 18.66%
# Epoch [4/200], Train Loss: 1.9209, Train Accuracy: 22.54%
# Validation Loss: 1.9165, Validation Accuracy: 21.45%
# Epoch [5/200], Train Loss: 1.9099, Train Accuracy: 24.08%
# Validation Loss: 1.9066, Validation Accuracy: 21.73%
# Epoch [6/200], Train Loss: 1.9008, Train Accuracy: 24.21%
# Validation Loss: 1.8962, Validation Accuracy: 22.56%
# Epoch [7/200], Train Loss: 1.8885, Train Accuracy: 26.66%
# Validation Loss: 1.8852, Validation Accuracy: 23.12%
# Epoch [8/200], Train Loss: 1.8755, Train Accuracy: 27.49%
# Validation Loss: 1.8734, Validation Accuracy: 22.56%
# Epoch [9/200], Train Loss: 1.8613, Train Accuracy: 27.98%
# Validation Loss: 1.8606, Validation Accuracy: 23.40%
# Epoch [10/200], Train Loss: 1.8517, Train Accuracy: 27.29%
# Validation Loss: 1.8471, Validation Accuracy: 23.68%
# Epoch [11/200], Train Loss: 1.8360, Train Accuracy: 28.54%
# Validation Loss: 1.8327, Validation Accuracy: 23.68%
# Epoch [12/200], Train Loss: 1.8179, Train Accuracy: 29.38%
# Validation Loss: 1.8175, Validation Accuracy: 25.35%
# Epoch [13/200], Train Loss: 1.8083, Train Accuracy: 29.31%
# Validation Loss: 1.8017, Validation Accuracy: 25.35%
# Epoch [14/200], Train Loss: 1.7909, Train Accuracy: 28.82%
# Validation Loss: 1.7853, Validation Accuracy: 25.91%
# Epoch [15/200], Train Loss: 1.7657, Train Accuracy: 30.50%
# Validation Loss: 1.7686, Validation Accuracy: 27.58%
# Epoch [16/200], Train Loss: 1.7544, Train Accuracy: 30.84%
# Validation Loss: 1.7518, Validation Accuracy: 28.97%
# Epoch [17/200], Train Loss: 1.7339, Train Accuracy: 31.61%
# Validation Loss: 1.7351, Validation Accuracy: 29.81%
# Epoch [18/200], Train Loss: 1.7152, Train Accuracy: 31.96%
# Validation Loss: 1.7188, Validation Accuracy: 30.64%
# Epoch [19/200], Train Loss: 1.7007, Train Accuracy: 31.26%
# Validation Loss: 1.7035, Validation Accuracy: 31.20%
# Epoch [20/200], Train Loss: 1.6832, Train Accuracy: 33.29%
# Validation Loss: 1.6895, Validation Accuracy: 32.03%
# Epoch [21/200], Train Loss: 1.6631, Train Accuracy: 33.91%
# Validation Loss: 1.6766, Validation Accuracy: 32.59%
# Epoch [22/200], Train Loss: 1.6505, Train Accuracy: 34.12%
# Validation Loss: 1.6649, Validation Accuracy: 32.87%
# Epoch [23/200], Train Loss: 1.6369, Train Accuracy: 34.54%
# Validation Loss: 1.6544, Validation Accuracy: 33.15%
# Epoch [24/200], Train Loss: 1.6249, Train Accuracy: 34.05%
# Validation Loss: 1.6446, Validation Accuracy: 35.65%
# Epoch [25/200], Train Loss: 1.6108, Train Accuracy: 34.33%
# Validation Loss: 1.6351, Validation Accuracy: 35.65%
# Epoch [26/200], Train Loss: 1.6052, Train Accuracy: 35.31%
# Validation Loss: 1.6259, Validation Accuracy: 34.82%
# Epoch [27/200], Train Loss: 1.6001, Train Accuracy: 34.33%
# Validation Loss: 1.6163, Validation Accuracy: 35.10%
# Epoch [28/200], Train Loss: 1.5753, Train Accuracy: 37.33%
# Validation Loss: 1.6063, Validation Accuracy: 35.93%
# Epoch [29/200], Train Loss: 1.5759, Train Accuracy: 37.19%
# Validation Loss: 1.5951, Validation Accuracy: 37.05%
# Epoch [30/200], Train Loss: 1.5484, Train Accuracy: 38.45%
# Validation Loss: 1.5831, Validation Accuracy: 37.88%
# Epoch [31/200], Train Loss: 1.5409, Train Accuracy: 38.03%
# Validation Loss: 1.5710, Validation Accuracy: 37.88%
# Epoch [32/200], Train Loss: 1.5349, Train Accuracy: 39.57%
# Validation Loss: 1.5585, Validation Accuracy: 38.72%
# Epoch [33/200], Train Loss: 1.5235, Train Accuracy: 38.59%
# Validation Loss: 1.5462, Validation Accuracy: 39.83%
# Epoch [34/200], Train Loss: 1.4978, Train Accuracy: 42.22%
# Validation Loss: 1.5341, Validation Accuracy: 40.39%
# Epoch [35/200], Train Loss: 1.4902, Train Accuracy: 39.50%
# Validation Loss: 1.5221, Validation Accuracy: 41.23%
# Epoch [36/200], Train Loss: 1.4880, Train Accuracy: 41.87%
# Validation Loss: 1.5097, Validation Accuracy: 41.78%
# Epoch [37/200], Train Loss: 1.4868, Train Accuracy: 41.87%
# Validation Loss: 1.4974, Validation Accuracy: 42.90%
# Epoch [38/200], Train Loss: 1.4613, Train Accuracy: 41.94%
# Validation Loss: 1.4858, Validation Accuracy: 43.18%
# Epoch [39/200], Train Loss: 1.4495, Train Accuracy: 44.94%
# Validation Loss: 1.4740, Validation Accuracy: 43.18%
# Epoch [40/200], Train Loss: 1.4352, Train Accuracy: 43.48%
# Validation Loss: 1.4623, Validation Accuracy: 44.57%
# Epoch [41/200], Train Loss: 1.4122, Train Accuracy: 45.36%
# Validation Loss: 1.4503, Validation Accuracy: 45.40%
# Epoch [42/200], Train Loss: 1.4087, Train Accuracy: 47.45%
# Validation Loss: 1.4387, Validation Accuracy: 45.13%
# Epoch [43/200], Train Loss: 1.3964, Train Accuracy: 46.89%
# Validation Loss: 1.4275, Validation Accuracy: 45.40%
# Epoch [44/200], Train Loss: 1.3913, Train Accuracy: 48.22%
# Validation Loss: 1.4160, Validation Accuracy: 45.13%
# Epoch [45/200], Train Loss: 1.3867, Train Accuracy: 45.85%
# Validation Loss: 1.4047, Validation Accuracy: 47.08%
# Epoch [46/200], Train Loss: 1.3724, Train Accuracy: 48.50%
# Validation Loss: 1.3933, Validation Accuracy: 47.35%
# Epoch [47/200], Train Loss: 1.3645, Train Accuracy: 49.34%
# Validation Loss: 1.3818, Validation Accuracy: 47.63%
# Epoch [48/200], Train Loss: 1.3545, Train Accuracy: 48.43%
# Validation Loss: 1.3707, Validation Accuracy: 47.91%
# Epoch [49/200], Train Loss: 1.3384, Train Accuracy: 49.69%
# Validation Loss: 1.3601, Validation Accuracy: 49.03%
# Epoch [50/200], Train Loss: 1.3234, Train Accuracy: 48.57%
# Validation Loss: 1.3503, Validation Accuracy: 48.75%
# Epoch [51/200], Train Loss: 1.3136, Train Accuracy: 50.45%
# Validation Loss: 1.3410, Validation Accuracy: 48.75%
# Epoch [52/200], Train Loss: 1.3074, Train Accuracy: 51.22%
# Validation Loss: 1.3319, Validation Accuracy: 49.30%
# Epoch [53/200], Train Loss: 1.3110, Train Accuracy: 51.08%
# Validation Loss: 1.3232, Validation Accuracy: 49.86%
# Epoch [54/200], Train Loss: 1.2751, Train Accuracy: 51.85%
# Validation Loss: 1.3150, Validation Accuracy: 50.70%
# Epoch [55/200], Train Loss: 1.2783, Train Accuracy: 52.06%
# Validation Loss: 1.3063, Validation Accuracy: 50.97%
# Epoch [56/200], Train Loss: 1.2917, Train Accuracy: 51.71%
# Validation Loss: 1.2971, Validation Accuracy: 51.53%
# Epoch [57/200], Train Loss: 1.2415, Train Accuracy: 54.36%
# Validation Loss: 1.2872, Validation Accuracy: 50.70%
# Epoch [58/200], Train Loss: 1.2478, Train Accuracy: 53.04%
# Validation Loss: 1.2777, Validation Accuracy: 51.25%
# Epoch [59/200], Train Loss: 1.2363, Train Accuracy: 53.94%
# Validation Loss: 1.2694, Validation Accuracy: 51.25%
# Epoch [60/200], Train Loss: 1.2334, Train Accuracy: 53.45%
# Validation Loss: 1.2615, Validation Accuracy: 50.97%
# Epoch [61/200], Train Loss: 1.2250, Train Accuracy: 52.62%
# Validation Loss: 1.2545, Validation Accuracy: 51.25%
# Epoch [62/200], Train Loss: 1.2221, Train Accuracy: 55.27%
# Validation Loss: 1.2472, Validation Accuracy: 51.53%
# Epoch [63/200], Train Loss: 1.2044, Train Accuracy: 55.20%
# Validation Loss: 1.2394, Validation Accuracy: 51.81%
# Epoch [64/200], Train Loss: 1.1982, Train Accuracy: 56.04%
# Validation Loss: 1.2290, Validation Accuracy: 51.81%
# Epoch [65/200], Train Loss: 1.2069, Train Accuracy: 54.99%
# Validation Loss: 1.2199, Validation Accuracy: 52.65%
# Epoch [66/200], Train Loss: 1.1673, Train Accuracy: 56.80%
# Validation Loss: 1.2119, Validation Accuracy: 52.92%
# Epoch [67/200], Train Loss: 1.1703, Train Accuracy: 55.83%
# Validation Loss: 1.2050, Validation Accuracy: 53.48%
# Epoch [68/200], Train Loss: 1.1717, Train Accuracy: 55.34%
# Validation Loss: 1.1994, Validation Accuracy: 53.48%
# Epoch [69/200], Train Loss: 1.1358, Train Accuracy: 56.87%
# Validation Loss: 1.1926, Validation Accuracy: 53.48%
# Epoch [70/200], Train Loss: 1.1505, Train Accuracy: 57.01%
# Validation Loss: 1.1852, Validation Accuracy: 52.92%
# Epoch [71/200], Train Loss: 1.1409, Train Accuracy: 56.04%
# Validation Loss: 1.1773, Validation Accuracy: 53.48%
# Epoch [72/200], Train Loss: 1.1250, Train Accuracy: 57.36%
# Validation Loss: 1.1690, Validation Accuracy: 54.04%
# Epoch [73/200], Train Loss: 1.1187, Train Accuracy: 58.83%
# Validation Loss: 1.1611, Validation Accuracy: 54.60%
# Epoch [74/200], Train Loss: 1.1202, Train Accuracy: 57.71%
# Validation Loss: 1.1547, Validation Accuracy: 55.71%
# Epoch [75/200], Train Loss: 1.1148, Train Accuracy: 57.92%
# Validation Loss: 1.1497, Validation Accuracy: 55.71%
# Epoch [76/200], Train Loss: 1.1099, Train Accuracy: 58.27%
# Validation Loss: 1.1461, Validation Accuracy: 55.43%
# Epoch [77/200], Train Loss: 1.0846, Train Accuracy: 58.83%
# Validation Loss: 1.1419, Validation Accuracy: 55.15%
# Epoch [78/200], Train Loss: 1.0878, Train Accuracy: 59.67%
# Validation Loss: 1.1349, Validation Accuracy: 55.15%
# Epoch [79/200], Train Loss: 1.0953, Train Accuracy: 58.90%
# Validation Loss: 1.1271, Validation Accuracy: 56.27%
# Epoch [80/200], Train Loss: 1.0788, Train Accuracy: 60.36%
# Validation Loss: 1.1209, Validation Accuracy: 56.55%
# Epoch [81/200], Train Loss: 1.0714, Train Accuracy: 58.69%
# Validation Loss: 1.1140, Validation Accuracy: 56.55%
# Epoch [82/200], Train Loss: 1.0849, Train Accuracy: 60.43%
# Validation Loss: 1.1087, Validation Accuracy: 56.82%
# Epoch [83/200], Train Loss: 1.0791, Train Accuracy: 58.06%
# Validation Loss: 1.1027, Validation Accuracy: 56.82%
# Epoch [84/200], Train Loss: 1.0410, Train Accuracy: 59.73%
# Validation Loss: 1.0961, Validation Accuracy: 57.10%
# Epoch [85/200], Train Loss: 1.0468, Train Accuracy: 60.57%
# Validation Loss: 1.0887, Validation Accuracy: 57.38%
# Epoch [86/200], Train Loss: 1.0234, Train Accuracy: 61.83%
# Validation Loss: 1.0845, Validation Accuracy: 57.94%
# Epoch [87/200], Train Loss: 1.0375, Train Accuracy: 61.20%
# Validation Loss: 1.0813, Validation Accuracy: 57.94%
# Epoch [88/200], Train Loss: 1.0285, Train Accuracy: 61.20%
# Validation Loss: 1.0749, Validation Accuracy: 58.22%
# Epoch [89/200], Train Loss: 1.0319, Train Accuracy: 60.78%
# Validation Loss: 1.0686, Validation Accuracy: 58.50%
# Epoch [90/200], Train Loss: 1.0199, Train Accuracy: 61.69%
# Validation Loss: 1.0626, Validation Accuracy: 58.77%
# Epoch [91/200], Train Loss: 1.0014, Train Accuracy: 62.81%
# Validation Loss: 1.0549, Validation Accuracy: 59.61%
# Epoch [92/200], Train Loss: 1.0104, Train Accuracy: 61.41%
# Validation Loss: 1.0490, Validation Accuracy: 59.89%
# Epoch [93/200], Train Loss: 0.9909, Train Accuracy: 63.29%
# Validation Loss: 1.0468, Validation Accuracy: 59.61%
# Epoch [94/200], Train Loss: 0.9916, Train Accuracy: 63.92%
# Validation Loss: 1.0403, Validation Accuracy: 59.33%
# Epoch [95/200], Train Loss: 0.9936, Train Accuracy: 61.90%
# Validation Loss: 1.0347, Validation Accuracy: 59.61%
# Epoch [96/200], Train Loss: 0.9933, Train Accuracy: 62.67%
# Validation Loss: 1.0316, Validation Accuracy: 59.89%
# Epoch [97/200], Train Loss: 0.9855, Train Accuracy: 63.01%
# Validation Loss: 1.0270, Validation Accuracy: 59.61%
# Epoch [98/200], Train Loss: 0.9699, Train Accuracy: 63.99%
# Validation Loss: 1.0216, Validation Accuracy: 60.17%
# Epoch [99/200], Train Loss: 0.9794, Train Accuracy: 62.60%
# Validation Loss: 1.0159, Validation Accuracy: 59.33%
# Epoch [100/200], Train Loss: 0.9542, Train Accuracy: 63.57%
# Validation Loss: 1.0101, Validation Accuracy: 60.17%
# Epoch [101/200], Train Loss: 0.9629, Train Accuracy: 64.20%
# Validation Loss: 1.0068, Validation Accuracy: 60.45%
# Epoch [102/200], Train Loss: 0.9371, Train Accuracy: 64.48%
# Validation Loss: 1.0028, Validation Accuracy: 61.00%
# Epoch [103/200], Train Loss: 0.9387, Train Accuracy: 65.39%
# Validation Loss: 0.9987, Validation Accuracy: 61.28%
# Epoch [104/200], Train Loss: 0.9414, Train Accuracy: 64.90%
# Validation Loss: 0.9936, Validation Accuracy: 60.45%
# Epoch [105/200], Train Loss: 0.9411, Train Accuracy: 64.62%
# Validation Loss: 0.9868, Validation Accuracy: 60.72%
# Epoch [106/200], Train Loss: 0.9314, Train Accuracy: 64.97%
# Validation Loss: 0.9814, Validation Accuracy: 61.00%
# Epoch [107/200], Train Loss: 0.9294, Train Accuracy: 65.88%
# Validation Loss: 0.9767, Validation Accuracy: 61.00%
# Epoch [108/200], Train Loss: 0.9245, Train Accuracy: 65.46%
# Validation Loss: 0.9707, Validation Accuracy: 61.84%
# Epoch [109/200], Train Loss: 0.9157, Train Accuracy: 66.50%
# Validation Loss: 0.9655, Validation Accuracy: 62.95%
# Epoch [110/200], Train Loss: 0.9094, Train Accuracy: 65.74%
# Validation Loss: 0.9599, Validation Accuracy: 64.07%
# Epoch [111/200], Train Loss: 0.9040, Train Accuracy: 67.20%
# Validation Loss: 0.9557, Validation Accuracy: 63.79%
# Epoch [112/200], Train Loss: 0.8966, Train Accuracy: 66.85%
# Validation Loss: 0.9531, Validation Accuracy: 64.35%
# Epoch [113/200], Train Loss: 0.8971, Train Accuracy: 66.64%
# Validation Loss: 0.9486, Validation Accuracy: 62.95%
# Epoch [114/200], Train Loss: 0.8936, Train Accuracy: 66.29%
# Validation Loss: 0.9427, Validation Accuracy: 62.40%
# Epoch [115/200], Train Loss: 0.8864, Train Accuracy: 66.29%
# Validation Loss: 0.9393, Validation Accuracy: 63.51%
# Epoch [116/200], Train Loss: 0.8831, Train Accuracy: 67.34%
# Validation Loss: 0.9360, Validation Accuracy: 62.95%
# Epoch [117/200], Train Loss: 0.8765, Train Accuracy: 67.83%
# Validation Loss: 0.9330, Validation Accuracy: 64.07%
# Epoch [118/200], Train Loss: 0.8780, Train Accuracy: 67.55%
# Validation Loss: 0.9272, Validation Accuracy: 65.46%
# Epoch [119/200], Train Loss: 0.8623, Train Accuracy: 67.90%
# Validation Loss: 0.9221, Validation Accuracy: 66.57%
# Epoch [120/200], Train Loss: 0.8609, Train Accuracy: 68.74%
# Validation Loss: 0.9161, Validation Accuracy: 66.57%
# Epoch [121/200], Train Loss: 0.8590, Train Accuracy: 68.18%
# Validation Loss: 0.9103, Validation Accuracy: 66.30%
# Epoch [122/200], Train Loss: 0.8432, Train Accuracy: 68.39%
# Validation Loss: 0.9086, Validation Accuracy: 64.35%
# Epoch [123/200], Train Loss: 0.8441, Train Accuracy: 68.39%
# Validation Loss: 0.9077, Validation Accuracy: 64.07%
# Epoch [124/200], Train Loss: 0.8494, Train Accuracy: 68.11%
# Validation Loss: 0.9007, Validation Accuracy: 66.02%
# Epoch [125/200], Train Loss: 0.8396, Train Accuracy: 68.95%
# Validation Loss: 0.8946, Validation Accuracy: 68.80%
# Epoch [126/200], Train Loss: 0.8435, Train Accuracy: 68.53%
# Validation Loss: 0.8895, Validation Accuracy: 69.36%
# Epoch [127/200], Train Loss: 0.8483, Train Accuracy: 68.11%
# Validation Loss: 0.8850, Validation Accuracy: 69.08%
# Epoch [128/200], Train Loss: 0.8213, Train Accuracy: 69.78%
# Validation Loss: 0.8827, Validation Accuracy: 69.36%
# Epoch [129/200], Train Loss: 0.8093, Train Accuracy: 70.06%
# Validation Loss: 0.8811, Validation Accuracy: 67.97%
# Epoch [130/200], Train Loss: 0.8011, Train Accuracy: 71.18%
# Validation Loss: 0.8768, Validation Accuracy: 67.69%
# Epoch [131/200], Train Loss: 0.8120, Train Accuracy: 69.64%
# Validation Loss: 0.8690, Validation Accuracy: 68.52%
# Epoch [132/200], Train Loss: 0.8045, Train Accuracy: 70.76%
# Validation Loss: 0.8637, Validation Accuracy: 69.08%
# Epoch [133/200], Train Loss: 0.8184, Train Accuracy: 70.06%
# Validation Loss: 0.8626, Validation Accuracy: 68.80%
# Epoch [134/200], Train Loss: 0.7970, Train Accuracy: 70.41%
# Validation Loss: 0.8595, Validation Accuracy: 69.36%
# Epoch [135/200], Train Loss: 0.8023, Train Accuracy: 71.60%
# Validation Loss: 0.8529, Validation Accuracy: 69.64%
# Epoch [136/200], Train Loss: 0.7951, Train Accuracy: 70.83%
# Validation Loss: 0.8479, Validation Accuracy: 71.31%
# Epoch [137/200], Train Loss: 0.7934, Train Accuracy: 71.11%
# Validation Loss: 0.8450, Validation Accuracy: 71.59%
# Epoch [138/200], Train Loss: 0.7954, Train Accuracy: 71.11%
# Validation Loss: 0.8436, Validation Accuracy: 71.87%
# Epoch [139/200], Train Loss: 0.7876, Train Accuracy: 71.60%
# Validation Loss: 0.8405, Validation Accuracy: 71.03%
# Epoch [140/200], Train Loss: 0.7838, Train Accuracy: 72.78%
# Validation Loss: 0.8356, Validation Accuracy: 69.92%
# Epoch [141/200], Train Loss: 0.7664, Train Accuracy: 71.46%
# Validation Loss: 0.8307, Validation Accuracy: 69.64%
# Epoch [142/200], Train Loss: 0.7663, Train Accuracy: 72.23%
# Validation Loss: 0.8249, Validation Accuracy: 69.64%
# Epoch [143/200], Train Loss: 0.7688, Train Accuracy: 72.58%
# Validation Loss: 0.8230, Validation Accuracy: 70.75%
# Epoch [144/200], Train Loss: 0.7671, Train Accuracy: 71.39%
# Validation Loss: 0.8213, Validation Accuracy: 71.31%
# Epoch [145/200], Train Loss: 0.7687, Train Accuracy: 71.11%
# Validation Loss: 0.8161, Validation Accuracy: 72.14%
# Epoch [146/200], Train Loss: 0.7661, Train Accuracy: 71.53%
# Validation Loss: 0.8129, Validation Accuracy: 72.70%
# Epoch [147/200], Train Loss: 0.7438, Train Accuracy: 72.23%
# Validation Loss: 0.8135, Validation Accuracy: 71.87%
# Epoch [148/200], Train Loss: 0.7375, Train Accuracy: 74.04%
# Validation Loss: 0.8137, Validation Accuracy: 71.59%
# Epoch [149/200], Train Loss: 0.7399, Train Accuracy: 74.32%
# Validation Loss: 0.8088, Validation Accuracy: 73.26%
# Epoch [150/200], Train Loss: 0.7470, Train Accuracy: 72.37%
# Validation Loss: 0.8048, Validation Accuracy: 72.70%
# Epoch [151/200], Train Loss: 0.7374, Train Accuracy: 73.34%
# Validation Loss: 0.7988, Validation Accuracy: 72.70%
# Epoch [152/200], Train Loss: 0.7371, Train Accuracy: 72.78%
# Validation Loss: 0.7957, Validation Accuracy: 72.98%
# Epoch [153/200], Train Loss: 0.7358, Train Accuracy: 72.64%
# Validation Loss: 0.7941, Validation Accuracy: 73.26%
# Epoch [154/200], Train Loss: 0.7256, Train Accuracy: 73.20%
# Validation Loss: 0.7917, Validation Accuracy: 73.26%
# Epoch [155/200], Train Loss: 0.7356, Train Accuracy: 73.62%
# Validation Loss: 0.7889, Validation Accuracy: 74.09%
# Epoch [156/200], Train Loss: 0.7238, Train Accuracy: 74.39%
# Validation Loss: 0.7872, Validation Accuracy: 73.82%
# Epoch [157/200], Train Loss: 0.7313, Train Accuracy: 74.04%
# Validation Loss: 0.7844, Validation Accuracy: 73.54%
# Epoch [158/200], Train Loss: 0.7234, Train Accuracy: 73.62%
# Validation Loss: 0.7812, Validation Accuracy: 73.26%
# Epoch [159/200], Train Loss: 0.7070, Train Accuracy: 76.13%
# Validation Loss: 0.7769, Validation Accuracy: 74.09%
# Epoch [160/200], Train Loss: 0.7115, Train Accuracy: 75.44%
# Validation Loss: 0.7719, Validation Accuracy: 73.54%
# Epoch [161/200], Train Loss: 0.7029, Train Accuracy: 75.16%
# Validation Loss: 0.7729, Validation Accuracy: 74.09%
# Epoch [162/200], Train Loss: 0.7049, Train Accuracy: 75.09%
# Validation Loss: 0.7731, Validation Accuracy: 74.37%
# Epoch [163/200], Train Loss: 0.6979, Train Accuracy: 74.60%
# Validation Loss: 0.7674, Validation Accuracy: 74.37%
# Epoch [164/200], Train Loss: 0.7063, Train Accuracy: 72.85%
# Validation Loss: 0.7641, Validation Accuracy: 72.98%
# Epoch [165/200], Train Loss: 0.7049, Train Accuracy: 75.02%
# Validation Loss: 0.7642, Validation Accuracy: 74.09%
# Epoch [166/200], Train Loss: 0.7006, Train Accuracy: 74.18%
# Validation Loss: 0.7675, Validation Accuracy: 74.37%
# Epoch [167/200], Train Loss: 0.6828, Train Accuracy: 75.44%
# Validation Loss: 0.7651, Validation Accuracy: 74.37%
# Epoch [168/200], Train Loss: 0.6900, Train Accuracy: 75.85%
# Validation Loss: 0.7621, Validation Accuracy: 74.65%
# Epoch [169/200], Train Loss: 0.6802, Train Accuracy: 75.51%
# Validation Loss: 0.7623, Validation Accuracy: 74.37%
# Epoch [170/200], Train Loss: 0.6887, Train Accuracy: 75.51%
# Validation Loss: 0.7628, Validation Accuracy: 74.65%
# Epoch [171/200], Train Loss: 0.6928, Train Accuracy: 75.65%
# Validation Loss: 0.7610, Validation Accuracy: 74.37%
# Epoch [172/200], Train Loss: 0.6663, Train Accuracy: 76.48%
# Validation Loss: 0.7590, Validation Accuracy: 74.37%
# Epoch [173/200], Train Loss: 0.6654, Train Accuracy: 76.06%
# Validation Loss: 0.7552, Validation Accuracy: 74.65%
# Epoch [174/200], Train Loss: 0.6695, Train Accuracy: 76.69%
# Validation Loss: 0.7501, Validation Accuracy: 74.65%
# Epoch [175/200], Train Loss: 0.6646, Train Accuracy: 76.41%
# Validation Loss: 0.7466, Validation Accuracy: 74.37%
# Epoch [176/200], Train Loss: 0.6693, Train Accuracy: 75.92%
# Validation Loss: 0.7455, Validation Accuracy: 74.65%
# Epoch [177/200], Train Loss: 0.6647, Train Accuracy: 74.39%
# Validation Loss: 0.7456, Validation Accuracy: 74.37%
# Epoch [178/200], Train Loss: 0.6557, Train Accuracy: 75.99%
# Validation Loss: 0.7417, Validation Accuracy: 74.37%
# Epoch [179/200], Train Loss: 0.6722, Train Accuracy: 74.46%
# Validation Loss: 0.7387, Validation Accuracy: 74.65%
# Epoch [180/200], Train Loss: 0.6585, Train Accuracy: 75.58%
# Validation Loss: 0.7370, Validation Accuracy: 74.93%
# Epoch [181/200], Train Loss: 0.6548, Train Accuracy: 75.44%
# Validation Loss: 0.7367, Validation Accuracy: 74.93%
# Epoch [182/200], Train Loss: 0.6605, Train Accuracy: 76.13%
# Validation Loss: 0.7356, Validation Accuracy: 74.93%
# Epoch [183/200], Train Loss: 0.6509, Train Accuracy: 76.27%
# Validation Loss: 0.7334, Validation Accuracy: 75.21%
# Epoch [184/200], Train Loss: 0.6499, Train Accuracy: 76.41%
# Validation Loss: 0.7320, Validation Accuracy: 74.93%
# Epoch [185/200], Train Loss: 0.6383, Train Accuracy: 77.11%
# Validation Loss: 0.7317, Validation Accuracy: 74.65%
# Epoch [186/200], Train Loss: 0.6521, Train Accuracy: 76.27%
# Validation Loss: 0.7333, Validation Accuracy: 74.65%
# Epoch [187/200], Train Loss: 0.6569, Train Accuracy: 75.23%
# Validation Loss: 0.7302, Validation Accuracy: 74.65%
# Epoch [188/200], Train Loss: 0.6396, Train Accuracy: 76.55%
# Validation Loss: 0.7279, Validation Accuracy: 75.21%
# Epoch [189/200], Train Loss: 0.6320, Train Accuracy: 77.04%
# Validation Loss: 0.7260, Validation Accuracy: 75.49%
# Epoch [190/200], Train Loss: 0.6399, Train Accuracy: 77.11%
# Validation Loss: 0.7293, Validation Accuracy: 75.49%
# Epoch [191/200], Train Loss: 0.6242, Train Accuracy: 77.67%
# Validation Loss: 0.7274, Validation Accuracy: 75.77%
# Epoch [192/200], Train Loss: 0.6272, Train Accuracy: 77.46%
# Validation Loss: 0.7216, Validation Accuracy: 75.21%
# Epoch [193/200], Train Loss: 0.6245, Train Accuracy: 77.95%
# Validation Loss: 0.7172, Validation Accuracy: 74.93%
# Epoch [194/200], Train Loss: 0.6359, Train Accuracy: 77.74%
# Validation Loss: 0.7159, Validation Accuracy: 75.21%
# Epoch [195/200], Train Loss: 0.6237, Train Accuracy: 77.88%
# Validation Loss: 0.7168, Validation Accuracy: 75.49%
# Epoch [196/200], Train Loss: 0.6350, Train Accuracy: 76.62%
# Validation Loss: 0.7161, Validation Accuracy: 74.65%
# Epoch [197/200], Train Loss: 0.6363, Train Accuracy: 77.88%
# Validation Loss: 0.7149, Validation Accuracy: 74.37%
# Epoch [198/200], Train Loss: 0.6176, Train Accuracy: 77.81%
# Validation Loss: 0.7139, Validation Accuracy: 74.65%
# Epoch [199/200], Train Loss: 0.6223, Train Accuracy: 78.37%
# Validation Loss: 0.7145, Validation Accuracy: 75.21%
# Epoch [200/200], Train Loss: 0.6239, Train Accuracy: 77.18%
# Validation Loss: 0.7147, Validation Accuracy: 74.93%
# Epoch [201/200], Train Loss: 0.6102, Train Accuracy: 77.46%
# Validation Loss: 0.7128, Validation Accuracy: 74.65%
# Epoch [202/200], Train Loss: 0.6265, Train Accuracy: 76.97%
# Validation Loss: 0.7082, Validation Accuracy: 74.65%
# Epoch [203/200], Train Loss: 0.5986, Train Accuracy: 78.37%
# Validation Loss: 0.7080, Validation Accuracy: 74.65%
# Epoch [204/200], Train Loss: 0.6222, Train Accuracy: 78.16%
# Validation Loss: 0.7114, Validation Accuracy: 75.21%
# Epoch [205/200], Train Loss: 0.6050, Train Accuracy: 79.20%
# Validation Loss: 0.7110, Validation Accuracy: 74.93%
# Epoch [206/200], Train Loss: 0.6037, Train Accuracy: 79.20%
# Validation Loss: 0.7067, Validation Accuracy: 76.88%
# Epoch [207/200], Train Loss: 0.6092, Train Accuracy: 79.00%
# Validation Loss: 0.7020, Validation Accuracy: 76.60%
# Epoch [208/200], Train Loss: 0.6009, Train Accuracy: 77.11%
# Validation Loss: 0.7025, Validation Accuracy: 75.21%
# Epoch [209/200], Train Loss: 0.6041, Train Accuracy: 78.09%
# Validation Loss: 0.7049, Validation Accuracy: 74.37%
# Epoch [210/200], Train Loss: 0.6059, Train Accuracy: 78.44%
# Validation Loss: 0.7025, Validation Accuracy: 74.93%
# Epoch [211/200], Train Loss: 0.6022, Train Accuracy: 78.16%
# Validation Loss: 0.7030, Validation Accuracy: 75.49%
# Epoch [212/200], Train Loss: 0.5938, Train Accuracy: 78.09%
# Validation Loss: 0.7017, Validation Accuracy: 75.49%
# Epoch [213/200], Train Loss: 0.5960, Train Accuracy: 78.37%
# Validation Loss: 0.6983, Validation Accuracy: 75.49%
# Epoch [214/200], Train Loss: 0.6022, Train Accuracy: 77.39%
# Validation Loss: 0.6948, Validation Accuracy: 75.49%
# Epoch [215/200], Train Loss: 0.5889, Train Accuracy: 79.06%
# Validation Loss: 0.6940, Validation Accuracy: 75.21%
# Epoch [216/200], Train Loss: 0.5891, Train Accuracy: 78.02%
# Validation Loss: 0.6937, Validation Accuracy: 75.77%
# Epoch [217/200], Train Loss: 0.5818, Train Accuracy: 79.62%
# Validation Loss: 0.6970, Validation Accuracy: 74.93%
# Epoch [218/200], Train Loss: 0.5840, Train Accuracy: 80.32%
# Validation Loss: 0.6963, Validation Accuracy: 74.65%
# Epoch [219/200], Train Loss: 0.5851, Train Accuracy: 78.79%
# Validation Loss: 0.6937, Validation Accuracy: 74.37%
# Epoch [220/200], Train Loss: 0.5763, Train Accuracy: 80.11%
# Validation Loss: 0.6933, Validation Accuracy: 75.49%
# Epoch [221/200], Train Loss: 0.5810, Train Accuracy: 78.23%
# Validation Loss: 0.6944, Validation Accuracy: 76.04%
# Epoch [222/200], Train Loss: 0.5836, Train Accuracy: 79.69%
# Validation Loss: 0.6938, Validation Accuracy: 74.65%
# Epoch [223/200], Train Loss: 0.5850, Train Accuracy: 78.37%
# Validation Loss: 0.6934, Validation Accuracy: 74.65%
# Epoch [224/200], Train Loss: 0.5752, Train Accuracy: 79.27%
# Validation Loss: 0.6896, Validation Accuracy: 75.49%
# Epoch [225/200], Train Loss: 0.5740, Train Accuracy: 79.20%
# Validation Loss: 0.6848, Validation Accuracy: 76.04%
# Epoch [226/200], Train Loss: 0.5760, Train Accuracy: 77.60%
# Validation Loss: 0.6868, Validation Accuracy: 76.88%
# Epoch [227/200], Train Loss: 0.5721, Train Accuracy: 81.09%
# Validation Loss: 0.6923, Validation Accuracy: 75.21%
# Epoch [228/200], Train Loss: 0.5748, Train Accuracy: 79.41%
# Validation Loss: 0.6915, Validation Accuracy: 75.21%
# Epoch [229/200], Train Loss: 0.5636, Train Accuracy: 79.55%
# Validation Loss: 0.6863, Validation Accuracy: 75.77%
# Epoch [230/200], Train Loss: 0.5697, Train Accuracy: 79.06%
# Validation Loss: 0.6846, Validation Accuracy: 76.32%
# Epoch [231/200], Train Loss: 0.5680, Train Accuracy: 79.55%
# Validation Loss: 0.6886, Validation Accuracy: 75.77%
# Epoch [232/200], Train Loss: 0.5639, Train Accuracy: 79.20%
# Validation Loss: 0.6907, Validation Accuracy: 75.49%
# Epoch [233/200], Train Loss: 0.5737, Train Accuracy: 79.83%
# Validation Loss: 0.6877, Validation Accuracy: 74.93%
# Epoch [234/200], Train Loss: 0.5467, Train Accuracy: 79.69%
# Validation Loss: 0.6857, Validation Accuracy: 74.65%
# Epoch [235/200], Train Loss: 0.5677, Train Accuracy: 79.06%
# Validation Loss: 0.6843, Validation Accuracy: 75.77%
# Epoch [236/200], Train Loss: 0.5438, Train Accuracy: 81.09%
# Validation Loss: 0.6849, Validation Accuracy: 74.93%
# Epoch [237/200], Train Loss: 0.5641, Train Accuracy: 79.20%
# Validation Loss: 0.6871, Validation Accuracy: 74.37%
# Epoch [238/200], Train Loss: 0.5527, Train Accuracy: 79.27%
# Validation Loss: 0.6885, Validation Accuracy: 74.37%
# Epoch [239/200], Train Loss: 0.5595, Train Accuracy: 80.67%
# Validation Loss: 0.6847, Validation Accuracy: 74.93%
# Epoch [240/200], Train Loss: 0.5454, Train Accuracy: 80.25%
# Validation Loss: 0.6819, Validation Accuracy: 76.04%
# Epoch [241/200], Train Loss: 0.5547, Train Accuracy: 79.83%
# Validation Loss: 0.6819, Validation Accuracy: 75.21%
# Epoch [242/200], Train Loss: 0.5563, Train Accuracy: 80.25%
# Validation Loss: 0.6870, Validation Accuracy: 75.49%
# Epoch [243/200], Train Loss: 0.5492, Train Accuracy: 79.90%
# Validation Loss: 0.6878, Validation Accuracy: 74.09%
# Epoch [244/200], Train Loss: 0.5472, Train Accuracy: 80.74%
# Validation Loss: 0.6849, Validation Accuracy: 75.77%
# Epoch [245/200], Train Loss: 0.5574, Train Accuracy: 80.46%
# Validation Loss: 0.6835, Validation Accuracy: 75.49%
# Epoch [246/200], Train Loss: 0.5380, Train Accuracy: 81.23%
# Validation Loss: 0.6835, Validation Accuracy: 76.04%
# Epoch [247/200], Train Loss: 0.5575, Train Accuracy: 80.04%
# Validation Loss: 0.6851, Validation Accuracy: 74.65%
# Epoch [248/200], Train Loss: 0.5488, Train Accuracy: 80.67%
# Validation Loss: 0.6856, Validation Accuracy: 75.21%
# Epoch [249/200], Train Loss: 0.5544, Train Accuracy: 80.53%
# Validation Loss: 0.6819, Validation Accuracy: 75.49%
# Epoch [250/200], Train Loss: 0.5478, Train Accuracy: 81.23%
# Validation Loss: 0.6805, Validation Accuracy: 76.88%
# Epoch [251/200], Train Loss: 0.5519, Train Accuracy: 79.62%
# Validation Loss: 0.6785, Validation Accuracy: 76.60%
# Epoch [252/200], Train Loss: 0.5500, Train Accuracy: 80.18%
# Validation Loss: 0.6771, Validation Accuracy: 76.32%
# Epoch [253/200], Train Loss: 0.5402, Train Accuracy: 80.74%
# Validation Loss: 0.6781, Validation Accuracy: 76.88%
# Epoch [254/200], Train Loss: 0.5499, Train Accuracy: 80.32%
# Validation Loss: 0.6800, Validation Accuracy: 74.93%
# Epoch [255/200], Train Loss: 0.5307, Train Accuracy: 80.74%
# Validation Loss: 0.6808, Validation Accuracy: 75.21%
# Epoch [256/200], Train Loss: 0.5308, Train Accuracy: 80.39%
# Validation Loss: 0.6771, Validation Accuracy: 76.60%
# Epoch [257/200], Train Loss: 0.5378, Train Accuracy: 81.44%
# Validation Loss: 0.6779, Validation Accuracy: 76.04%
# Epoch [258/200], Train Loss: 0.5340, Train Accuracy: 82.27%
# Validation Loss: 0.6818, Validation Accuracy: 75.21%
# Epoch [259/200], Train Loss: 0.5316, Train Accuracy: 80.11%
# Validation Loss: 0.6884, Validation Accuracy: 74.65%
# Epoch [260/200], Train Loss: 0.5337, Train Accuracy: 81.02%
# Validation Loss: 0.6837, Validation Accuracy: 74.65%
# Epoch [261/200], Train Loss: 0.5434, Train Accuracy: 80.74%
# Validation Loss: 0.6782, Validation Accuracy: 76.04%
# Epoch [262/200], Train Loss: 0.5307, Train Accuracy: 82.27%
# Validation Loss: 0.6768, Validation Accuracy: 76.32%
# Epoch [263/200], Train Loss: 0.5350, Train Accuracy: 80.18%
# Validation Loss: 0.6756, Validation Accuracy: 75.49%
# Epoch [264/200], Train Loss: 0.5217, Train Accuracy: 81.79%
# Validation Loss: 0.6766, Validation Accuracy: 75.49%
# Epoch [265/200], Train Loss: 0.5249, Train Accuracy: 80.81%
# Validation Loss: 0.6756, Validation Accuracy: 76.04%
# Epoch [266/200], Train Loss: 0.5103, Train Accuracy: 81.65%
# Validation Loss: 0.6736, Validation Accuracy: 76.32%
# Epoch [267/200], Train Loss: 0.5091, Train Accuracy: 82.27%
# Validation Loss: 0.6739, Validation Accuracy: 76.04%
# Epoch [268/200], Train Loss: 0.5222, Train Accuracy: 81.65%
# Validation Loss: 0.6756, Validation Accuracy: 75.49%
# Epoch [269/200], Train Loss: 0.5207, Train Accuracy: 82.07%
# Validation Loss: 0.6775, Validation Accuracy: 75.21%
# Epoch [270/200], Train Loss: 0.5132, Train Accuracy: 81.65%
# Validation Loss: 0.6793, Validation Accuracy: 75.21%
# Epoch [271/200], Train Loss: 0.5300, Train Accuracy: 80.88%
# Validation Loss: 0.6797, Validation Accuracy: 75.21%
# Epoch [272/200], Train Loss: 0.5298, Train Accuracy: 81.23%
# Validation Loss: 0.6761, Validation Accuracy: 76.04%
# Epoch [273/200], Train Loss: 0.5055, Train Accuracy: 82.97%
# Validation Loss: 0.6742, Validation Accuracy: 76.04%
# Epoch [274/200], Train Loss: 0.5162, Train Accuracy: 80.74%
# Validation Loss: 0.6768, Validation Accuracy: 75.21%
# Epoch [275/200], Train Loss: 0.5219, Train Accuracy: 82.07%
# Validation Loss: 0.6775, Validation Accuracy: 74.93%
# Epoch [276/200], Train Loss: 0.5379, Train Accuracy: 79.62%
# Validation Loss: 0.6761, Validation Accuracy: 75.49%
# Epoch [277/200], Train Loss: 0.5105, Train Accuracy: 81.72%
# Validation Loss: 0.6754, Validation Accuracy: 76.04%
# Epoch [278/200], Train Loss: 0.5388, Train Accuracy: 81.51%
# Validation Loss: 0.6736, Validation Accuracy: 76.60%
# Epoch [279/200], Train Loss: 0.5220, Train Accuracy: 80.74%
# Validation Loss: 0.6732, Validation Accuracy: 76.04%
# Epoch [280/200], Train Loss: 0.5043, Train Accuracy: 82.76%
# Validation Loss: 0.6702, Validation Accuracy: 76.04%
# Epoch [281/200], Train Loss: 0.5024, Train Accuracy: 82.69%
# Validation Loss: 0.6671, Validation Accuracy: 77.99%
# Epoch [282/200], Train Loss: 0.5042, Train Accuracy: 81.65%
# Validation Loss: 0.6680, Validation Accuracy: 77.72%
# Epoch [283/200], Train Loss: 0.4973, Train Accuracy: 81.86%
# Validation Loss: 0.6715, Validation Accuracy: 77.44%
# Epoch [284/200], Train Loss: 0.5038, Train Accuracy: 82.34%
# Validation Loss: 0.6762, Validation Accuracy: 76.88%
# Epoch [285/200], Train Loss: 0.4974, Train Accuracy: 81.79%
# Validation Loss: 0.6763, Validation Accuracy: 76.60%
# Epoch [286/200], Train Loss: 0.4980, Train Accuracy: 81.09%
# Validation Loss: 0.6757, Validation Accuracy: 76.04%
# Epoch [287/200], Train Loss: 0.5053, Train Accuracy: 82.62%
# Validation Loss: 0.6752, Validation Accuracy: 76.32%
# Epoch [288/200], Train Loss: 0.5089, Train Accuracy: 81.58%
# Validation Loss: 0.6731, Validation Accuracy: 77.44%
# Epoch [289/200], Train Loss: 0.4931, Train Accuracy: 81.44%
# Validation Loss: 0.6743, Validation Accuracy: 76.60%
# Epoch [290/200], Train Loss: 0.4856, Train Accuracy: 81.93%
# Validation Loss: 0.6766, Validation Accuracy: 75.77%
# Epoch [291/200], Train Loss: 0.4838, Train Accuracy: 83.32%
# Validation Loss: 0.6767, Validation Accuracy: 76.04%
# Epoch [292/200], Train Loss: 0.4858, Train Accuracy: 83.18%
# Validation Loss: 0.6759, Validation Accuracy: 76.60%
# Epoch [293/200], Train Loss: 0.4994, Train Accuracy: 82.69%
# Validation Loss: 0.6764, Validation Accuracy: 76.04%
# Epoch [294/200], Train Loss: 0.4834, Train Accuracy: 82.83%
# Validation Loss: 0.6801, Validation Accuracy: 76.88%
# Epoch [295/200], Train Loss: 0.5142, Train Accuracy: 81.65%
# Validation Loss: 0.6794, Validation Accuracy: 77.16%
# Epoch [296/200], Train Loss: 0.4726, Train Accuracy: 83.46%
# Validation Loss: 0.6730, Validation Accuracy: 77.72%
# Epoch [297/200], Train Loss: 0.4979, Train Accuracy: 81.65%
# Validation Loss: 0.6674, Validation Accuracy: 77.99%
# Epoch [298/200], Train Loss: 0.4761, Train Accuracy: 81.86%
# Validation Loss: 0.6679, Validation Accuracy: 78.27%
# Epoch [299/200], Train Loss: 0.4860, Train Accuracy: 82.14%
# Validation Loss: 0.6726, Validation Accuracy: 76.32%
# Epoch [300/200], Train Loss: 0.4813, Train Accuracy: 82.41%
# Validation Loss: 0.6704, Validation Accuracy: 76.88%
# Epoch [301/200], Train Loss: 0.4872, Train Accuracy: 82.48%
# Validation Loss: 0.6675, Validation Accuracy: 77.99%
# Early stopping at epoch 301. Best Validation Loss: 0.6671

# %%
torch.save(model.state_dict(), "cnn_numerical.pth")
print("Model saved to 'trained_model.pth'")
# Out:
# Model saved to 'trained_model.pth'

# %%
# Plot loss and accuracy curves
def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)
    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Accuracy")
    plt.plot(epochs, history["val_acc"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    plt.show()

plot_history(history)

# Assuming val_true and val_pred are the true and predicted labels
val_true = y_val_tensor.cpu().numpy()  
val_pred = val_predicted.cpu().numpy()  

# Label mapping
label_mapping = {0: '1', 1: '2', 2: '4', 3: '5', 4: '6', 5: '8', 6: '9'}

# Decode labels
val_true_decoded = [label_mapping[label] for label in val_true]
val_pred_decoded = [label_mapping[label] for label in val_pred]

# Classification report with mapped labels
print("\nClassification Report (Mapped Labels):\n")
print(classification_report(val_true_decoded, val_pred_decoded, target_names=list(label_mapping.values())))

# Confusion matrix with mapped labels
cm = confusion_matrix(val_true_decoded, val_pred_decoded, labels=list(label_mapping.values()))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=list(label_mapping.values()), yticklabels=list(label_mapping.values()))
plt.title("Confusion Matrix (Mapped Labels)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ROC and AUC
if len(set(val_true)) == 2:  # Binary classification
    val_probs = torch.softmax(val_outputs, dim=1)[:, 1].cpu().numpy()
    auc = roc_auc_score(val_true, val_probs)
    fpr, tpr, _ = roc_curve(val_true, val_probs)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
    plt.plot([0, 1], [0, 1], "--", color="gray")
    plt.title("ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()
else:
    print("ROC curve and AUC are only applicable for binary classification.")
# Out:
# Classification Report (Mapped Labels):
#
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88        57
#            2       0.71      0.69      0.70        52
#            4       0.87      0.82      0.84        55
#            5       0.70      0.60      0.65        50
#            6       0.78      0.81      0.80        43
#            8       0.73      0.82      0.77        50
#            9       0.80      0.79      0.80        52
#
#     accuracy                           0.78       359
#    macro avg       0.78      0.78      0.78       359
# weighted avg       0.78      0.78      0.78       359
# ROC curve and AUC are only applicable for binary classification.

# %% [markdown]
# # LSTM+ CNN

# %%
# Define the model
class LSTM_CNN_Model(nn.Module):
    def __init__(self, input_dim, hidden_dim, lstm_layers, cnn_channels, num_classes):
        super(LSTM_CNN_Model, self).__init__()

        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=lstm_layers, batch_first=True, bidirectional=True)
        self.conv1 = nn.Conv1d(in_channels=hidden_dim * 2, out_channels=cnn_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
        self.fc1 = nn.Linear(cnn_channels, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x, (hn, cn) = self.lstm(x)
        x = x.permute(0, 2, 1)
        x = self.relu(self.conv1(x))
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Initialize model, criterion, and optimizer
model = LSTM_CNN_Model(input_dim=8, hidden_dim=64, lstm_layers=2, cnn_channels=32, num_classes=7)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Track history
history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

# Early stopping parameters
early_stop_patience = 20
best_val_loss = float('inf')
patience_counter = 0

# Training loop
for epoch in range(500):
    model.train()
    optimizer.zero_grad()

    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()

    _, predicted = torch.max(outputs, 1)
    correct = (predicted == y_train_tensor).sum().item()
    train_accuracy = correct / y_train_tensor.size(0) * 100

    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val_tensor)
        val_loss = criterion(val_outputs, y_val_tensor)
        _, val_predicted = torch.max(val_outputs, 1)
        val_correct = (val_predicted == y_val_tensor).sum().item()
        val_accuracy = val_correct / y_val_tensor.size(0) * 100

    # Store history
    history["train_loss"].append(loss.item())
    history["val_loss"].append(val_loss.item())
    history["train_acc"].append(train_accuracy)
    history["val_acc"].append(val_accuracy)

    # Verbose output
    print(f"Epoch [{epoch+1}/200], Train Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss.item():.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        print(f"Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss:.4f}")
        break
# Out:
# Epoch [1/200], Train Loss: 1.9468, Train Accuracy: 14.86%
# Validation Loss: 1.9472, Validation Accuracy: 13.93%
# Epoch [2/200], Train Loss: 1.9483, Train Accuracy: 14.10%
# Validation Loss: 1.9467, Validation Accuracy: 13.93%
# Epoch [3/200], Train Loss: 1.9460, Train Accuracy: 14.65%
# Validation Loss: 1.9462, Validation Accuracy: 13.93%
# Epoch [4/200], Train Loss: 1.9470, Train Accuracy: 15.00%
# Validation Loss: 1.9457, Validation Accuracy: 13.93%
# Epoch [5/200], Train Loss: 1.9468, Train Accuracy: 14.10%
# Validation Loss: 1.9452, Validation Accuracy: 20.06%
# Epoch [6/200], Train Loss: 1.9457, Train Accuracy: 14.65%
# Validation Loss: 1.9446, Validation Accuracy: 20.33%
# Epoch [7/200], Train Loss: 1.9463, Train Accuracy: 15.49%
# Validation Loss: 1.9439, Validation Accuracy: 12.26%
# Epoch [8/200], Train Loss: 1.9437, Train Accuracy: 16.75%
# Validation Loss: 1.9432, Validation Accuracy: 11.98%
# Epoch [9/200], Train Loss: 1.9435, Train Accuracy: 14.38%
# Validation Loss: 1.9423, Validation Accuracy: 11.98%
# Epoch [10/200], Train Loss: 1.9430, Train Accuracy: 16.40%
# Validation Loss: 1.9413, Validation Accuracy: 11.98%
# Epoch [11/200], Train Loss: 1.9415, Train Accuracy: 16.12%
# Validation Loss: 1.9401, Validation Accuracy: 11.98%
# Epoch [12/200], Train Loss: 1.9384, Train Accuracy: 18.77%
# Validation Loss: 1.9387, Validation Accuracy: 11.98%
# Epoch [13/200], Train Loss: 1.9369, Train Accuracy: 19.47%
# Validation Loss: 1.9370, Validation Accuracy: 15.88%
# Epoch [14/200], Train Loss: 1.9358, Train Accuracy: 18.49%
# Validation Loss: 1.9351, Validation Accuracy: 17.55%
# Epoch [15/200], Train Loss: 1.9324, Train Accuracy: 20.94%
# Validation Loss: 1.9328, Validation Accuracy: 17.55%
# Epoch [16/200], Train Loss: 1.9309, Train Accuracy: 20.87%
# Validation Loss: 1.9301, Validation Accuracy: 17.55%
# Epoch [17/200], Train Loss: 1.9268, Train Accuracy: 21.91%
# Validation Loss: 1.9270, Validation Accuracy: 17.55%
# Epoch [18/200], Train Loss: 1.9261, Train Accuracy: 21.70%
# Validation Loss: 1.9234, Validation Accuracy: 17.55%
# Epoch [19/200], Train Loss: 1.9221, Train Accuracy: 21.70%
# Validation Loss: 1.9193, Validation Accuracy: 17.55%
# Epoch [20/200], Train Loss: 1.9158, Train Accuracy: 23.52%
# Validation Loss: 1.9148, Validation Accuracy: 17.55%
# Epoch [21/200], Train Loss: 1.9134, Train Accuracy: 22.40%
# Validation Loss: 1.9097, Validation Accuracy: 17.55%
# Epoch [22/200], Train Loss: 1.9071, Train Accuracy: 22.75%
# Validation Loss: 1.9041, Validation Accuracy: 17.55%
# Epoch [23/200], Train Loss: 1.8999, Train Accuracy: 24.21%
# Validation Loss: 1.8980, Validation Accuracy: 17.55%
# Epoch [24/200], Train Loss: 1.8937, Train Accuracy: 23.03%
# Validation Loss: 1.8913, Validation Accuracy: 17.55%
# Epoch [25/200], Train Loss: 1.8877, Train Accuracy: 24.21%
# Validation Loss: 1.8840, Validation Accuracy: 17.83%
# Epoch [26/200], Train Loss: 1.8815, Train Accuracy: 22.96%
# Validation Loss: 1.8760, Validation Accuracy: 17.83%
# Epoch [27/200], Train Loss: 1.8733, Train Accuracy: 25.12%
# Validation Loss: 1.8672, Validation Accuracy: 18.11%
# Epoch [28/200], Train Loss: 1.8625, Train Accuracy: 23.38%
# Validation Loss: 1.8577, Validation Accuracy: 17.83%
# Epoch [29/200], Train Loss: 1.8539, Train Accuracy: 22.05%
# Validation Loss: 1.8473, Validation Accuracy: 17.83%
# Epoch [30/200], Train Loss: 1.8398, Train Accuracy: 24.08%
# Validation Loss: 1.8361, Validation Accuracy: 17.83%
# Epoch [31/200], Train Loss: 1.8328, Train Accuracy: 22.54%
# Validation Loss: 1.8240, Validation Accuracy: 17.83%
# Epoch [32/200], Train Loss: 1.8181, Train Accuracy: 23.45%
# Validation Loss: 1.8113, Validation Accuracy: 19.78%
# Epoch [33/200], Train Loss: 1.8040, Train Accuracy: 22.96%
# Validation Loss: 1.7981, Validation Accuracy: 21.45%
# Epoch [34/200], Train Loss: 1.7904, Train Accuracy: 24.08%
# Validation Loss: 1.7847, Validation Accuracy: 22.01%
# Epoch [35/200], Train Loss: 1.7767, Train Accuracy: 23.52%
# Validation Loss: 1.7712, Validation Accuracy: 20.89%
# Epoch [36/200], Train Loss: 1.7614, Train Accuracy: 24.98%
# Validation Loss: 1.7581, Validation Accuracy: 20.33%
# Epoch [37/200], Train Loss: 1.7488, Train Accuracy: 23.31%
# Validation Loss: 1.7456, Validation Accuracy: 22.01%
# Epoch [38/200], Train Loss: 1.7364, Train Accuracy: 23.31%
# Validation Loss: 1.7340, Validation Accuracy: 20.33%
# Epoch [39/200], Train Loss: 1.7176, Train Accuracy: 23.31%
# Validation Loss: 1.7236, Validation Accuracy: 20.06%
# Epoch [40/200], Train Loss: 1.7035, Train Accuracy: 24.77%
# Validation Loss: 1.7145, Validation Accuracy: 20.06%
# Epoch [41/200], Train Loss: 1.6958, Train Accuracy: 23.87%
# Validation Loss: 1.7066, Validation Accuracy: 20.61%
# Epoch [42/200], Train Loss: 1.6883, Train Accuracy: 23.10%
# Validation Loss: 1.6997, Validation Accuracy: 20.06%
# Epoch [43/200], Train Loss: 1.6728, Train Accuracy: 23.38%
# Validation Loss: 1.6933, Validation Accuracy: 20.33%
# Epoch [44/200], Train Loss: 1.6604, Train Accuracy: 25.82%
# Validation Loss: 1.6873, Validation Accuracy: 21.17%
# Epoch [45/200], Train Loss: 1.6544, Train Accuracy: 25.47%
# Validation Loss: 1.6811, Validation Accuracy: 23.12%
# Epoch [46/200], Train Loss: 1.6509, Train Accuracy: 26.24%
# Validation Loss: 1.6745, Validation Accuracy: 22.01%
# Epoch [47/200], Train Loss: 1.6377, Train Accuracy: 26.38%
# Validation Loss: 1.6676, Validation Accuracy: 23.40%
# Epoch [48/200], Train Loss: 1.6253, Train Accuracy: 26.10%
# Validation Loss: 1.6604, Validation Accuracy: 24.79%
# Epoch [49/200], Train Loss: 1.6167, Train Accuracy: 26.10%
# Validation Loss: 1.6526, Validation Accuracy: 24.79%
# Epoch [50/200], Train Loss: 1.6174, Train Accuracy: 28.33%
# Validation Loss: 1.6443, Validation Accuracy: 25.91%
# Epoch [51/200], Train Loss: 1.6037, Train Accuracy: 30.22%
# Validation Loss: 1.6360, Validation Accuracy: 27.02%
# Epoch [52/200], Train Loss: 1.5884, Train Accuracy: 28.19%
# Validation Loss: 1.6275, Validation Accuracy: 27.02%
# Epoch [53/200], Train Loss: 1.5875, Train Accuracy: 29.03%
# Validation Loss: 1.6189, Validation Accuracy: 27.58%
# Epoch [54/200], Train Loss: 1.5891, Train Accuracy: 30.64%
# Validation Loss: 1.6108, Validation Accuracy: 27.86%
# Epoch [55/200], Train Loss: 1.5682, Train Accuracy: 30.08%
# Validation Loss: 1.6033, Validation Accuracy: 27.58%
# Epoch [56/200], Train Loss: 1.5593, Train Accuracy: 31.47%
# Validation Loss: 1.5968, Validation Accuracy: 27.30%
# Epoch [57/200], Train Loss: 1.5529, Train Accuracy: 32.38%
# Validation Loss: 1.5908, Validation Accuracy: 27.30%
# Epoch [58/200], Train Loss: 1.5453, Train Accuracy: 32.10%
# Validation Loss: 1.5854, Validation Accuracy: 28.69%
# Epoch [59/200], Train Loss: 1.5401, Train Accuracy: 34.68%
# Validation Loss: 1.5805, Validation Accuracy: 30.08%
# Epoch [60/200], Train Loss: 1.5361, Train Accuracy: 33.50%
# Validation Loss: 1.5761, Validation Accuracy: 30.08%
# Epoch [61/200], Train Loss: 1.5248, Train Accuracy: 34.26%
# Validation Loss: 1.5721, Validation Accuracy: 30.08%
# Epoch [62/200], Train Loss: 1.5153, Train Accuracy: 34.68%
# Validation Loss: 1.5681, Validation Accuracy: 30.36%
# Epoch [63/200], Train Loss: 1.5033, Train Accuracy: 33.78%
# Validation Loss: 1.5640, Validation Accuracy: 30.36%
# Epoch [64/200], Train Loss: 1.5062, Train Accuracy: 34.19%
# Validation Loss: 1.5597, Validation Accuracy: 30.36%
# Epoch [65/200], Train Loss: 1.4996, Train Accuracy: 34.61%
# Validation Loss: 1.5550, Validation Accuracy: 30.36%
# Epoch [66/200], Train Loss: 1.4863, Train Accuracy: 34.26%
# Validation Loss: 1.5499, Validation Accuracy: 32.59%
# Epoch [67/200], Train Loss: 1.4857, Train Accuracy: 34.96%
# Validation Loss: 1.5441, Validation Accuracy: 32.31%
# Epoch [68/200], Train Loss: 1.4754, Train Accuracy: 36.85%
# Validation Loss: 1.5373, Validation Accuracy: 33.70%
# Epoch [69/200], Train Loss: 1.4728, Train Accuracy: 37.82%
# Validation Loss: 1.5300, Validation Accuracy: 33.70%
# Epoch [70/200], Train Loss: 1.4695, Train Accuracy: 37.89%
# Validation Loss: 1.5227, Validation Accuracy: 35.10%
# Epoch [71/200], Train Loss: 1.4520, Train Accuracy: 38.24%
# Validation Loss: 1.5154, Validation Accuracy: 35.10%
# Epoch [72/200], Train Loss: 1.4375, Train Accuracy: 39.01%
# Validation Loss: 1.5087, Validation Accuracy: 36.49%
# Epoch [73/200], Train Loss: 1.4470, Train Accuracy: 38.24%
# Validation Loss: 1.5027, Validation Accuracy: 36.49%
# Epoch [74/200], Train Loss: 1.4469, Train Accuracy: 38.80%
# Validation Loss: 1.4972, Validation Accuracy: 36.49%
# Epoch [75/200], Train Loss: 1.4223, Train Accuracy: 41.03%
# Validation Loss: 1.4919, Validation Accuracy: 36.49%
# Epoch [76/200], Train Loss: 1.4263, Train Accuracy: 39.92%
# Validation Loss: 1.4868, Validation Accuracy: 36.21%
# Epoch [77/200], Train Loss: 1.4155, Train Accuracy: 40.40%
# Validation Loss: 1.4819, Validation Accuracy: 35.93%
# Epoch [78/200], Train Loss: 1.4126, Train Accuracy: 41.10%
# Validation Loss: 1.4777, Validation Accuracy: 35.93%
# Epoch [79/200], Train Loss: 1.4072, Train Accuracy: 39.01%
# Validation Loss: 1.4742, Validation Accuracy: 35.93%
# Epoch [80/200], Train Loss: 1.4041, Train Accuracy: 41.03%
# Validation Loss: 1.4711, Validation Accuracy: 35.93%
# Epoch [81/200], Train Loss: 1.3921, Train Accuracy: 42.29%
# Validation Loss: 1.4678, Validation Accuracy: 36.21%
# Epoch [82/200], Train Loss: 1.3944, Train Accuracy: 41.03%
# Validation Loss: 1.4651, Validation Accuracy: 36.77%
# Epoch [83/200], Train Loss: 1.3895, Train Accuracy: 42.43%
# Validation Loss: 1.4633, Validation Accuracy: 37.05%
# Epoch [84/200], Train Loss: 1.3949, Train Accuracy: 41.17%
# Validation Loss: 1.4608, Validation Accuracy: 37.05%
# Epoch [85/200], Train Loss: 1.3748, Train Accuracy: 42.08%
# Validation Loss: 1.4580, Validation Accuracy: 37.60%
# Epoch [86/200], Train Loss: 1.3799, Train Accuracy: 42.08%
# Validation Loss: 1.4551, Validation Accuracy: 37.05%
# Epoch [87/200], Train Loss: 1.3766, Train Accuracy: 43.13%
# Validation Loss: 1.4526, Validation Accuracy: 37.33%
# Epoch [88/200], Train Loss: 1.3650, Train Accuracy: 42.64%
# Validation Loss: 1.4502, Validation Accuracy: 37.33%
# Epoch [89/200], Train Loss: 1.3676, Train Accuracy: 43.06%
# Validation Loss: 1.4486, Validation Accuracy: 37.60%
# Epoch [90/200], Train Loss: 1.3633, Train Accuracy: 42.85%
# Validation Loss: 1.4475, Validation Accuracy: 38.16%
# Epoch [91/200], Train Loss: 1.3424, Train Accuracy: 44.17%
# Validation Loss: 1.4463, Validation Accuracy: 38.72%
# Epoch [92/200], Train Loss: 1.3494, Train Accuracy: 44.31%
# Validation Loss: 1.4441, Validation Accuracy: 38.72%
# Epoch [93/200], Train Loss: 1.3439, Train Accuracy: 44.03%
# Validation Loss: 1.4411, Validation Accuracy: 37.88%
# Epoch [94/200], Train Loss: 1.3500, Train Accuracy: 43.41%
# Validation Loss: 1.4387, Validation Accuracy: 37.33%
# Epoch [95/200], Train Loss: 1.3362, Train Accuracy: 44.87%
# Validation Loss: 1.4368, Validation Accuracy: 36.77%
# Epoch [96/200], Train Loss: 1.3359, Train Accuracy: 44.59%
# Validation Loss: 1.4342, Validation Accuracy: 37.33%
# Epoch [97/200], Train Loss: 1.3208, Train Accuracy: 44.80%
# Validation Loss: 1.4315, Validation Accuracy: 37.88%
# Epoch [98/200], Train Loss: 1.3319, Train Accuracy: 44.38%
# Validation Loss: 1.4288, Validation Accuracy: 37.05%
# Epoch [99/200], Train Loss: 1.3223, Train Accuracy: 44.87%
# Validation Loss: 1.4250, Validation Accuracy: 37.33%
# Epoch [100/200], Train Loss: 1.3394, Train Accuracy: 43.61%
# Validation Loss: 1.4213, Validation Accuracy: 36.77%
# Epoch [101/200], Train Loss: 1.3087, Train Accuracy: 45.22%
# Validation Loss: 1.4191, Validation Accuracy: 36.49%
# Epoch [102/200], Train Loss: 1.3108, Train Accuracy: 45.92%
# Validation Loss: 1.4183, Validation Accuracy: 37.33%
# Epoch [103/200], Train Loss: 1.2999, Train Accuracy: 45.22%
# Validation Loss: 1.4181, Validation Accuracy: 37.60%
# Epoch [104/200], Train Loss: 1.3038, Train Accuracy: 46.13%
# Validation Loss: 1.4181, Validation Accuracy: 37.88%
# Epoch [105/200], Train Loss: 1.3054, Train Accuracy: 46.69%
# Validation Loss: 1.4165, Validation Accuracy: 38.16%
# Epoch [106/200], Train Loss: 1.3106, Train Accuracy: 45.78%
# Validation Loss: 1.4127, Validation Accuracy: 38.16%
# Epoch [107/200], Train Loss: 1.2940, Train Accuracy: 48.01%
# Validation Loss: 1.4091, Validation Accuracy: 38.44%
# Epoch [108/200], Train Loss: 1.2953, Train Accuracy: 45.85%
# Validation Loss: 1.4060, Validation Accuracy: 37.88%
# Epoch [109/200], Train Loss: 1.2943, Train Accuracy: 46.48%
# Validation Loss: 1.4034, Validation Accuracy: 37.60%
# Epoch [110/200], Train Loss: 1.2916, Train Accuracy: 47.52%
# Validation Loss: 1.4008, Validation Accuracy: 37.60%
# Epoch [111/200], Train Loss: 1.2774, Train Accuracy: 46.27%
# Validation Loss: 1.3985, Validation Accuracy: 37.60%
# Epoch [112/200], Train Loss: 1.2856, Train Accuracy: 46.27%
# Validation Loss: 1.3956, Validation Accuracy: 37.88%
# Epoch [113/200], Train Loss: 1.2763, Train Accuracy: 46.13%
# Validation Loss: 1.3933, Validation Accuracy: 37.60%
# Epoch [114/200], Train Loss: 1.2657, Train Accuracy: 48.29%
# Validation Loss: 1.3915, Validation Accuracy: 37.33%
# Epoch [115/200], Train Loss: 1.2657, Train Accuracy: 48.50%
# Validation Loss: 1.3898, Validation Accuracy: 38.72%
# Epoch [116/200], Train Loss: 1.2639, Train Accuracy: 48.92%
# Validation Loss: 1.3868, Validation Accuracy: 39.00%
# Epoch [117/200], Train Loss: 1.2650, Train Accuracy: 47.52%
# Validation Loss: 1.3828, Validation Accuracy: 38.72%
# Epoch [118/200], Train Loss: 1.2587, Train Accuracy: 48.29%
# Validation Loss: 1.3782, Validation Accuracy: 39.55%
# Epoch [119/200], Train Loss: 1.2557, Train Accuracy: 48.78%
# Validation Loss: 1.3741, Validation Accuracy: 40.39%
# Epoch [120/200], Train Loss: 1.2452, Train Accuracy: 49.41%
# Validation Loss: 1.3699, Validation Accuracy: 41.23%
# Epoch [121/200], Train Loss: 1.2478, Train Accuracy: 49.76%
# Validation Loss: 1.3661, Validation Accuracy: 41.50%
# Epoch [122/200], Train Loss: 1.2527, Train Accuracy: 49.41%
# Validation Loss: 1.3627, Validation Accuracy: 42.34%
# Epoch [123/200], Train Loss: 1.2291, Train Accuracy: 51.78%
# Validation Loss: 1.3593, Validation Accuracy: 42.90%
# Epoch [124/200], Train Loss: 1.2371, Train Accuracy: 49.62%
# Validation Loss: 1.3558, Validation Accuracy: 43.18%
# Epoch [125/200], Train Loss: 1.2317, Train Accuracy: 49.83%
# Validation Loss: 1.3525, Validation Accuracy: 42.90%
# Epoch [126/200], Train Loss: 1.2201, Train Accuracy: 50.24%
# Validation Loss: 1.3494, Validation Accuracy: 42.06%
# Epoch [127/200], Train Loss: 1.2271, Train Accuracy: 49.55%
# Validation Loss: 1.3459, Validation Accuracy: 42.62%
# Epoch [128/200], Train Loss: 1.2184, Train Accuracy: 50.45%
# Validation Loss: 1.3422, Validation Accuracy: 42.90%
# Epoch [129/200], Train Loss: 1.2077, Train Accuracy: 50.45%
# Validation Loss: 1.3394, Validation Accuracy: 43.45%
# Epoch [130/200], Train Loss: 1.2135, Train Accuracy: 51.57%
# Validation Loss: 1.3365, Validation Accuracy: 44.29%
# Epoch [131/200], Train Loss: 1.2035, Train Accuracy: 51.71%
# Validation Loss: 1.3341, Validation Accuracy: 45.40%
# Epoch [132/200], Train Loss: 1.1898, Train Accuracy: 52.90%
# Validation Loss: 1.3309, Validation Accuracy: 46.52%
# Epoch [133/200], Train Loss: 1.2014, Train Accuracy: 51.22%
# Validation Loss: 1.3282, Validation Accuracy: 46.24%
# Epoch [134/200], Train Loss: 1.2006, Train Accuracy: 51.57%
# Validation Loss: 1.3241, Validation Accuracy: 45.96%
# Epoch [135/200], Train Loss: 1.1880, Train Accuracy: 52.06%
# Validation Loss: 1.3183, Validation Accuracy: 45.68%
# Epoch [136/200], Train Loss: 1.1912, Train Accuracy: 51.36%
# Validation Loss: 1.3136, Validation Accuracy: 45.96%
# Epoch [137/200], Train Loss: 1.1922, Train Accuracy: 52.41%
# Validation Loss: 1.3102, Validation Accuracy: 46.24%
# Epoch [138/200], Train Loss: 1.1876, Train Accuracy: 51.85%
# Validation Loss: 1.3080, Validation Accuracy: 47.63%
# Epoch [139/200], Train Loss: 1.1704, Train Accuracy: 52.41%
# Validation Loss: 1.3080, Validation Accuracy: 46.80%
# Epoch [140/200], Train Loss: 1.1793, Train Accuracy: 53.80%
# Validation Loss: 1.3060, Validation Accuracy: 46.80%
# Epoch [141/200], Train Loss: 1.1731, Train Accuracy: 52.69%
# Validation Loss: 1.3002, Validation Accuracy: 46.52%
# Epoch [142/200], Train Loss: 1.1671, Train Accuracy: 53.11%
# Validation Loss: 1.2945, Validation Accuracy: 47.63%
# Epoch [143/200], Train Loss: 1.1639, Train Accuracy: 52.76%
# Validation Loss: 1.2897, Validation Accuracy: 47.63%
# Epoch [144/200], Train Loss: 1.1482, Train Accuracy: 53.80%
# Validation Loss: 1.2859, Validation Accuracy: 47.08%
# Epoch [145/200], Train Loss: 1.1614, Train Accuracy: 53.38%
# Validation Loss: 1.2835, Validation Accuracy: 47.91%
# Epoch [146/200], Train Loss: 1.1567, Train Accuracy: 52.55%
# Validation Loss: 1.2819, Validation Accuracy: 47.63%
# Epoch [147/200], Train Loss: 1.1511, Train Accuracy: 55.90%
# Validation Loss: 1.2791, Validation Accuracy: 47.63%
# Epoch [148/200], Train Loss: 1.1430, Train Accuracy: 54.71%
# Validation Loss: 1.2734, Validation Accuracy: 47.91%
# Epoch [149/200], Train Loss: 1.1505, Train Accuracy: 54.99%
# Validation Loss: 1.2663, Validation Accuracy: 49.30%
# Epoch [150/200], Train Loss: 1.1393, Train Accuracy: 54.50%
# Validation Loss: 1.2600, Validation Accuracy: 49.30%
# Epoch [151/200], Train Loss: 1.1226, Train Accuracy: 54.71%
# Validation Loss: 1.2543, Validation Accuracy: 49.58%
# Epoch [152/200], Train Loss: 1.1169, Train Accuracy: 56.52%
# Validation Loss: 1.2509, Validation Accuracy: 50.14%
# Epoch [153/200], Train Loss: 1.1198, Train Accuracy: 56.04%
# Validation Loss: 1.2484, Validation Accuracy: 50.42%
# Epoch [154/200], Train Loss: 1.1157, Train Accuracy: 56.52%
# Validation Loss: 1.2440, Validation Accuracy: 50.70%
# Epoch [155/200], Train Loss: 1.1089, Train Accuracy: 56.94%
# Validation Loss: 1.2383, Validation Accuracy: 51.25%
# Epoch [156/200], Train Loss: 1.1030, Train Accuracy: 56.18%
# Validation Loss: 1.2323, Validation Accuracy: 52.09%
# Epoch [157/200], Train Loss: 1.1026, Train Accuracy: 57.85%
# Validation Loss: 1.2249, Validation Accuracy: 52.37%
# Epoch [158/200], Train Loss: 1.0869, Train Accuracy: 57.29%
# Validation Loss: 1.2169, Validation Accuracy: 52.37%
# Epoch [159/200], Train Loss: 1.0739, Train Accuracy: 57.64%
# Validation Loss: 1.2094, Validation Accuracy: 53.48%
# Epoch [160/200], Train Loss: 1.0938, Train Accuracy: 58.20%
# Validation Loss: 1.2021, Validation Accuracy: 53.76%
# Epoch [161/200], Train Loss: 1.0798, Train Accuracy: 57.99%
# Validation Loss: 1.1963, Validation Accuracy: 53.48%
# Epoch [162/200], Train Loss: 1.0865, Train Accuracy: 58.20%
# Validation Loss: 1.1919, Validation Accuracy: 53.20%
# Epoch [163/200], Train Loss: 1.0671, Train Accuracy: 58.62%
# Validation Loss: 1.1879, Validation Accuracy: 53.20%
# Epoch [164/200], Train Loss: 1.0595, Train Accuracy: 58.97%
# Validation Loss: 1.1816, Validation Accuracy: 53.48%
# Epoch [165/200], Train Loss: 1.0463, Train Accuracy: 60.08%
# Validation Loss: 1.1748, Validation Accuracy: 52.92%
# Epoch [166/200], Train Loss: 1.0508, Train Accuracy: 59.18%
# Validation Loss: 1.1676, Validation Accuracy: 53.76%
# Epoch [167/200], Train Loss: 1.0422, Train Accuracy: 59.46%
# Validation Loss: 1.1602, Validation Accuracy: 53.48%
# Epoch [168/200], Train Loss: 1.0388, Train Accuracy: 60.57%
# Validation Loss: 1.1522, Validation Accuracy: 53.48%
# Epoch [169/200], Train Loss: 1.0391, Train Accuracy: 60.22%
# Validation Loss: 1.1444, Validation Accuracy: 53.48%
# Epoch [170/200], Train Loss: 1.0265, Train Accuracy: 61.76%
# Validation Loss: 1.1367, Validation Accuracy: 54.04%
# Epoch [171/200], Train Loss: 1.0112, Train Accuracy: 61.62%
# Validation Loss: 1.1306, Validation Accuracy: 54.04%
# Epoch [172/200], Train Loss: 1.0117, Train Accuracy: 62.18%
# Validation Loss: 1.1250, Validation Accuracy: 54.32%
# Epoch [173/200], Train Loss: 1.0324, Train Accuracy: 61.62%
# Validation Loss: 1.1198, Validation Accuracy: 54.60%
# Epoch [174/200], Train Loss: 0.9992, Train Accuracy: 61.27%
# Validation Loss: 1.1146, Validation Accuracy: 54.87%
# Epoch [175/200], Train Loss: 1.0154, Train Accuracy: 62.88%
# Validation Loss: 1.1071, Validation Accuracy: 55.99%
# Epoch [176/200], Train Loss: 0.9942, Train Accuracy: 62.74%
# Validation Loss: 1.0983, Validation Accuracy: 57.10%
# Epoch [177/200], Train Loss: 0.9817, Train Accuracy: 62.81%
# Validation Loss: 1.0899, Validation Accuracy: 56.27%
# Epoch [178/200], Train Loss: 0.9781, Train Accuracy: 62.53%
# Validation Loss: 1.0832, Validation Accuracy: 56.82%
# Epoch [179/200], Train Loss: 0.9550, Train Accuracy: 64.06%
# Validation Loss: 1.0785, Validation Accuracy: 57.38%
# Epoch [180/200], Train Loss: 0.9609, Train Accuracy: 64.06%
# Validation Loss: 1.0726, Validation Accuracy: 57.66%
# Epoch [181/200], Train Loss: 0.9674, Train Accuracy: 63.92%
# Validation Loss: 1.0655, Validation Accuracy: 57.38%
# Epoch [182/200], Train Loss: 0.9473, Train Accuracy: 64.34%
# Validation Loss: 1.0584, Validation Accuracy: 57.10%
# Epoch [183/200], Train Loss: 0.9479, Train Accuracy: 64.62%
# Validation Loss: 1.0497, Validation Accuracy: 58.22%
# Epoch [184/200], Train Loss: 0.9561, Train Accuracy: 63.92%
# Validation Loss: 1.0416, Validation Accuracy: 58.50%
# Epoch [185/200], Train Loss: 0.9329, Train Accuracy: 65.25%
# Validation Loss: 1.0346, Validation Accuracy: 58.22%
# Epoch [186/200], Train Loss: 0.9287, Train Accuracy: 65.11%
# Validation Loss: 1.0285, Validation Accuracy: 58.22%
# Epoch [187/200], Train Loss: 0.9289, Train Accuracy: 66.36%
# Validation Loss: 1.0240, Validation Accuracy: 58.50%
# Epoch [188/200], Train Loss: 0.9265, Train Accuracy: 64.55%
# Validation Loss: 1.0132, Validation Accuracy: 59.33%
# Epoch [189/200], Train Loss: 0.9185, Train Accuracy: 65.53%
# Validation Loss: 1.0014, Validation Accuracy: 59.61%
# Epoch [190/200], Train Loss: 0.8957, Train Accuracy: 65.88%
# Validation Loss: 0.9938, Validation Accuracy: 60.17%
# Epoch [191/200], Train Loss: 0.9180, Train Accuracy: 65.25%
# Validation Loss: 0.9871, Validation Accuracy: 60.72%
# Epoch [192/200], Train Loss: 0.9053, Train Accuracy: 66.50%
# Validation Loss: 0.9837, Validation Accuracy: 62.12%
# Epoch [193/200], Train Loss: 0.8952, Train Accuracy: 66.57%
# Validation Loss: 0.9839, Validation Accuracy: 61.56%
# Epoch [194/200], Train Loss: 0.8877, Train Accuracy: 67.34%
# Validation Loss: 0.9750, Validation Accuracy: 62.67%
# Epoch [195/200], Train Loss: 0.8756, Train Accuracy: 66.99%
# Validation Loss: 0.9676, Validation Accuracy: 62.95%
# Epoch [196/200], Train Loss: 0.8822, Train Accuracy: 67.69%
# Validation Loss: 0.9625, Validation Accuracy: 62.95%
# Epoch [197/200], Train Loss: 0.8810, Train Accuracy: 66.02%
# Validation Loss: 0.9558, Validation Accuracy: 62.40%
# Epoch [198/200], Train Loss: 0.8554, Train Accuracy: 68.39%
# Validation Loss: 0.9504, Validation Accuracy: 62.67%
# Epoch [199/200], Train Loss: 0.8524, Train Accuracy: 67.83%
# Validation Loss: 0.9446, Validation Accuracy: 62.95%
# Epoch [200/200], Train Loss: 0.8481, Train Accuracy: 67.97%
# Validation Loss: 0.9378, Validation Accuracy: 63.23%
# Epoch [201/200], Train Loss: 0.8526, Train Accuracy: 67.41%
# Validation Loss: 0.9306, Validation Accuracy: 63.51%
# Epoch [202/200], Train Loss: 0.8435, Train Accuracy: 67.90%
# Validation Loss: 0.9250, Validation Accuracy: 64.35%
# Epoch [203/200], Train Loss: 0.8317, Train Accuracy: 68.67%
# Validation Loss: 0.9219, Validation Accuracy: 64.07%
# Epoch [204/200], Train Loss: 0.8413, Train Accuracy: 68.95%
# Validation Loss: 0.9184, Validation Accuracy: 64.62%
# Epoch [205/200], Train Loss: 0.8469, Train Accuracy: 68.11%
# Validation Loss: 0.9128, Validation Accuracy: 64.07%
# Epoch [206/200], Train Loss: 0.8190, Train Accuracy: 69.78%
# Validation Loss: 0.9050, Validation Accuracy: 65.18%
# Epoch [207/200], Train Loss: 0.8296, Train Accuracy: 69.50%
# Validation Loss: 0.8976, Validation Accuracy: 66.57%
# Epoch [208/200], Train Loss: 0.8122, Train Accuracy: 69.23%
# Validation Loss: 0.8929, Validation Accuracy: 66.30%
# Epoch [209/200], Train Loss: 0.8182, Train Accuracy: 69.23%
# Validation Loss: 0.8903, Validation Accuracy: 66.57%
# Epoch [210/200], Train Loss: 0.8101, Train Accuracy: 70.41%
# Validation Loss: 0.8881, Validation Accuracy: 65.74%
# Epoch [211/200], Train Loss: 0.8128, Train Accuracy: 69.30%
# Validation Loss: 0.8892, Validation Accuracy: 66.02%
# Epoch [212/200], Train Loss: 0.8033, Train Accuracy: 69.99%
# Validation Loss: 0.8903, Validation Accuracy: 65.46%
# Epoch [213/200], Train Loss: 0.7936, Train Accuracy: 70.20%
# Validation Loss: 0.8875, Validation Accuracy: 66.02%
# Epoch [214/200], Train Loss: 0.7857, Train Accuracy: 70.62%
# Validation Loss: 0.8773, Validation Accuracy: 66.30%
# Epoch [215/200], Train Loss: 0.7927, Train Accuracy: 70.69%
# Validation Loss: 0.8714, Validation Accuracy: 66.85%
# Epoch [216/200], Train Loss: 0.8017, Train Accuracy: 69.78%
# Validation Loss: 0.8674, Validation Accuracy: 67.41%
# Epoch [217/200], Train Loss: 0.7834, Train Accuracy: 69.78%
# Validation Loss: 0.8649, Validation Accuracy: 67.41%
# Epoch [218/200], Train Loss: 0.7951, Train Accuracy: 70.48%
# Validation Loss: 0.8623, Validation Accuracy: 67.69%
# Epoch [219/200], Train Loss: 0.7833, Train Accuracy: 70.83%
# Validation Loss: 0.8597, Validation Accuracy: 68.25%
# Epoch [220/200], Train Loss: 0.7775, Train Accuracy: 70.76%
# Validation Loss: 0.8572, Validation Accuracy: 68.80%
# Epoch [221/200], Train Loss: 0.7813, Train Accuracy: 69.92%
# Validation Loss: 0.8531, Validation Accuracy: 68.25%
# Epoch [222/200], Train Loss: 0.7746, Train Accuracy: 71.11%
# Validation Loss: 0.8497, Validation Accuracy: 68.25%
# Epoch [223/200], Train Loss: 0.7864, Train Accuracy: 70.55%
# Validation Loss: 0.8457, Validation Accuracy: 67.97%
# Epoch [224/200], Train Loss: 0.7699, Train Accuracy: 71.67%
# Validation Loss: 0.8413, Validation Accuracy: 68.52%
# Epoch [225/200], Train Loss: 0.7640, Train Accuracy: 72.58%
# Validation Loss: 0.8395, Validation Accuracy: 68.52%
# Epoch [226/200], Train Loss: 0.7729, Train Accuracy: 70.90%
# Validation Loss: 0.8383, Validation Accuracy: 68.25%
# Epoch [227/200], Train Loss: 0.7594, Train Accuracy: 71.04%
# Validation Loss: 0.8374, Validation Accuracy: 68.52%
# Epoch [228/200], Train Loss: 0.7539, Train Accuracy: 73.20%
# Validation Loss: 0.8348, Validation Accuracy: 68.80%
# Epoch [229/200], Train Loss: 0.7375, Train Accuracy: 72.23%
# Validation Loss: 0.8318, Validation Accuracy: 68.52%
# Epoch [230/200], Train Loss: 0.7416, Train Accuracy: 72.51%
# Validation Loss: 0.8277, Validation Accuracy: 67.97%
# Epoch [231/200], Train Loss: 0.7453, Train Accuracy: 72.71%
# Validation Loss: 0.8252, Validation Accuracy: 67.69%
# Epoch [232/200], Train Loss: 0.7435, Train Accuracy: 72.85%
# Validation Loss: 0.8229, Validation Accuracy: 68.52%
# Epoch [233/200], Train Loss: 0.7464, Train Accuracy: 72.58%
# Validation Loss: 0.8229, Validation Accuracy: 68.52%
# Epoch [234/200], Train Loss: 0.7333, Train Accuracy: 72.71%
# Validation Loss: 0.8227, Validation Accuracy: 69.36%
# Epoch [235/200], Train Loss: 0.7351, Train Accuracy: 72.64%
# Validation Loss: 0.8219, Validation Accuracy: 69.36%
# Epoch [236/200], Train Loss: 0.7374, Train Accuracy: 72.64%
# Validation Loss: 0.8203, Validation Accuracy: 70.19%
# Epoch [237/200], Train Loss: 0.7402, Train Accuracy: 72.58%
# Validation Loss: 0.8178, Validation Accuracy: 70.47%
# Epoch [238/200], Train Loss: 0.7255, Train Accuracy: 73.76%
# Validation Loss: 0.8178, Validation Accuracy: 70.75%
# Epoch [239/200], Train Loss: 0.7234, Train Accuracy: 73.20%
# Validation Loss: 0.8168, Validation Accuracy: 70.19%
# Epoch [240/200], Train Loss: 0.7337, Train Accuracy: 73.13%
# Validation Loss: 0.8153, Validation Accuracy: 69.64%
# Epoch [241/200], Train Loss: 0.7155, Train Accuracy: 72.99%
# Validation Loss: 0.8122, Validation Accuracy: 70.19%
# Epoch [242/200], Train Loss: 0.7234, Train Accuracy: 72.51%
# Validation Loss: 0.8082, Validation Accuracy: 70.47%
# Epoch [243/200], Train Loss: 0.7201, Train Accuracy: 72.44%
# Validation Loss: 0.8048, Validation Accuracy: 70.47%
# Epoch [244/200], Train Loss: 0.7103, Train Accuracy: 75.02%
# Validation Loss: 0.8023, Validation Accuracy: 70.19%
# Epoch [245/200], Train Loss: 0.7109, Train Accuracy: 74.39%
# Validation Loss: 0.8013, Validation Accuracy: 70.19%
# Epoch [246/200], Train Loss: 0.7056, Train Accuracy: 74.11%
# Validation Loss: 0.7997, Validation Accuracy: 71.03%
# Epoch [247/200], Train Loss: 0.7083, Train Accuracy: 73.62%
# Validation Loss: 0.7997, Validation Accuracy: 71.03%
# Epoch [248/200], Train Loss: 0.7080, Train Accuracy: 74.46%
# Validation Loss: 0.7990, Validation Accuracy: 71.87%
# Epoch [249/200], Train Loss: 0.6973, Train Accuracy: 73.90%
# Validation Loss: 0.7979, Validation Accuracy: 71.31%
# Epoch [250/200], Train Loss: 0.7071, Train Accuracy: 74.88%
# Validation Loss: 0.7957, Validation Accuracy: 70.19%
# Epoch [251/200], Train Loss: 0.7092, Train Accuracy: 73.62%
# Validation Loss: 0.7920, Validation Accuracy: 70.47%
# Epoch [252/200], Train Loss: 0.7062, Train Accuracy: 74.32%
# Validation Loss: 0.7896, Validation Accuracy: 71.31%
# Epoch [253/200], Train Loss: 0.6929, Train Accuracy: 74.32%
# Validation Loss: 0.7863, Validation Accuracy: 70.47%
# Epoch [254/200], Train Loss: 0.6925, Train Accuracy: 74.18%
# Validation Loss: 0.7832, Validation Accuracy: 69.64%
# Epoch [255/200], Train Loss: 0.7055, Train Accuracy: 74.04%
# Validation Loss: 0.7780, Validation Accuracy: 71.03%
# Epoch [256/200], Train Loss: 0.6777, Train Accuracy: 74.04%
# Validation Loss: 0.7737, Validation Accuracy: 71.87%
# Epoch [257/200], Train Loss: 0.6863, Train Accuracy: 75.23%
# Validation Loss: 0.7707, Validation Accuracy: 71.59%
# Epoch [258/200], Train Loss: 0.6974, Train Accuracy: 74.53%
# Validation Loss: 0.7715, Validation Accuracy: 70.75%
# Epoch [259/200], Train Loss: 0.6783, Train Accuracy: 75.16%
# Validation Loss: 0.7701, Validation Accuracy: 70.75%
# Epoch [260/200], Train Loss: 0.6774, Train Accuracy: 74.95%
# Validation Loss: 0.7701, Validation Accuracy: 72.14%
# Epoch [261/200], Train Loss: 0.6699, Train Accuracy: 76.20%
# Validation Loss: 0.7702, Validation Accuracy: 72.14%
# Epoch [262/200], Train Loss: 0.6807, Train Accuracy: 75.65%
# Validation Loss: 0.7691, Validation Accuracy: 71.59%
# Epoch [263/200], Train Loss: 0.6676, Train Accuracy: 75.02%
# Validation Loss: 0.7665, Validation Accuracy: 71.31%
# Epoch [264/200], Train Loss: 0.6753, Train Accuracy: 76.13%
# Validation Loss: 0.7625, Validation Accuracy: 70.75%
# Epoch [265/200], Train Loss: 0.6604, Train Accuracy: 74.95%
# Validation Loss: 0.7580, Validation Accuracy: 70.75%
# Epoch [266/200], Train Loss: 0.6714, Train Accuracy: 74.81%
# Validation Loss: 0.7544, Validation Accuracy: 71.87%
# Epoch [267/200], Train Loss: 0.6746, Train Accuracy: 75.02%
# Validation Loss: 0.7531, Validation Accuracy: 70.75%
# Epoch [268/200], Train Loss: 0.6669, Train Accuracy: 75.58%
# Validation Loss: 0.7541, Validation Accuracy: 70.47%
# Epoch [269/200], Train Loss: 0.6543, Train Accuracy: 76.34%
# Validation Loss: 0.7546, Validation Accuracy: 72.14%
# Epoch [270/200], Train Loss: 0.6459, Train Accuracy: 76.41%
# Validation Loss: 0.7559, Validation Accuracy: 72.98%
# Epoch [271/200], Train Loss: 0.6648, Train Accuracy: 75.58%
# Validation Loss: 0.7542, Validation Accuracy: 73.54%
# Epoch [272/200], Train Loss: 0.6524, Train Accuracy: 76.76%
# Validation Loss: 0.7537, Validation Accuracy: 73.26%
# Epoch [273/200], Train Loss: 0.6486, Train Accuracy: 76.41%
# Validation Loss: 0.7486, Validation Accuracy: 73.26%
# Epoch [274/200], Train Loss: 0.6504, Train Accuracy: 76.27%
# Validation Loss: 0.7453, Validation Accuracy: 72.98%
# Epoch [275/200], Train Loss: 0.6489, Train Accuracy: 76.48%
# Validation Loss: 0.7443, Validation Accuracy: 73.26%
# Epoch [276/200], Train Loss: 0.6481, Train Accuracy: 76.62%
# Validation Loss: 0.7421, Validation Accuracy: 72.98%
# Epoch [277/200], Train Loss: 0.6484, Train Accuracy: 76.13%
# Validation Loss: 0.7420, Validation Accuracy: 73.26%
# Epoch [278/200], Train Loss: 0.6542, Train Accuracy: 76.20%
# Validation Loss: 0.7411, Validation Accuracy: 72.70%
# Epoch [279/200], Train Loss: 0.6543, Train Accuracy: 76.34%
# Validation Loss: 0.7398, Validation Accuracy: 73.54%
# Epoch [280/200], Train Loss: 0.6406, Train Accuracy: 76.62%
# Validation Loss: 0.7362, Validation Accuracy: 74.09%
# Epoch [281/200], Train Loss: 0.6508, Train Accuracy: 76.34%
# Validation Loss: 0.7340, Validation Accuracy: 74.37%
# Epoch [282/200], Train Loss: 0.6373, Train Accuracy: 76.55%
# Validation Loss: 0.7324, Validation Accuracy: 74.09%
# Epoch [283/200], Train Loss: 0.6483, Train Accuracy: 76.69%
# Validation Loss: 0.7319, Validation Accuracy: 73.82%
# Epoch [284/200], Train Loss: 0.6314, Train Accuracy: 76.97%
# Validation Loss: 0.7323, Validation Accuracy: 73.82%
# Epoch [285/200], Train Loss: 0.6423, Train Accuracy: 76.06%
# Validation Loss: 0.7319, Validation Accuracy: 73.82%
# Epoch [286/200], Train Loss: 0.6300, Train Accuracy: 76.69%
# Validation Loss: 0.7293, Validation Accuracy: 73.82%
# Epoch [287/200], Train Loss: 0.6345, Train Accuracy: 77.32%
# Validation Loss: 0.7227, Validation Accuracy: 73.82%
# Epoch [288/200], Train Loss: 0.6266, Train Accuracy: 78.09%
# Validation Loss: 0.7189, Validation Accuracy: 74.37%
# Epoch [289/200], Train Loss: 0.6272, Train Accuracy: 77.25%
# Validation Loss: 0.7178, Validation Accuracy: 74.09%
# Epoch [290/200], Train Loss: 0.6186, Train Accuracy: 77.67%
# Validation Loss: 0.7208, Validation Accuracy: 74.37%
# Epoch [291/200], Train Loss: 0.6163, Train Accuracy: 77.39%
# Validation Loss: 0.7232, Validation Accuracy: 74.09%
# Epoch [292/200], Train Loss: 0.6144, Train Accuracy: 77.67%
# Validation Loss: 0.7245, Validation Accuracy: 73.82%
# Epoch [293/200], Train Loss: 0.6121, Train Accuracy: 77.32%
# Validation Loss: 0.7244, Validation Accuracy: 74.09%
# Epoch [294/200], Train Loss: 0.6078, Train Accuracy: 78.30%
# Validation Loss: 0.7244, Validation Accuracy: 73.26%
# Epoch [295/200], Train Loss: 0.6212, Train Accuracy: 77.67%
# Validation Loss: 0.7201, Validation Accuracy: 73.82%
# Epoch [296/200], Train Loss: 0.6258, Train Accuracy: 77.32%
# Validation Loss: 0.7190, Validation Accuracy: 74.37%
# Epoch [297/200], Train Loss: 0.6219, Train Accuracy: 77.32%
# Validation Loss: 0.7154, Validation Accuracy: 74.65%
# Epoch [298/200], Train Loss: 0.6148, Train Accuracy: 77.67%
# Validation Loss: 0.7198, Validation Accuracy: 74.09%
# Epoch [299/200], Train Loss: 0.6123, Train Accuracy: 77.11%
# Validation Loss: 0.7152, Validation Accuracy: 75.21%
# Epoch [300/200], Train Loss: 0.6135, Train Accuracy: 76.97%
# Validation Loss: 0.7132, Validation Accuracy: 74.93%
# Epoch [301/200], Train Loss: 0.6063, Train Accuracy: 78.65%
# Validation Loss: 0.7090, Validation Accuracy: 74.65%
# Epoch [302/200], Train Loss: 0.6069, Train Accuracy: 77.88%
# Validation Loss: 0.7093, Validation Accuracy: 74.09%
# Epoch [303/200], Train Loss: 0.6052, Train Accuracy: 78.72%
# Validation Loss: 0.7049, Validation Accuracy: 74.09%
# Epoch [304/200], Train Loss: 0.6009, Train Accuracy: 77.25%
# Validation Loss: 0.7034, Validation Accuracy: 74.65%
# Epoch [305/200], Train Loss: 0.6041, Train Accuracy: 76.83%
# Validation Loss: 0.7042, Validation Accuracy: 74.65%
# Epoch [306/200], Train Loss: 0.6052, Train Accuracy: 78.79%
# Validation Loss: 0.7066, Validation Accuracy: 74.37%
# Epoch [307/200], Train Loss: 0.5995, Train Accuracy: 77.67%
# Validation Loss: 0.7051, Validation Accuracy: 74.37%
# Epoch [308/200], Train Loss: 0.5772, Train Accuracy: 79.00%
# Validation Loss: 0.7047, Validation Accuracy: 74.09%
# Epoch [309/200], Train Loss: 0.6005, Train Accuracy: 77.67%
# Validation Loss: 0.7024, Validation Accuracy: 74.09%
# Epoch [310/200], Train Loss: 0.5983, Train Accuracy: 78.79%
# Validation Loss: 0.7029, Validation Accuracy: 74.65%
# Epoch [311/200], Train Loss: 0.5962, Train Accuracy: 78.65%
# Validation Loss: 0.6996, Validation Accuracy: 74.65%
# Epoch [312/200], Train Loss: 0.5818, Train Accuracy: 78.86%
# Validation Loss: 0.7009, Validation Accuracy: 74.37%
# Epoch [313/200], Train Loss: 0.5838, Train Accuracy: 78.44%
# Validation Loss: 0.7033, Validation Accuracy: 74.37%
# Epoch [314/200], Train Loss: 0.5777, Train Accuracy: 78.79%
# Validation Loss: 0.7068, Validation Accuracy: 74.65%
# Epoch [315/200], Train Loss: 0.5814, Train Accuracy: 79.20%
# Validation Loss: 0.7038, Validation Accuracy: 74.09%
# Epoch [316/200], Train Loss: 0.5768, Train Accuracy: 79.06%
# Validation Loss: 0.7025, Validation Accuracy: 74.93%
# Epoch [317/200], Train Loss: 0.5684, Train Accuracy: 79.55%
# Validation Loss: 0.6997, Validation Accuracy: 74.93%
# Epoch [318/200], Train Loss: 0.5818, Train Accuracy: 79.06%
# Validation Loss: 0.6983, Validation Accuracy: 74.93%
# Epoch [319/200], Train Loss: 0.5764, Train Accuracy: 78.58%
# Validation Loss: 0.6958, Validation Accuracy: 74.93%
# Epoch [320/200], Train Loss: 0.5630, Train Accuracy: 79.06%
# Validation Loss: 0.6952, Validation Accuracy: 75.21%
# Epoch [321/200], Train Loss: 0.5794, Train Accuracy: 79.41%
# Validation Loss: 0.6947, Validation Accuracy: 74.93%
# Epoch [322/200], Train Loss: 0.5756, Train Accuracy: 79.00%
# Validation Loss: 0.6929, Validation Accuracy: 74.93%
# Epoch [323/200], Train Loss: 0.5876, Train Accuracy: 78.16%
# Validation Loss: 0.6914, Validation Accuracy: 75.21%
# Epoch [324/200], Train Loss: 0.5629, Train Accuracy: 79.13%
# Validation Loss: 0.6886, Validation Accuracy: 75.77%
# Epoch [325/200], Train Loss: 0.5633, Train Accuracy: 80.18%
# Validation Loss: 0.6872, Validation Accuracy: 76.60%
# Epoch [326/200], Train Loss: 0.5736, Train Accuracy: 79.27%
# Validation Loss: 0.6878, Validation Accuracy: 75.49%
# Epoch [327/200], Train Loss: 0.5594, Train Accuracy: 79.69%
# Validation Loss: 0.6886, Validation Accuracy: 75.49%
# Epoch [328/200], Train Loss: 0.5703, Train Accuracy: 79.00%
# Validation Loss: 0.6856, Validation Accuracy: 75.21%
# Epoch [329/200], Train Loss: 0.5718, Train Accuracy: 79.13%
# Validation Loss: 0.6865, Validation Accuracy: 75.49%
# Epoch [330/200], Train Loss: 0.5600, Train Accuracy: 78.72%
# Validation Loss: 0.6910, Validation Accuracy: 75.49%
# Epoch [331/200], Train Loss: 0.5591, Train Accuracy: 78.72%
# Validation Loss: 0.6919, Validation Accuracy: 74.93%
# Epoch [332/200], Train Loss: 0.5686, Train Accuracy: 79.90%
# Validation Loss: 0.6935, Validation Accuracy: 74.93%
# Epoch [333/200], Train Loss: 0.5572, Train Accuracy: 79.13%
# Validation Loss: 0.6967, Validation Accuracy: 75.49%
# Epoch [334/200], Train Loss: 0.5429, Train Accuracy: 80.11%
# Validation Loss: 0.7011, Validation Accuracy: 75.49%
# Epoch [335/200], Train Loss: 0.5586, Train Accuracy: 79.62%
# Validation Loss: 0.6964, Validation Accuracy: 74.93%
# Epoch [336/200], Train Loss: 0.5574, Train Accuracy: 80.18%
# Validation Loss: 0.6909, Validation Accuracy: 74.93%
# Epoch [337/200], Train Loss: 0.5758, Train Accuracy: 78.72%
# Validation Loss: 0.6914, Validation Accuracy: 75.21%
# Epoch [338/200], Train Loss: 0.5397, Train Accuracy: 80.67%
# Validation Loss: 0.6896, Validation Accuracy: 75.49%
# Epoch [339/200], Train Loss: 0.5555, Train Accuracy: 79.55%
# Validation Loss: 0.6867, Validation Accuracy: 75.77%
# Epoch [340/200], Train Loss: 0.5449, Train Accuracy: 79.97%
# Validation Loss: 0.6867, Validation Accuracy: 76.04%
# Epoch [341/200], Train Loss: 0.5566, Train Accuracy: 79.00%
# Validation Loss: 0.6869, Validation Accuracy: 76.04%
# Epoch [342/200], Train Loss: 0.5604, Train Accuracy: 78.58%
# Validation Loss: 0.6852, Validation Accuracy: 75.77%
# Epoch [343/200], Train Loss: 0.5554, Train Accuracy: 79.90%
# Validation Loss: 0.6816, Validation Accuracy: 75.77%
# Epoch [344/200], Train Loss: 0.5379, Train Accuracy: 79.76%
# Validation Loss: 0.6814, Validation Accuracy: 75.49%
# Epoch [345/200], Train Loss: 0.5371, Train Accuracy: 81.09%
# Validation Loss: 0.6811, Validation Accuracy: 74.93%
# Epoch [346/200], Train Loss: 0.5551, Train Accuracy: 80.74%
# Validation Loss: 0.6805, Validation Accuracy: 75.49%
# Epoch [347/200], Train Loss: 0.5363, Train Accuracy: 80.46%
# Validation Loss: 0.6832, Validation Accuracy: 74.65%
# Epoch [348/200], Train Loss: 0.5382, Train Accuracy: 80.32%
# Validation Loss: 0.6842, Validation Accuracy: 74.65%
# Epoch [349/200], Train Loss: 0.5430, Train Accuracy: 79.34%
# Validation Loss: 0.6861, Validation Accuracy: 74.37%
# Epoch [350/200], Train Loss: 0.5446, Train Accuracy: 80.60%
# Validation Loss: 0.6927, Validation Accuracy: 75.21%
# Epoch [351/200], Train Loss: 0.5352, Train Accuracy: 80.88%
# Validation Loss: 0.6989, Validation Accuracy: 75.21%
# Epoch [352/200], Train Loss: 0.5258, Train Accuracy: 79.90%
# Validation Loss: 0.6929, Validation Accuracy: 75.21%
# Epoch [353/200], Train Loss: 0.5326, Train Accuracy: 80.25%
# Validation Loss: 0.6874, Validation Accuracy: 74.93%
# Epoch [354/200], Train Loss: 0.5328, Train Accuracy: 80.25%
# Validation Loss: 0.6851, Validation Accuracy: 75.49%
# Epoch [355/200], Train Loss: 0.5286, Train Accuracy: 80.95%
# Validation Loss: 0.6864, Validation Accuracy: 75.49%
# Epoch [356/200], Train Loss: 0.5359, Train Accuracy: 80.18%
# Validation Loss: 0.6770, Validation Accuracy: 75.77%
# Epoch [357/200], Train Loss: 0.5282, Train Accuracy: 79.90%
# Validation Loss: 0.6763, Validation Accuracy: 75.21%
# Epoch [358/200], Train Loss: 0.5358, Train Accuracy: 81.72%
# Validation Loss: 0.6810, Validation Accuracy: 75.49%
# Epoch [359/200], Train Loss: 0.5328, Train Accuracy: 81.02%
# Validation Loss: 0.6832, Validation Accuracy: 75.77%
# Epoch [360/200], Train Loss: 0.5312, Train Accuracy: 80.95%
# Validation Loss: 0.6830, Validation Accuracy: 75.77%
# Epoch [361/200], Train Loss: 0.5194, Train Accuracy: 79.48%
# Validation Loss: 0.6839, Validation Accuracy: 76.04%
# Epoch [362/200], Train Loss: 0.5295, Train Accuracy: 79.90%
# Validation Loss: 0.6912, Validation Accuracy: 75.77%
# Epoch [363/200], Train Loss: 0.5133, Train Accuracy: 80.74%
# Validation Loss: 0.6844, Validation Accuracy: 76.04%
# Epoch [364/200], Train Loss: 0.5204, Train Accuracy: 81.02%
# Validation Loss: 0.6854, Validation Accuracy: 74.93%
# Epoch [365/200], Train Loss: 0.5200, Train Accuracy: 80.46%
# Validation Loss: 0.6881, Validation Accuracy: 74.93%
# Epoch [366/200], Train Loss: 0.5090, Train Accuracy: 81.44%
# Validation Loss: 0.6946, Validation Accuracy: 75.21%
# Epoch [367/200], Train Loss: 0.5236, Train Accuracy: 81.02%
# Validation Loss: 0.6881, Validation Accuracy: 74.65%
# Epoch [368/200], Train Loss: 0.5282, Train Accuracy: 80.88%
# Validation Loss: 0.6838, Validation Accuracy: 74.93%
# Epoch [369/200], Train Loss: 0.5248, Train Accuracy: 80.46%
# Validation Loss: 0.6820, Validation Accuracy: 75.49%
# Epoch [370/200], Train Loss: 0.5157, Train Accuracy: 81.93%
# Validation Loss: 0.6827, Validation Accuracy: 75.77%
# Epoch [371/200], Train Loss: 0.5073, Train Accuracy: 81.16%
# Validation Loss: 0.6761, Validation Accuracy: 75.77%
# Epoch [372/200], Train Loss: 0.5203, Train Accuracy: 80.81%
# Validation Loss: 0.6750, Validation Accuracy: 76.04%
# Epoch [373/200], Train Loss: 0.5342, Train Accuracy: 81.09%
# Validation Loss: 0.6770, Validation Accuracy: 76.04%
# Epoch [374/200], Train Loss: 0.5134, Train Accuracy: 81.23%
# Validation Loss: 0.6797, Validation Accuracy: 76.32%
# Epoch [375/200], Train Loss: 0.5162, Train Accuracy: 80.67%
# Validation Loss: 0.6773, Validation Accuracy: 75.77%
# Epoch [376/200], Train Loss: 0.5174, Train Accuracy: 80.81%
# Validation Loss: 0.6770, Validation Accuracy: 75.21%
# Epoch [377/200], Train Loss: 0.5074, Train Accuracy: 81.30%
# Validation Loss: 0.6781, Validation Accuracy: 75.49%
# Epoch [378/200], Train Loss: 0.5076, Train Accuracy: 81.37%
# Validation Loss: 0.6803, Validation Accuracy: 75.21%
# Epoch [379/200], Train Loss: 0.5122, Train Accuracy: 81.09%
# Validation Loss: 0.6806, Validation Accuracy: 75.49%
# Epoch [380/200], Train Loss: 0.5120, Train Accuracy: 81.23%
# Validation Loss: 0.6789, Validation Accuracy: 75.21%
# Epoch [381/200], Train Loss: 0.5164, Train Accuracy: 80.74%
# Validation Loss: 0.6778, Validation Accuracy: 75.21%
# Epoch [382/200], Train Loss: 0.5102, Train Accuracy: 81.02%
# Validation Loss: 0.6827, Validation Accuracy: 75.49%
# Epoch [383/200], Train Loss: 0.5039, Train Accuracy: 81.37%
# Validation Loss: 0.6778, Validation Accuracy: 75.21%
# Epoch [384/200], Train Loss: 0.5070, Train Accuracy: 81.72%
# Validation Loss: 0.6779, Validation Accuracy: 75.49%
# Epoch [385/200], Train Loss: 0.4973, Train Accuracy: 81.02%
# Validation Loss: 0.6775, Validation Accuracy: 75.77%
# Epoch [386/200], Train Loss: 0.4872, Train Accuracy: 81.72%
# Validation Loss: 0.6811, Validation Accuracy: 76.04%
# Epoch [387/200], Train Loss: 0.5048, Train Accuracy: 81.51%
# Validation Loss: 0.6799, Validation Accuracy: 76.32%
# Epoch [388/200], Train Loss: 0.5016, Train Accuracy: 81.51%
# Validation Loss: 0.6771, Validation Accuracy: 76.04%
# Epoch [389/200], Train Loss: 0.5013, Train Accuracy: 81.65%
# Validation Loss: 0.6743, Validation Accuracy: 75.49%
# Epoch [390/200], Train Loss: 0.4896, Train Accuracy: 81.30%
# Validation Loss: 0.6745, Validation Accuracy: 76.32%
# Epoch [391/200], Train Loss: 0.4925, Train Accuracy: 81.44%
# Validation Loss: 0.6757, Validation Accuracy: 76.04%
# Epoch [392/200], Train Loss: 0.4956, Train Accuracy: 82.00%
# Validation Loss: 0.6753, Validation Accuracy: 76.32%
# Epoch [393/200], Train Loss: 0.5082, Train Accuracy: 81.23%
# Validation Loss: 0.6753, Validation Accuracy: 76.04%
# Epoch [394/200], Train Loss: 0.4890, Train Accuracy: 81.79%
# Validation Loss: 0.6783, Validation Accuracy: 75.77%
# Epoch [395/200], Train Loss: 0.4835, Train Accuracy: 81.79%
# Validation Loss: 0.6820, Validation Accuracy: 75.49%
# Epoch [396/200], Train Loss: 0.4934, Train Accuracy: 82.76%
# Validation Loss: 0.6797, Validation Accuracy: 75.77%
# Epoch [397/200], Train Loss: 0.4961, Train Accuracy: 82.34%
# Validation Loss: 0.6758, Validation Accuracy: 76.32%
# Epoch [398/200], Train Loss: 0.5021, Train Accuracy: 80.95%
# Validation Loss: 0.6738, Validation Accuracy: 76.60%
# Epoch [399/200], Train Loss: 0.4791, Train Accuracy: 82.00%
# Validation Loss: 0.6764, Validation Accuracy: 77.16%
# Epoch [400/200], Train Loss: 0.4904, Train Accuracy: 81.16%
# Validation Loss: 0.6726, Validation Accuracy: 76.60%
# Epoch [401/200], Train Loss: 0.4845, Train Accuracy: 81.72%
# Validation Loss: 0.6719, Validation Accuracy: 76.60%
# Epoch [402/200], Train Loss: 0.4869, Train Accuracy: 82.00%
# Validation Loss: 0.6735, Validation Accuracy: 76.60%
# Epoch [403/200], Train Loss: 0.4892, Train Accuracy: 81.86%
# Validation Loss: 0.6755, Validation Accuracy: 76.60%
# Epoch [404/200], Train Loss: 0.4687, Train Accuracy: 83.39%
# Validation Loss: 0.6743, Validation Accuracy: 76.60%
# Epoch [405/200], Train Loss: 0.4755, Train Accuracy: 83.11%
# Validation Loss: 0.6724, Validation Accuracy: 77.16%
# Epoch [406/200], Train Loss: 0.4879, Train Accuracy: 81.79%
# Validation Loss: 0.6745, Validation Accuracy: 77.72%
# Epoch [407/200], Train Loss: 0.4799, Train Accuracy: 82.00%
# Validation Loss: 0.6753, Validation Accuracy: 77.16%
# Epoch [408/200], Train Loss: 0.4847, Train Accuracy: 82.00%
# Validation Loss: 0.6730, Validation Accuracy: 77.16%
# Epoch [409/200], Train Loss: 0.4816, Train Accuracy: 82.00%
# Validation Loss: 0.6719, Validation Accuracy: 76.60%
# Epoch [410/200], Train Loss: 0.4701, Train Accuracy: 82.55%
# Validation Loss: 0.6753, Validation Accuracy: 76.04%
# Epoch [411/200], Train Loss: 0.4797, Train Accuracy: 82.41%
# Validation Loss: 0.6798, Validation Accuracy: 75.49%
# Epoch [412/200], Train Loss: 0.4708, Train Accuracy: 82.21%
# Validation Loss: 0.6830, Validation Accuracy: 76.60%
# Epoch [413/200], Train Loss: 0.4725, Train Accuracy: 83.11%
# Validation Loss: 0.6812, Validation Accuracy: 77.16%
# Epoch [414/200], Train Loss: 0.4657, Train Accuracy: 81.93%
# Validation Loss: 0.6759, Validation Accuracy: 77.16%
# Epoch [415/200], Train Loss: 0.4735, Train Accuracy: 82.07%
# Validation Loss: 0.6722, Validation Accuracy: 77.44%
# Epoch [416/200], Train Loss: 0.4751, Train Accuracy: 82.48%
# Validation Loss: 0.6696, Validation Accuracy: 76.88%
# Epoch [417/200], Train Loss: 0.4828, Train Accuracy: 81.30%
# Validation Loss: 0.6640, Validation Accuracy: 77.16%
# Epoch [418/200], Train Loss: 0.4655, Train Accuracy: 82.90%
# Validation Loss: 0.6610, Validation Accuracy: 76.88%
# Epoch [419/200], Train Loss: 0.4685, Train Accuracy: 82.55%
# Validation Loss: 0.6624, Validation Accuracy: 76.60%
# Epoch [420/200], Train Loss: 0.4684, Train Accuracy: 82.14%
# Validation Loss: 0.6695, Validation Accuracy: 76.88%
# Epoch [421/200], Train Loss: 0.4699, Train Accuracy: 82.41%
# Validation Loss: 0.6717, Validation Accuracy: 77.16%
# Epoch [422/200], Train Loss: 0.4671, Train Accuracy: 82.27%
# Validation Loss: 0.6754, Validation Accuracy: 77.16%
# Epoch [423/200], Train Loss: 0.4702, Train Accuracy: 81.58%
# Validation Loss: 0.6783, Validation Accuracy: 77.99%
# Epoch [424/200], Train Loss: 0.4745, Train Accuracy: 82.27%
# Validation Loss: 0.6903, Validation Accuracy: 77.44%
# Epoch [425/200], Train Loss: 0.4790, Train Accuracy: 81.65%
# Validation Loss: 0.6776, Validation Accuracy: 77.72%
# Epoch [426/200], Train Loss: 0.4714, Train Accuracy: 82.27%
# Validation Loss: 0.6739, Validation Accuracy: 76.60%
# Epoch [427/200], Train Loss: 0.4577, Train Accuracy: 82.69%
# Validation Loss: 0.6722, Validation Accuracy: 77.16%
# Epoch [428/200], Train Loss: 0.4705, Train Accuracy: 82.41%
# Validation Loss: 0.6761, Validation Accuracy: 76.88%
# Epoch [429/200], Train Loss: 0.4738, Train Accuracy: 82.14%
# Validation Loss: 0.6705, Validation Accuracy: 76.88%
# Epoch [430/200], Train Loss: 0.4537, Train Accuracy: 82.48%
# Validation Loss: 0.6691, Validation Accuracy: 76.88%
# Epoch [431/200], Train Loss: 0.4777, Train Accuracy: 82.14%
# Validation Loss: 0.6711, Validation Accuracy: 77.16%
# Epoch [432/200], Train Loss: 0.4744, Train Accuracy: 82.55%
# Validation Loss: 0.6750, Validation Accuracy: 77.44%
# Epoch [433/200], Train Loss: 0.4517, Train Accuracy: 82.48%
# Validation Loss: 0.6777, Validation Accuracy: 77.16%
# Epoch [434/200], Train Loss: 0.4799, Train Accuracy: 82.62%
# Validation Loss: 0.6690, Validation Accuracy: 78.27%
# Epoch [435/200], Train Loss: 0.4691, Train Accuracy: 82.76%
# Validation Loss: 0.6676, Validation Accuracy: 78.83%
# Epoch [436/200], Train Loss: 0.4640, Train Accuracy: 82.69%
# Validation Loss: 0.6664, Validation Accuracy: 78.27%
# Epoch [437/200], Train Loss: 0.4649, Train Accuracy: 82.48%
# Validation Loss: 0.6735, Validation Accuracy: 77.99%
# Epoch [438/200], Train Loss: 0.4518, Train Accuracy: 82.55%
# Validation Loss: 0.6700, Validation Accuracy: 77.72%
# Early stopping at epoch 438. Best Validation Loss: 0.6610

# %%
torch.save(model.state_dict(), "cnn_lstm_numerical.pth")
print("Model saved to 'trained_model.pth'")
# Out:
# Model saved to 'trained_model.pth'

# %%
# Plot loss and accuracy curves
def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)
    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Accuracy")
    plt.plot(epochs, history["val_acc"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    plt.show()

plot_history(history)

# Assuming val_true and val_pred are the true and predicted labels
val_true = y_val_tensor.cpu().numpy()  
val_pred = val_predicted.cpu().numpy()  

# Label mapping
label_mapping = {0: '1', 1: '2', 2: '4', 3: '5', 4: '6', 5: '8', 6: '9'}

# Decode labels
val_true_decoded = [label_mapping[label] for label in val_true]
val_pred_decoded = [label_mapping[label] for label in val_pred]

# Classification report with mapped labels
print("\nClassification Report (Mapped Labels):\n")
print(classification_report(val_true_decoded, val_pred_decoded, target_names=list(label_mapping.values())))

# Confusion matrix with mapped labels
cm = confusion_matrix(val_true_decoded, val_pred_decoded, labels=list(label_mapping.values()))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=list(label_mapping.values()), yticklabels=list(label_mapping.values()))
plt.title("Confusion Matrix (Mapped Labels)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ROC and AUC
if len(set(val_true)) == 2:  # Binary classification
    val_probs = torch.softmax(val_outputs, dim=1)[:, 1].cpu().numpy()
    auc = roc_auc_score(val_true, val_probs)
    fpr, tpr, _ = roc_curve(val_true, val_probs)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
    plt.plot([0, 1], [0, 1], "--", color="gray")
    plt.title("ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()
else:
    print("ROC curve and AUC are only applicable for binary classification.")
# Out:
# Classification Report (Mapped Labels):
#
#               precision    recall  f1-score   support
#
#            1       0.84      0.91      0.87        57
#            2       0.67      0.69      0.68        52
#            4       0.85      0.73      0.78        55
#            5       0.74      0.64      0.69        50
#            6       0.81      0.88      0.84        43
#            8       0.74      0.84      0.79        50
#            9       0.80      0.75      0.77        52
#
#     accuracy                           0.78       359
#    macro avg       0.78      0.78      0.78       359
# weighted avg       0.78      0.78      0.78       359
# ROC curve and AUC are only applicable for binary classification.
